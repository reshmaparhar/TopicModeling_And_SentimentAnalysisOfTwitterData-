# %%
from tweepy.streaming import StreamListener
from tweepy import OAuthHandler
from tweepy import Stream
import json
#from auth import TwitterAuth

#Very simple (non-production) Twitter stream example
#1. Download / install python and tweepy (pip install tweepy)
#2. Fill in information in auth.py
#3. Run as: python streaming_simple.py
#4. It will keep running until the user presses ctrl+c to exit
#All output stored to output.json (one tweet  per line)
#Text of tweets also printed as recieved (see note about not doing this in production (final) code
consumer_key="AwF7WSXYvcuinEPrXNbJRZtYe"
consumer_secret="dJ2Cvid0fAruIcd28qfKEBS3azrg3lGFTNsVMZTNtcbqgAQvOR"
access_token="1234693348893458433-fTXBAgdplLA0E4qAPxrOHLLkiwmyEx"
access_token_secret="e7CLFdGtgNitUs7kU8B1PC1qYI66hk3e4DwaJ5yDmMDau"


class StdOutListener(StreamListener):
        
        #This function gets called every time a new tweet is received on the stream
    def on_data(self, data):
          
          fhOut.write(data)
                
                #Convert the data to a json object (shouldn't do this in production; might slow down and miss tweets)
          j=json.loads(data)

                #See Twitter reference for what fields are included -- https://dev.twitter.com/docs/platform-objects/tweets
          text=j["text"] #The text of the tweet
          print(text) #Print it out
           

    def on_error(self, status):
        print("ERROR")
        print(status)

if __name__ == '__main__':
        try:
                #Create a file to store output. "a" means append (add on to previous file)
                fhOut = open("output.json","a")

                #Create the listener
                l = StdOutListener()
                auth = OAuthHandler(consumer_key, consumer_secret)
                auth.set_access_token(access_token, access_token_secret)

                #Connect to the Twitter stream
                stream = Stream(auth, l)        

                #Terms to track
                stream.filter(track=["india"], languages=["en"])
                
                #Alternatively, location box  for geotagged tweets
                #stream.filter(locations=[-0.530, 51.322, 0.231, 51.707])

        except KeyboardInterrupt:
                #User pressed ctrl+c -- get ready to exit the program
                pass

        #Close the 
        fhOut.close()
# Out:
# RT @akhileshsharma1: Breaking News: All the vaccines which have been granted emergency approval for restricted use by USFDA, EMA, UK, MHRA,…
# @unacademy 🏏1. Reserve Bank of India
# 🏏2. The percentage of earth surface covered by India is 2.4.
# 🏏3. 8 September… https://t.co/fF2oPIdHu2
# RT @RanaAyyub: At Kumbh, Covid guard slips: No thermal screening, few masks, 102 test positive. With close to 3.1 million in attendance, mo…
# RT @aush_if: @AgentSaffron By far india had managed covid far better than any other country (10 times better than USA where a large section…
# RT @saharzaman: Hold ur breath before u call this a "masterstroke" by the Govt. Was it waiting for the letter by @RahulGandhi to remind the…
# RT @stae_elephants: A young bull elephant Kusha in S India was recaptured and tortured after escaping from Dubare “camp” to find a mate.  S…
# Kick this person out.
# RT @LiveLawIndia: 'Friends, to have a more civilized India, it is our responsibility to strengthen judiciary. Our Constitution provides a s…
# RT @Suhelseth: You might also wish us Happy Vaisakhi, Ugadi, Navratri, and tomorrow, Vishu too. Since India IS one of your biggest markets.…
# RT @DostKhan_Jammu: Indeed, it's unbelievable.
# An Independent Kerala MLA PC George has said: "India must declare itself a Hindu Rashtra to…
# RT @RealAbdulSubhan: There’s no difference in Hindu extremists in India and Muslim extremists in Pakistan.
#  https://t.co/GKaMmaxAlN
# RT @IndiaHistorypic: 1890s :: Peace In Karachi When It Was Part of India https://t.co/NtYCAoT2VS
# Machine Learning and Deep Learning: How to get started, job opportunities and future scope - India Today
#
# Read more… https://t.co/kWf3OQZcfP
# RT @DrHanifQ: Celebrating the diversity of India!
# #happynewyear2078
# #HappyNavratri https://t.co/OceiRmlWZs
# RT @shytigress: Jagmeet Singh's Family left India as Refugees decades ago.They abandoned  their rights to Indian citizenship.
# Jagmeet is Pe…
# RT @nareshkumbhani: Darjeeling is one of the most beautiful cities in India, and is one of the oldest established cities in India.
#
# It rece…
# RT @lucifer_damned: Last year, one IITian on my fb  explained the “genius of Modi in saving India from Corona by beating utensils through “…
# Next generation of India .My dear Urdu and arebic students . Masaallah! https://t.co/TuNfcGjA3e
# @gambhirmaamla Have you tried this? https://t.co/DsXZJTuk8V
# RT @ShroffMeghana: When kids are brainwashed so openly, it's not just horrifying but also extremely sad that innocent minds are being poiso…
# Aarogya mantri ... minister of health or working in the health dept. what is wrong with a generation of fathers rai… https://t.co/jCHObcSCnQ
# THIS IS MAP OF OUTDOOR COVERAGE ON ROOF IN OUR VILLAGE DHARAMPURA DISTRICT KAITHAL HARYANA INDIA 136033.… https://t.co/xDE8pknWd3
# RT @MeKAMAAL: A Hindu friend brings Ugadi pachadi to a Muslim friend's house on Ugadi day And a Muslim friend brings kheer to a hindu frien…
# RT @Darthsoul0: Size of Vatican Church : 21,000 Sq. meters.
#
# Size of Madurai Meenakshi temple: 65,000 sq. meters.
#
# Almost everyone in the w…
# RT @RavinderKapur2: Look at the US’s sharp fall in COVID cases since Trump was removed in Jan and Biden took over.
#
# You can be sure there a…
# RT @Forbes: Tesla faces speed bumps as it takes its first steps into India’s nascent electric vehicle market, analysts warn https://t.co/KF…
# RT @imMAK02: I tried to search anything related to #KumbhMela2021 on Manish Tiwari's TL but found nothing.
#
# Last year this person was sprea…
# RT @Msur71: He is the Home Minister of India which is topping the charts in daily infections and lowest vaccination in the world nations wh…
# RT @dwnews: Hindu pilgrims flocked to take a holy bath in India's Ganges river, even as the country logged the world's highest tally of new…
# RT @Lolzz53544865: #cancelboardexams2021 #cancleboardexam2021 CBSE board exams must be cancelled.
# Sir chahe kuch ho me to ab next year aap…
# RT @ThePrintIndia: Kashmir or trade, only political will can help India, Pakistan move forward: Ex-envoy to Delhi Salman Bashir
#
# @NayanimaB…
# RT @Sallustan: @taran_adarsh Young Tiger will Roarrr Pan india this time 🐅
# RT @sensible56: #ModiFailsIndia
# If only Modi listened to @RahulGandhi
# If only RG was our PM.
#
# Give everyone vaccine, stop 'eventbaazi': Ra…
# RT @stae_elephants: A young bull elephant Kusha in S India was recaptured and tortured after escaping from Dubare “camp” to find a mate.  S…
# @AmitShah Who is the most useless Chief Minister of India ?
#
# Pls Vote and retweet this poll.
# RT @subhash_kak: Would you say @ruchirsharma_1 that lack of स्वाभिमान, self-respect, amongst India's Anglicized elite was responsible for m…
# RT @imwonwoo1796: Minghao #SIDEBYSIDE_NEXT_TO_THE8 is trending
# #1 Worldwide
# #1 Indonesia
# #1 Chile
# #1 Mexico
# #1 Malaysia
# #1 Philippines
# #2 U…
# RT @virsanghvi: Three days ago Ravi Shankar Prasad was attacking Rahul Gandhi for ‘lobbying for foreign vaccines.’
# Now that the Govt has do…
# RT @rohini_sgh: Just as @RahulGandhi had been insisting all along. After mocking and abusing him and shrieking that no one takes him seriou…
# RT @RanaAyyub: At Kumbh, Covid guard slips: No thermal screening, few masks, 102 test positive. With close to 3.1 million in attendance, mo…
# @sumanthraman Emphasis on make in India is a long term vision. Accepting foreign vaccine to fight the pandemic is immediate necessity.
# RT @kvsaathwika: Saudi Arabia -600 covid -19  cases
# Exams cancelled
# Kuwait - 1400 covid -19 cases
# Exams cancelled
#
# INDIA- 1,40,000 covi…
# RT @RadioChinar: #IncredibleIndia
# India is again embracing its diversity and unity today as she celebrates #Ramazan, #Baisakhi and #Navreh…
# RT @rohini_sgh: Just as @RahulGandhi had been insisting all along. After mocking and abusing him and shrieking that no one takes him seriou…
# RT @QuintNeon: Pandemic, what's that?
# (In video: Recent footage from the Kumbh Mela, Haridwar)
#
# #corona #coronamemes #coronaviruspandemic #…
# RT @RanaAyyub: At Kumbh, Covid guard slips: No thermal screening, few masks, 102 test positive. With close to 3.1 million in attendance, mo…
# RT @TimesNow: Considering anyone else other than Allah as a deity, worshipping it, bowing before it, is expressly forbidden in Islam: @ARan…
# RT @Nagaraj91241208: 3 days waiting n lucknow for cremations
# News of a known couple died due to corona received today
# Indians n India u r…
# RT @CNNnews18: An alternative mode of assessment should be adopted. Why it cannot be adopted and why the board is not taking efforts?: Pres…
# RT @thebetterindia: The cultural historian Thomas Berry once said, “The greater the diversity, the greater the perfection.” And with every…
# RT @MrMaheshroyal1: #boardexams2021 #cancelboardexams2021
# #Telangana
# @NSUI_TS @SonuSood
# Please promote inter 1st year students of Telanga…
# @deewanadeepu @arunpudur @TwitterSupport As oppression? There is like over a billion Hindus in India and 200 millio… https://t.co/Exoe1p3Z83
# RT @mixupindia1: Wow suddenly covid is over? Pandemic is finished?! Really loved this scenario. If this type of gathering can take place th…
# RT @priyankac19: Also, for all those cabinet ministers screeching, politicising and  tweeting that there no vaccine shortage at all, I offe…
# RT @RanaAyyub: At Kumbh, Covid guard slips: No thermal screening, few masks, 102 test positive. With close to 3.1 million in attendance, mo…
# RT @RanaAyyub: What is left for a virus to kill .....
# RT @Darkblade694: @vijayendra0505 Listen Sir VIJAYENDRA, First of all vaccine for Teenagers has Not Arrived Yet. Wht If your Child is Into…
# India should select a team with sanju Samson, deepak Hooda, prithvi Shaw, Abdul samad, nitish Rana, varun Chakrabar… https://t.co/wZuVyPOIO0
# RT @htTweets: Amid rising cases of Covid-19, Uttarakhand chief minister Tirath Singh Rawat reduced the timings for night curfew citing upco…
# RT @AbhishekNapa: THIS IS MAP OF OUTDOOR COVERAGE ON ROOF IN OUR VILLAGE DHARAMPURA DISTRICT KAITHAL HARYANA INDIA 136033.
# @reliancejio @Ji…
# RT @dominneo: #JasLy became evasive all of a sudden. 😂😂😂
# #AlyGoni
#
# JASMIN BHASIN SABSE HASEEN
# #JasminBhasin
# Ummm how to ask... My ass is burning.. seems it has become stiff the hole. Little pain while in washroom... Unable… https://t.co/b4I6X7RMV9
# RT @lucifer_damned: Last year, one IITian on my fb  explained the “genius of Modi in saving India from Corona by beating utensils through “…
# RT @BankerJigyansu: The facts also confirmed by a few bhaktans of my society who have returned from Kumbh few days back. Son of a bhaktan s…
# RT @MeghUpdates: India Should Be Declared As A Hindu Rashtra : Kerela MLA P C George
# RT @laksr_tn: Achchacho...Did the government now become a lobbyist for  pharma companies?
# RT @rohini_sgh: Just as @RahulGandhi had been insisting all along. After mocking and abusing him and shrieking that no one takes him seriou…
# RT @AGNEZMOAG: (NEWS UPDATE)
#  New countries that enter the voting Agnation On Twiterr
# - India 🇮🇳
#
# Keep Voting #Agnation #BestFanArmy at #iH…
# @varungrover Sirji, you shouldn't just read the papers, see the pictures too. India me corona bacha kahan hai?
# RT @Mohd_BM_: Hello @ManishTewari
# Why are you not tweeting about #KumbhMela2021?
#
# Are you acting like Sanghi? https://t.co/L14CKHcT7K
# RT @SadhguruJV: Resurgence of pandemic an indictment of human compulsiveness. Sacrifice of so many of our fellowmen will be laid to waste i…
# RT @koosphoria__: Whats happening in india ; a thread/srs
# RT @HemantaPandit11: Darjeeling is one of the most beautiful cities in India, and is one of the oldest established cities in India.
#
# It rec…
# RT @PLEKarnataka: Kannadigas have no shared history and culture with Naagas, Punjabis, Biharis and Gujaratis.
#
# Why should all these Nation…
# RT @RanaAyyub: At Kumbh, Covid guard slips: No thermal screening, few masks, 102 test positive. With close to 3.1 million in attendance, mo…
# RT @lipstickkranti: Writing about technology from India now feels like having a front-row seat to the country’s rapid slide into authoritar…
# RT @snehamordani: Huge move by the Govt to meet the demand for vaccines -The NEGVAC has recommended that vaccines for COVID-19, which have…
# RT @navdeepsaini96: I pay my homage to the great martyrs of the #JallianwalaBagh massacre, who gave their lives for the future of our natio…
# These are globalist publishing monopolies &amp; need to demonstrate accountability, address privacy concerns &amp; explain… https://t.co/E4gy9UTAWo
# RT @RuchiraC: I can't believe that people are having to plead with the CBSE to cancel offline exams. CBSE itself should reconsider offline…
# RT @shouryology: CBSE will be Curing India's Overpopulation while conducting the Offline Exams  ...
# #cancelboardexams2021 #cancelboardexam2…
# RT @English_bahen: Quite shocking that all political parties, social organisations, religious organisations are ignoring the murderous thre…
# RT @InderpalSinghD2: On this Vaisakhi we #CheatedHomeBuyers  across India inform @RBI @nsitharaman @HardeepSPuri @HomeLoansByHDFC @CarebyHD…
# RT @TheWolfpackIN: Top American Senator Todd Young says that imposing CAATSA sanctions on India for buying the multi-billion-dollar S-400 m…
# RT @LiveLawIndia: 'Friends, to have a more civilized India, it is our responsibility to strengthen judiciary. Our Constitution provides a s…
# RT @kvsaathwika: Saudi Arabia -600 covid -19  cases
# Exams cancelled
# Kuwait - 1400 covid -19 cases
# Exams cancelled
#
# INDIA- 1,40,000 covi…
# RT @JhaSanjay: Thank you Government of India for the decision to give EAU to all foreign approved vaccines. This was much needed to augment…
# RT @diptimoz: 102 yrs since #JallianwalaBagh massacre #India for which #QueenElizabeth &amp; #PrincePhilip never apologised. Now neocolonialism…
# RT @payalbhayana: My friend posted these pics from kumbh 2021.Why international media showing last years pics and so are leftist liberal me…
# RT @PopssKiPrincess: Father of d Indian constitution, On April 14, India celebrates d Ambedkar Jayanti 2 commemorate d birth anniversary of…
# RT @DrKarspeaking: In India's second wave, most of the people getting infected or having a severe COVID infection are under 45 years. Why?…
# RT @SanjeevSanskrit: Ahmadiyas murdered Pandit Lekhram in 1897 when he exposed fraud of Mirza Ghulam Ahmed - founder of Ahmadiya movement…
# RT @svaradarajan: Here's the cover of the 'Harvard study' on UP's migrant crisis. It's by the Institute for Competitiveness, Gurgaon. The I…
# RT @MdFujailAhmed: My humble tributes to d martyrs of #JallianwalaBagh who sacrificed their lives for d independence of our motherland.
# Jal…
# RT @RohitMaara: #VaadiVaasal trending in 27th position on India Trends 😎 🔥
#
# Make it top @Suriya_offl bloods
# Overseas purchases increased more than sevenfold to 98.6 tons last month from 13 tons a year earlier, according to… https://t.co/ZSqzhOD1VV
# Realme 8 5G, Relame 8 Pro 5G to launch in India on April 22 – Times of India https://t.co/nKJdPL9Dah
# RT @Reaproy: Value of major #India company @AdaniOnline takes 4.25% hit because of links/payments to #Myanmar Economic Corporation controll…
# RT @imwonwoo1796: Minghao #SIDEBYSIDE_NEXT_TO_THE8 is trending
# #1 Worldwide
# #1 Indonesia
# #1 Chile
# #1 Mexico
# #1 Malaysia
# #1 Philippines
# #2 U…
# COOL BANNE KE LIYE ENGLISH NHI DIMAAG AUR SENSE KA USE KRTE HAI
#
# WARNA ENGLISH TOH AAJKAL VILLAGERS BHI BOL LETE H… https://t.co/JvdsUYaVB6
# RT @RuchiraC: I can't believe that people are having to plead with the CBSE to cancel offline exams. CBSE itself should reconsider offline…
# RT @imMAK02: DO NOT compare Tablighi Jamaat with #KumbhMela2021 .
#
# TJ meet was held before 15 March when govt was saying "Corona is not a…
# On April 13, 1919, the public had gathered to celebrate Baisakhi. However, the British point of view, as seen from… https://t.co/pwdkVr4QPL
# Brazil coronavirus: Inside the crisis
# #news #covid #india #coronavirus #instagram #love #follow #like #media Brazil… https://t.co/lg4ewtPnBK
# RT @YearOfTheKraken: If you were not blaming Rakesh Tikait and the farmer protests for spreading Covid-19 in India, then shut the hell up a…
# RT @srinivasiyc: All the vaccines which have been granted emergency approval for restricted use by USFDA, EMA, UK, MHRA, PMDA Japan or WHO…
# RT @SinghStar88: @SonuSood Sir I am COVID warrior from Gujarat I request you to raise your voice for the young doctors for India We all are…
# RT @Raghava4mahesh: Ramadan will begin on April 14, 2021 in India and end on the evening of May 12, 2021 (dates will depend on
# moon sighti…
# RT @SadhguruJV: Resurgence of pandemic an indictment of human compulsiveness. Sacrifice of so many of our fellowmen will be laid to waste i…
# RT @AbhishBanerj: US companies are neck deep in collaboration with the Chinese govt.
#
# But a major Indian business is removed from the Dow J…
# Do India really care about our medical professionals?
# RT @DilliDurAst: “Covid accelerates India's millionaire exodus”
#
# In India, all is well. Sab changa si.  https://t.co/TY3UvX52qb
# @SuparnaSharma @somyalakhani @HuzuMufc @BucketheadCase @juneymb @JhinukSen Pulse candy nahin khai? The masala one?… https://t.co/2lhSRkkzhB
# RT @drharshvardhan: It'll be mandatory to conduct post-approval parallel bridging clinical trial as per prescribed provisions.
#
# This decisi…
# RT @thewire_in: S&amp;P Dow Jones Indices said it is removing India’s Adani Ports and Special Economic Zone Ltd from its sustainability index d…
# RT @AmanKayamHai_: What You Must Know About India's Move To Fast-Track Vaccines Okayed by US, UK, Others
# https://t.co/Ljq6Rq2dzb
# RT @Cryptic_Miind: Nehru will be remembered for setting up the foundation of Modern India.
#
# Indira Gandhi will be remembered for making Ban…
# India’s FC Goa🇮🇳 will make history tomorrow when they face Qatar's Al Rayyan🇶🇦 in AFC Champions League match at hom… https://t.co/6xKTZAk04h
# RT @sukumaranlens: @swati_gs Invaders have done this for 1000 years ---enough is enough
#
# Those who kill in the name of religion should get…
# RT @riazxo: be sure to keep the Muslim brothers and sisters in Xinjiang, Palestine and India in your duas this Ramadhan, as well as any oth…
# RT @nilanjanaroy: His track record — getting it right on the pandemic, the economy, policy — will not be acknowledged by most of the media,…
# Thank you @RahulGandhi for emerging as a true opposition to this inhuman regime. A relentless, humane, opposition.… https://t.co/Zh1MDEZIYU
# UK expands Covid-19 vaccine programme to over-45s – Times of India https://t.co/3I2vFNe6RY
# RT @PunnyBhaiya: Why Sanju Samson is not in team India?
# what are you delighted about
# RT @anubha1812: Demands To Cancel Offline Board Exams Grow, Parents  Body Writes To PM
#
# #cancelboardexams2021
# #boardexam2021
# #internalasses…
# RT @nilanjanaroy: His track record — getting it right on the pandemic, the economy, policy — will not be acknowledged by most of the media,…
# RT @CNNnews18: An alternative mode of assessment should be adopted. Why it cannot be adopted and why the board is not taking efforts?: Pres…
# RT @RadioChinar: #TikaUtsav
# Spread of #COVID19 virus is at an upsurge. Let us fight it bravely. "Every eligible person is requested to get…
# RT @vikrantkumar: Kakapora, Pulwama where youth pelted stones on Army while Army was doing encounter last week.
#
# Police caught them red han…
# RT @GowharGeelani: The apologetic tone and interrogative sentences when it is about the majoritarian discourse. In the case of scapegoats’…
# RT @AbhishBanerj: US companies are neck deep in collaboration with the Chinese govt.
#
# But a major Indian business is removed from the Dow J…
# RT @Rahinraj_Offl: • #VaadiVaasal trending in 27th position on India Trends 😎
#
# Make it top @Suriya_offl bloods
# RT @bbcworldservice: “The public are paying the price for letting their guard down.” After India’s Kumbh Mela festival was allowed to go ah…
# @_Stallion101 Your people, your colorful festivals, your beautiful culture and Amazing nature , all these beautiful… https://t.co/TtBODib8Ni
# @mydogistim @VeenaGraffMD @amit_pawa Hi @mydogistim. Me doing absolutely fine, in Bengaluru, India. Hope u r keepin… https://t.co/3bQGSy8Hai
# RT @ficci_india: Trade, technology, tourism and talent are areas where the India-Croatia relationship will grow in coming times: Mr Raj Kum…
# RT @hinduacademy: Jagatpita Brahma Mandir is a Hindu temple situated at Pushkar, Rajasthan, India. It's close to the sacred Pushkar Lake to…
# RT @PredatorPSPK: #VakeelSaab Trailer [ All Time Record ]
#
# Most Liked Pan India Teaser Ni Regional Movie Trailer Tho Lepesadu Just 15 Days…
# RT @AskAnshul: Everyone has opinions. You may agree or disagree but India is not ruled by Sharia where one calls for beheading over disagre…
# RT @voiceofkarur: India level Trending 🤣🔥
#
# #தற்குறி_ஸ்டாலின் https://t.co/IkX5OvOIUk
# RT @VidyaKrishnan: Delighted? Mortuaries are running at full capacity.
# RT @dilipasbe: Fintech growth areas (at random) for next 3 years
#
# 1. Pay later,EMI,Digital credit
# 2. UPI,Mobility,Bill Pay
# 3. Super apps
# 4.…
# RT @imwonwoo1796: Minghao #SIDEBYSIDE_NEXT_TO_THE8 is trending
# #1 Worldwide
# #1 Indonesia
# #1 Chile
# #1 Mexico
# #1 Malaysia
# #1 Philippines
# #2 U…
# RT @thedevil_ind: Tweeting from Android to tell Apple boss that they are biggest users 🤣🤣🤣🤣🤣🤣 https://t.co/IJuIR0mKNt
# RT @RanaAyyub: At Kumbh, Covid guard slips: No thermal screening, few masks, 102 test positive. With close to 3.1 million in attendance, mo…
# RT @Soumya_Addya: 3.5% Bhramins always tried to hijack and divert the history of Mulnivasi community.
#
# But in the leadership of @WamanCMesh…
# RT @fekubawa: Tablighi jammat is COVID hotspot and are super spreaders. Where are all spineless, Godi Media news anchor today?
#
# India as a…
# RT @MirJunaidJKWP: Today is yet another mark of the symbiotic cultural reality of #India. Sikhs r celebrating #baisakhi2021,  Muslims r wel…
# RT @MickyGupta84: Isn't this exactly what @RahulGandhi had suggested a couple of days ago and @rsprasad accused him of lobbying for pharma…
# RT @MeghUpdates: India Should Be Declared As A Hindu Rashtra : Kerela MLA P C George
# RT @AP: India is experiencing its worst pandemic surge, with average daily infections exceeding 130,000. The spike is alarming because Indi…
# RT @VidyaKrishnan: Delighted? Mortuaries are running at full capacity.
# RT @ARanganathan72: Kasab, ordered by his handler to wear the Kalava, the sacred Hindu thread, was not meant to be captured alive. That he…
# RT @manwinder98: “We consume the benefits of these farmers' labour, from the cotton of our crewnecks to the spices in our lattes. Turmeric,…
# RT @AP: India is experiencing its worst pandemic surge, with average daily infections exceeding 130,000. The spike is alarming because Indi…
# RT @RadioChinar: #TikaUtsav
# Spread of #COVID19 virus is at an upsurge. Let us fight it bravely. "Every eligible person is requested to get…
# RT @rohini_sgh: Just as @RahulGandhi had been insisting all along. After mocking and abusing him and shrieking that no one takes him seriou…
# RT @userhyunie: // rape murder stabbing
# -
# -
# -
# -
# -
# -
# - what is happening and what happened in india, a thread. please do not click if tws wi…
# RT @subhash_kak: Would you say @ruchirsharma_1 that lack of स्वाभिमान, self-respect, amongst India's Anglicized elite was responsible for m…
# RT @RuchiraC: I can't believe that people are having to plead with the CBSE to cancel offline exams. CBSE itself should reconsider offline…
# RT @AbhishekNapa: THIS IS MAP OF OUTDOOR COVERAGE ON ROOF IN OUR VILLAGE DHARAMPURA DISTRICT KAITHAL HARYANA INDIA 136033.
# @reliancejio @Ji…
# RT @imwonwoo1796: Minghao #SIDEBYSIDE_NEXT_TO_THE8 is trending
# #1 Worldwide
# #1 Indonesia
# #1 Chile
# #1 Mexico
# #1 Malaysia
# #1 Philippines
# #2 U…
# these are the same kinda people who don't know india is in Asia but go on and ratio people for not knowing a certai… https://t.co/Wxv4CHBryI
# RT @RohanV: "Over 48 hours, The Indian Express walked through an area of over 10 km — from the railway station in Haridwar, the iconic Har…
# RT @narendramodi: Over the next few days, people across India are going to be marking various festivals. These festivals showcase India’s d…
# Are you looking for a vashikaran specialist in India? https://t.co/eoKUqnrSgy
# RT @imMAK02: I tried to search anything related to #KumbhMela2021 on Manish Tiwari's TL but found nothing.
#
# Last year this person was sprea…
# RT @General_Oluchi: @pearlyima @AvrilAmaka You can hate Nigerian men but quote factual stats, because we all have access to the internet an…
# @ndtv If @RahulGandhi Ji would’ve bn the PM of India,the situation would’ve been managed better. #PMModi is only in… https://t.co/cLV81WLZx3
# @AmitShah Who is the most useless Chief Minister of India ?
#
# Pls Vote and retweet this poll.
# RT @JhaSanjay: Thank you Government of India for the decision to give EAU to all foreign approved vaccines. This was much needed to augment…
# RT @mirakamdar: I know so many people in India who want out of what they feel is an increasingly toxic environment on multiple levels, unfo…
# RT @Nicks103: Kidhar delighted? Kaunsa delighted? You were in no mood till yesterday to open up vaccine procurement
# RT @rohini_sgh: Just as @RahulGandhi had been insisting all along. After mocking and abusing him and shrieking that no one takes him seriou…
# @KashHistorypics This question you should put to india 😂
# ... This video is related to Op Gibraltar?
# @lexi__hensler From India🇮🇳
# Just posted a photo @ Delhi, India https://t.co/DJbc13VF9h
# RT @Tutejajoginder: .@tarak9999 &amp; @sivakoratala  collaborate for the 2nd time for a massive pan-India untitled film  Presented by: @NANDAMU…
# RT @SOUVIKMANDAL633: @narendramodi Corona is increasing in India. In other countries no exams will be conducted due to increasing corona so…
# RT @Orla_Hegarty: Anyone watching #COVID19 needs to pay very close attention to what’s unfolding in Brazil, in India, &amp; parts of Canada, es…
# 15-year-old sexually assaulted by 5 men for six months in Tamil Nadu, 3 arrested https://t.co/rGF0I2ttY0 via @indiatoday
# MODI AND UND BHAKTS ARE DESTROYING INDIA 🇮🇳
# RT @stae_elephants: A young bull elephant Kusha in S India was recaptured and tortured after escaping from Dubare “camp” to find a mate.  S…
# RT @rishibagree: Total Covid19 vaccinations Till Date :
#
# Italy - 13 Million
# India - 103 Million
#
# Today an Italian Politician Edvige Antoni…
# RT @nilanjanaroy: His track record — getting it right on the pandemic, the economy, policy — will not be acknowledged by most of the media,…
# There is overwhelming evidence to show that Gadkari lied about the Scania bus. Please read this excellent, damning… https://t.co/RsA16Q4lBQ
# RT @skz_india: Felix is trending in India 🇮🇳 https://t.co/jxkNAgkeEI
# Biggest cause of backwardness of India is inequality of health, education, jobs, and judiciary, all leads by upper… https://t.co/3EdtLZidUT
# RT @MeghUpdates: India Should Be Declared As A Hindu Rashtra : Kerela MLA P C George
# RT @Yeruvaka99: #Prabhas takes home a remuneration of Rs 100 crore given his pan-India appeal.
#
# #PawanKalyan and #MaheshBabu get about Rs…
# RT @SKaran640531: @AshishNarayanS8 @truthserum21 @urveeka @ANI Plus maintaining storage temperature of Pfizer is difficult in India.
# RT @ANURADHARAHEJA: @SrBachchan Wow this year Special Yr n date too🆎Sir❤️.🆎sir ❤️🙏🌹🌹🙏THANK YOU SO Much  For Ur Blessings🆎Sir .U Made My Day…
# RT @amitabhk87: My article in today’s FE : The next few weeks will be pivotal in India’s battle against Covid-19. All Indians must adhere t…
# #England's political move on behest of #USA to put #Pakistan on red list whereas,#UK is safe heaven of black money,… https://t.co/uL4HfR5YFF
# Now... it’s likely both their dead... and their Alive.... telepathy is well known in India....  I don’t blame China… https://t.co/zTMhGsyAPT
# LIVE News | LIVE TV 24x7 | Breaking News LIVE | India News | Republic TV... https://t.co/3EGJh6XbSO via @YouTube
# RT @TeamHinduUnited: A statement praising or criticizing a particular religion can not be termed offensive.
# We are living in a democracy an…
# RT @RanaAyyub: At Kumbh, Covid guard slips: No thermal screening, few masks, 102 test positive. With close to 3.1 million in attendance, mo…
# RT @PrashanjitN: Forign people and forign diesese, out in result out of India.
#
#  #AntiBrahmanismVaccineFestival https://t.co/eOGsARgHsN
# RT @RahulGandhi: In the light of the devastating Corona second wave, conducting #CBSE exams must be reconsidered. All stakeholders must be…
# RT @Sourabh_rai__: WE ARE GOING TO FILE A PETITION IN HIGH COURT OF INDIA.
# SO PLEASE RETWEET IF YOU AGREE
# #cancelboardexam2021
# #cancelboa…
# “No Salaries For Those Absent”: Karnataka Chief Minister On Bus Employees’ Strike https://t.co/s920GvEwTM
# RT @priyankac19: Also, for all those cabinet ministers screeching, politicising and  tweeting that there no vaccine shortage at all, I offe…
# RT @bharat_galani: Darjeeling is one of the most beautiful cities in India, and is one of the oldest established cities in India.
#
# It recei…
# RT @Advaidism: 23,000 Indian millionaires had left the country since 2014.
#
# Countries like Portugal, which runs a 'golden visa' programme a…
# RT @Hyderabadi_chai: Join me in India's Best Academic Job!
#
# @IIMAhmedabad's announcement for faculty positions (all levels) in Economics in…
# Delhi High Court reserves order on the pleas of Facebook and WhatsApp challenging a Competition Commission of India… https://t.co/MfU53iXUf2
# RT @dhruv_rathee: 👉Tablighi Jamat
#
# Date: April 2020
# Daily Cases in India: ~500
# People who attended: ~5000
# Godi Media Label: Corona Jihad…
# That's how meds usually work though. Any doctor could've told you this.
# RT @SOUVIKMANDAL633: @PMOIndia Corona is increasing in India. In other countries no exams will be conducted due to increasing corona so why…
# RT @RanaAyyub: At Kumbh, Covid guard slips: No thermal screening, few masks, 102 test positive. With close to 3.1 million in attendance, mo…
# RT @mirakamdar: I know so many people in India who want out of what they feel is an increasingly toxic environment on multiple levels, unfo…
# RT @akhileshsharma1: Breaking News: All the vaccines which have been granted emergency approval for restricted use by USFDA, EMA, UK, MHRA,…
# RT @VishnuNDTV: Sputnik V may not be a done deal just yet.  Our report.
#
# On Sputnik V For India, Price Issues - AstraZeneca Price Too Low,…
# Thread
# RT @atahasnain53: If every person could retweet this NDMA message India could be safer. Will you RT it?
# RT @imwonwoo1796: Minghao #SIDEBYSIDE_NEXT_TO_THE8 is trending
# #1 Worldwide
# #1 Indonesia
# #1 Chile
# #1 Mexico
# #1 Malaysia
# #1 Philippines
# #2 U…
# RT @AgentSaffron: Lol everywhere across the world corona had a more devastating 2nd wave even 3rd n 4th.
#
# Why would India be any different…
# RT @Zeeshan47383756: #HappyBirthdayPMModi
#   ● MADE IN INDIA 🇮🇳
#
#   ● BY INDIA 🇮🇳
#
#   ● BUT NOT FOR INDIA 🇮🇳
#
# #joblesssincemodi  #Prime…
# RT @Joydas: When Is the Last Election Rally of Narendra Modi in West Bengal? That’s the Day Election Commission will decide too many Covid…
# WHY INDIA MUST KNOW ABOUT VAISAKHI
# https://t.co/VLNt08xM0H
# RT @manabalayya: Still Two tags Trending at India Wide 🔥
#
# #Akhanda #BB3TitleRoar
#
# Once he step in history repeats 🦁 https://t.co/Z2hcIxjqag
# RT @DrJoyeeta: India has decided to grant emergency approval to all COVID vaccines approved by foreign drug regulators.
# A post approval bri…
# RT @GauravPandhi: Narendra Modi is THE MOST INCOMPETENT Prime Minister India ever had. His only focus is on his publicity and not public we…
# @nistula @Barugaru1 In the previous colonized elite, your sense of self worth was derived from who is more westerni… https://t.co/X0nZ3r7uDF
# RT @NareshS43783027: ##GodMorningMonday
# Saviour of the world
# Prophecy of 𝗦𝗵𝗿𝗶 Anandacharya of Norway about Sant Rampal Ji Maharaj
# After 199…
# RT @MeghUpdates: India Should Be Declared As A Hindu Rashtra : Kerela MLA P C George
# RT @BNODesk: BREAKING: India reports 169,243 new coronavirus cases, by far the biggest one-day increase on record
# Imports during the first three months of 2021 more than doubled in the world’s second-biggest consumer to almost 19… https://t.co/o9ZYo8uZPi
# @Kisanektamorcha We all people/ citizens of country warming to you &amp; stop nonsense talk( only farmers protest) &amp; go… https://t.co/gnwPwKdbMF
# RT @MIB_India: 102 years after April 13, 1919, India recalls the brutal #JallianwalaBaghMassacre, a cruel scar etched in the memory of Indi…
# #WestBengal | Union Home Minister #AmitShah said if BJP forms government, it will provide the status of Scheduled T… https://t.co/DTnevce8tJ
# RT @lucifer_damned: Last year, one IITian on my fb  explained the “genius of Modi in saving India from Corona by beating utensils through “…
# @priyankac19 Why don’t you worry about Maharashtra which is accounting for 50% of total cases in India. What covid… https://t.co/Fq8xm6SmTj
# Ambedekar said India's Constitution is  not secular , he is right. 4 lakh Indian temples controlled by Babus while… https://t.co/7Ly3hoCKO6
# @thecaravanindia @AWiseGentleman @sonalmatharu @joe_sperling @HansKoberstein Reserve Bank of India @OfficeOfRSP… https://t.co/0kdYOU4e84
# RT @SudsG4: The truth has been stripped and stands naked for all of us to see.
#
# Pseudo  secular ideology has always been about burying hist…
# @unacademy Answers:
# Q1. Reserve Bank of India
# Q2. 2.4
# Q3. 8th September
# #UnacademyFanOfTheMatch
# #LetsCrackIt… https://t.co/4eiV1nog2x
# RT @willsnellai87: Trending India ✔️
#
#  #தற்குறி_ஸ்டாலின் https://t.co/d35k5NmDcp
# RT @kanechoa: ABS-CBN and BBC Studios have forged an agreement for the local adaptation of the hit British series “Doctor Foster,” making t…
# RT @AskAnshul: Everyone has opinions. You may agree or disagree but India is not ruled by Sharia where one calls for beheading over disagre…
# RT @BiharKaLall: Till citizens of India see people like Kanhaiya Kumar as students , Swara Bhaskar as actors &amp; Ravish Kumar as journalists…
# RT @Pun_Starr: India is a step ahead of other countries.
#
# Some countries are increasing vaccine production. Some others are increasing hosp…
# RT @BTSPublicity: Top 10 countries where @BTS_twt received the most views on YouTube this week:
#
# 1. Japan: 35M
# 2. India: 22M
# 3. Indonesia:…
# RT @AmreliaRuhez: @SuperSaf Ramadan Mubarak To You Also...BTW in India it's Tomorrow 👍
# RT @AnshumanSail: Just In : After Sputnik V, GOI has approved all other vaccines approved by US FDA for use in India.
#
# Sh. Rahul Gandhi has…
# "Our government's effort has always been to vaccinate more people in less time. It is not problem of shortage but a… https://t.co/2l4FNFtQUy
# RT @Mohd_BM_: Hello @ManishTewari
# Why are you not tweeting about #KumbhMela2021?
#
# Are you acting like Sanghi? https://t.co/L14CKHcT7K
# RT @Suhelseth: You might also wish us Happy Vaisakhi, Ugadi, Navratri, and tomorrow, Vishu too. Since India IS one of your biggest markets.…
# RT @woke_netizen07: A second postponement just shows how unplanned the Govt is for boards exams. COVID cases are rising, the medical infras…
# RT @KodelaDeepak: Why not If they come up with a straight Hindi version?. #Major #Liger #RadheShyam will have straight Hindi with lip sync…
# RT @prempanicker: Do inform your colleague RS Prasad about this "remarkable" initiative. He was mocking a certain politician who suggested…
# RT @samar11: A grade nonsense
# Govt is now doing exactly what #RahulGandhi said it should.
# RT @CNNnews18: An alternative mode of assessment should be adopted. Why it cannot be adopted and why the board is not taking efforts?: Pres…
# RT @GauSevaAgniveer: Aahuti
#
# 1 UPI/GPay- agniveerupi@sbi
#
# 2 Outside India https://t.co/86dg2wM5C8
#
# 3 80G tax rebate - Only India
# Jan Swabhi…
# Aster allows NRI’s to play active role in healthcare management of their families in India
# https://t.co/O9KmM3e2tk https://t.co/HAkftwKirx
# @CJ_India Muslims ruled 600 yrs over India. If they really wanted to demolish temples so not a single temple would… https://t.co/ZDnvryi6QT
# #India:-Major fire broke out in Jaipuria Mall in #Indrapuram, #Ghaziabad.
#
# Fire tenders on spot. https://t.co/LnV7FYXG8i
# BJP leaders will have to flee if we go on offensive: KT Rama Rao | Hyderabad News – Times of India https://t.co/5JjbC08OXY
# RT @dev9_: Party time in the Pakistan Dressing Room after their victory over India in the finals of the Champions Trophy #INDvPAK #PAKvIND…
# RT @imwonwoo1796: Minghao #SIDEBYSIDE_NEXT_TO_THE8 is trending
# #1 Worldwide
# #1 Indonesia
# #1 Chile
# #1 Mexico
# #1 Malaysia
# #1 Philippines
# #2 U…
# RT @CNNnews18: An alternative mode of assessment should be adopted. Why it cannot be adopted and why the board is not taking efforts?: Pres…
# RT @tobioskis: open this thread to know what is happening in india rn /srs
# RT @unmissmedia: Health = wealth as #COVID19 has taught us. That's why #UNMISS peacekeepers from India 🇮🇳 joined hands with local communiti…
# RT @AbhishBanerj: US companies are neck deep in collaboration with the Chinese govt.
#
# But a major Indian business is removed from the Dow J…
# RT @shouryology: CBSE will be Curing India's Overpopulation while conducting the Offline Exams  ...
# #cancelboardexams2021 #cancelboardexam2…
# @DrRPNishank
#
# Sir, Please cancel all Board Exams all over India not only CBSE Board. As Per your New Education Policy Evaluate differently.
# RT @drharshvardhan: Delighted to share GoI's remarkable initiative to augment our basket of #COVID19vaccines
#
# #COVIDVaccines which have bee…
# RT @Mathitsfake: Reupping. Great curation on the whole farm laws saga.
# RT @anshikashukla_: Babus and babus’ chaprasis and babus’ political bosses and political patrons have their earnings assured. What do they…
# RT @SaketGokhale: Thanks @RahulGandhi!
#
# And not surprising but the champagne libbu “journalists” who keep attacking him everyday while suc…
# RT @StuartBroad8: Who is the best dancer in the England Cricket Team?
# Chris Woakes. 💃
# RT @newslaundry: Can we chart out a linear history of the feminist movement in India?
#
# In this episode of #LetsTalkAbout🎙️, @gupta_chahak e…
# RT @anirudh_ssrk: Biggest Self- Made Stars of India❤💥🙏 https://t.co/QwZHrjqc4J
# RT @RuchiraC: I can't believe that people are having to plead with the CBSE to cancel offline exams. CBSE itself should reconsider offline…
# RT @AdiviSesh: I promised you #MajorTheFilm is an ALL INDIAN film because
#
# #MajorSandeepUnnikrishnan is INDIA’s SON.
#
# #MajorTeaser Trendi…
# @seemapotdar_INC @NANA_PATOLE @abhijitsapkal1 @AdvYashomatiINC @CMOMaharashtra @SandhyaINC @charulata_tokas… https://t.co/w4fFwUFGSJ
# @sardesairajdeep Who is the most useless Chief Minister of India ?
#
# Pls Vote and retweet this poll.
# RT @awayondjourney: A beautiful village in India 🇮🇳
# Baghi, Himachal Pradesh https://t.co/UAKDaXxZZH
# RT @imwonwoo1796: Minghao #SIDEBYSIDE_NEXT_TO_THE8 is trending
# #1 Worldwide
# #1 Indonesia
# #1 Chile
# #1 Mexico
# #1 Malaysia
# #1 Philippines
# #2 U…
# RT @mygovindia: April 13, 1919, will never be forgotten in the history of India’s Independence. On the 102nd anniversary of the #Jallianwal…
# RT @izZlino: what's happening in india ? a thread /srs
# RT @VRG_7: Fuel replaces ghee in Surat cremations as Covid deaths spike | Surat News - Times of India https://t.co/uuHnKFCsSZ
# RT @AnshumanSail: Just In : After Sputnik V, GOI has approved all other vaccines approved by US FDA for use in India.
#
# Sh. Rahul Gandhi has…
# RT @AudaciousQuest_: Thank you @RahulGandhi for saving India from Modi's tali-thali and forcing the govt to make all the vaccine available.
# Delighted ??? R u serious
# Mr @drharshvardhan
# RT @RadioChinar: #IncredibleIndia
# India is again embracing its diversity and unity today as she celebrates #Ramazan, #Baisakhi and #Navreh…
# RT @drharshvardhan: Delighted to share GoI's remarkable initiative to augment our basket of #COVID19vaccines
#
# #COVIDVaccines which have bee…
# RT @bprerna: Who cares! It's all about 'shahi-snan' (holy dip).
# @PVishwamohan @BhootSantosh @samarjeet_n @GenPanwar @Soldier_forlife @malviyapankaj @rsprasad but I prefer people g… https://t.co/jxtIoTG9tC
# https://t.co/pJpDEdjZF8 PERMANENTLY PRODO¢T$ OF INDIA ???????!!!!
# @MughalAmiruddin @UNGeneva @UNOCHA @UNHumanRights @hrw Bsdk, he comes in middle.of encounter and throws stones. Wha… https://t.co/9ttsBIKFkK
# RT @ShreyaR_C: #thread Owner of a giant private school hides that fact while peddling questionable 'research' on public schooling in India.
# RT @rahul1maji: Darjeeling is one of the most beautiful cities in India, and is one of the oldest established cities in India.
#
# It received…
# RT @thecaravanindia: A Scania audit reveals emails, messages exchanged between Scania India officials and Nitin Gadkari's sons, Sarang and…
# RT @Mohd_BM_: Hello @ManishTewari
# Why are you not tweeting about #KumbhMela2021?
#
# Are you acting like Sanghi? https://t.co/L14CKHcT7K
# RT @SOUVIKMANDAL633: @MamataOfficial Corona is increasing in India. In other countries no exams will be conducted due to increasing corona…
# RT @tobioskis: open this thread to know what is happening in india rn /srs
# RT @Lolzz53544865: #cancelboardexams2021 #cancleboardexam2021 CBSE board exams must be cancelled.
# Sir chahe kuch ho me to ab next year aap…
# RT @Hyderabadi_chai: Join me in India's Best Academic Job!
#
# @IIMAhmedabad's announcement for faculty positions (all levels) in Economics in…
# RT @manojkjhadu: Art. 324 lies buried and thus the idea of ensuring level playing field. Fight on @MamataOfficial ji @RJDforIndia and @yada…
# RT @Jairam_Ramesh: 9 out of 12 members 'nominated' to the Rajya Sabha by the President have subsequently joined the BJP making a complete m…
# RT @InterTelangana: #passinterstudents
# #cancelboardexams2021 #nopostponeonlypromote
# Telangana(India) inter students join the link
#
# Link :-…
# RT @Mahna5G: If u wonder what kind of men were those who invited foreign powers to invade #India, just for their brief personal benefit &amp; e…
# RT @Suhelseth: You might also wish us Happy Vaisakhi, Ugadi, Navratri, and tomorrow, Vishu too. Since India IS one of your biggest markets.…
# RT @raqib_naik: My Latest!
#
# In United States, five groups linked to Hindu nationalist organisations in India including Vishwa Hindu Parisha…
# RT @bbcworldservice: “The public are paying the price for letting their guard down.” After India’s Kumbh Mela festival was allowed to go ah…
# RT @ani_digital: India becomes 60th country to authorise Russian COVID-19 vaccine Sputnik V
#
# Read @ANI Story |
# https://t.co/HnLngmzHVT htt…
# @BJP4India doesn't practice appeasement in states where Hindus are minority!
#
# Basically, appeasement will disappear… https://t.co/n6Lzlzwyus
# @Nilesh23897 @Shariflarkaa @CricCrazyJohns Pakistan play as well all these sports .... Both countries playing these… https://t.co/RQ9KXcL0Hy
# Desh to bhagvan bharose hi chal raha he ! The whole world was praising India and Modi for providing vaccines and fi… https://t.co/GVjLmS1E1f
# Tum Pakistan se ho 😡😡😡😡😤😡😤😡😤😱😱😱😱😱🤬🤬💣💣💣💣
# Me india se ho I'm from india💪💪💪
# @CarryMinati @PMOIndia @SonuSood… https://t.co/m6fYtzGzPK
# RT @GauravPandhi: Narendra Modi is THE MOST INCOMPETENT Prime Minister India ever had. His only focus is on his publicity and not public we…
# RT @mygovindia: Central Drug Authority of India, DCGA gives approval for the emergency use of the Russian vaccine, #SputnikV. This vaccine…
# NITI Aayog, the policy think tank of the Government of India, has launched Version 2.0 of the India Energy Dashboar… https://t.co/pSbig66mo9
# RT @CoinsbitIndia: Legality of Cryptocurrency in India Explained
#
# Crypto regulation in India took a new turn in 2020: The Supreme Court pro…
# RT @SanjeevSanskrit: Ahmadiyas murdered Pandit Lekhram in 1897 when he exposed fraud of Mirza Ghulam Ahmed - founder of Ahmadiya movement…
# RT @AbhishBanerj: US companies are neck deep in collaboration with the Chinese govt.
#
# But a major Indian business is removed from the Dow J…
# #Business : Bhuvneshwar Kumar wins ICC Players of the Month award for superb show in white-ball series against Engl… https://t.co/4ryOAOtjGc
# "Remarkable". Isme bhi self congratulations.
# RT @MEAIndia: EAM @DrSJaishankar: “We would like to be an enlightened power, which not only organises its own rise, but which also facilita…
# @fadeagbo @whitenigerian The real value comes in terms of employment, training of talent, investments into local te… https://t.co/14CNHnKJlP
# RT @BorisWatanabe: @OrwellNGoode No Indians care about this woke bs. He was hilarious as Apu. Everyone in India laughed at the accent. We h…
# RT @PrinceArihan: TMC spokespersons are a bunch of jokers. One fruitcake Anirban tells me that I should not bother about Bengal since I am…
# RT @akhileshsharma1: Breaking News: All the vaccines which have been granted emergency approval for restricted use by USFDA, EMA, UK, MHRA,…
# RT @OpIndia_com: India has to become a ‘Hindu Rashtra’, or it will be turned into an Islamic nation by 2030: Kerala MLA
# https://t.co/mjW4Al…
# RT @skpachauri11: @BJP4Karnataka @INCKarnataka @narendramodi Surat
#
# SMIMER &amp; pvt hospitals refusing to admit patients
# 300-350 patients are…
# RT @MeraUtami: @AhmadWaleed Muhammad Qasim saw that PM Nawaz Sharif will be exiled, PM Imran Khan will struggle and fail, Chaos &amp; civil unr…
# RT @Prakashukla: #NewYear as per #HinduCalendar is celebrated by different names in different parts of the country.
#
# That is what is wonde…
# We are following all the norms and regulations so we won't be having atleast new more positive cases.
#
# But just for… https://t.co/vz8orBTvHr
# RT @FinMinIndia: Finance Minister Smt. @nsitharaman and Mr. @borgebrende, President, @wef discussed the engagement of #worldeconomicforum w…
# RT @imwonwoo1796: Minghao #SIDEBYSIDE_NEXT_TO_THE8 is trending
# #1 Worldwide
# #1 Indonesia
# #1 Chile
# #1 Mexico
# #1 Malaysia
# #1 Philippines
# #2 U…
# This is gross stupid. Mass suicide, if this really erupts.
# Some people shud go to jail for abetment.
# Nagar n kushans gujjar were found in india in 78 AD also... Infact kushan gujjars expand their rule from peshawar t… https://t.co/8UfddlwxAD
# RT @SaketGokhale: The British were eventually packed off &amp; India became free. However, none of the colonial perpetrators ever faced the law…
# INDIA DRIVE: Find Online Citizen Services QUICKER
#
# INDIA Drive is your SEARCH ENGINE for Online Services from Stat… https://t.co/YSbZzzyLQF
# RT @tobioskis: open this thread to know what is happening in india rn /srs
# RT @MahuaMoitra: At Kumbh, Covid guard slips: No thermal screening, few masks, 102 test positive
#
# Good job ModiShah, good job YogiCM for ke…
# The EEZ is more than just an "economic zone". There are coastal state rights and jurisdictions at stake. India n ma… https://t.co/XbGsdPuFpr
# @Sadobson_87 Same reason Australia has banned flights from India.
# RT @CNNnews18: An alternative mode of assessment should be adopted. Why it cannot be adopted and why the board is not taking efforts?: Pres…
# RT @jinnierette: tw // stabbing , murder
# .
# .
# A woman in India was st4bbed 25 times in broad day light just cause she choose to keep working…
# RT @mygovindia: Take the #TikaUtsav pledge today &amp; contribute to India’s fight against COVID-19 by helping the elders or people lacking inf…
# RT @MEAIndia: EAM @DrSJaishankar: “We would like to be an enlightened power, which not only organises its own rise, but which also facilita…
# @drharshvardhan In history u would be remembered as a health minister, himself a medical professional, who cared ev… https://t.co/mALb8vyYag
# RT @ahmermkhan: Several million Hindus have gathered to take a dip in the Ganges river as a deadly second Covid-19 wave continues to sweep…
# RT @RisingBharat_: MMM was incepted in 1989 by Raj as a single-person company with just one product - two-wheeler loans for a foreign bank…
# @unacademy Answers:
# Q1. Reserve Bank of India
# Q2. 2.4
# Q3. 8th September
# #UnacademyFanOfTheMatch
# #LetsCrackIt… https://t.co/dIlwZfrtDQ
# @jhgage1 @momofbaboo1 @ExpatIslander @SmittyDick @GovChrisSununu So which country do we attack first, China or Indi… https://t.co/dJkp7Aq9Lz
# Happy New Year to every body as per India(Hindu) new year and Baiskhi Ki Vadhaiya
# RT @amarprasadreddy: E - Highways are the future of India. #ElectricVehicles https://t.co/vwpfM168mg
# RT @anubha1812: @VarshaEGaikwad @cbseindia29 @CambridgeInt @iborganization Thanks
# Need of the hour and good to see that Maharashtra govt i…
# RT @brain_ded_: Neend churayi teri kisne o sanam?
#
# ... India ke education system ne😔
#
# #cancelboardexams2021
# #cancelboards2021
# #internalas…
# RT @imMAK02: I tried to search anything related to #KumbhMela2021 on Manish Tiwari's TL but found nothing.
#
# Last year this person was sprea…
# RT @Smoker60470998: Nice CBSE i don't know why in INDIA exams is more important than our lifes
# #cancelcbseboards2021
# #cancelboardexams202…
# RT @mirakamdar: I know so many people in India who want out of what they feel is an increasingly toxic environment on multiple levels, unfo…
# Discover hotels around Chennai, India from 4 EUR per night: https://t.co/cLPg7zr7Pl https://t.co/kZTVPH0qnT
# RT @Tathastuaryan: 60,000 sanctuaries were crushed under Muslim principle in India. the saying 'sorry' votes ought to likewise be taken uni…
# RT @CoinsbitIndia: Legality of Cryptocurrency in India Explained
#
# Crypto regulation in India took a new turn in 2020: The Supreme Court pro…
# To new beginnings, peace &amp; abundance. Let's harvest the fresh feeling of hope, happiness &amp; healing.🌾🪘… https://t.co/56CQi3jY46
# RT @CNNnews18: An alternative mode of assessment should be adopted. Why it cannot be adopted and why the board is not taking efforts?: Pres…
# RT @DilliDurAst: The most important yet under-reported story in India today is the fudging of Covid death data and there is perhaps no stat…
# RT @Rahul_SharmaBJP: Darjeeling is one of the most beautiful and the oldest established cities in India.
#
# It received the first electric co…
# RT @Mohd_BM_: Hello @ManishTewari
# Why are you not tweeting about #KumbhMela2021?
#
# Are you acting like Sanghi? https://t.co/L14CKHcT7K
# New Videos Out now plz go and watch the pubg mobile india gaming
# RT @RanaAyyub: At Kumbh, Covid guard slips: No thermal screening, few masks, 102 test positive. With close to 3.1 million in attendance, mo…
# @krish_0108 Yes initial long range forecasts by most models are positive so a private weather agency in India has g… https://t.co/GZ47yBrcY5
# In a major blow to @rsprasad and @smritiirani
# RT @CNNnews18: An alternative mode of assessment should be adopted. Why it cannot be adopted and why the board is not taking efforts?: Pres…
# ...
# RT @dominneo: #JasLy became evasive all of a sudden. 😂😂😂
# #AlyGoni
#
# JASMIN BHASIN SABSE HASEEN
# #JasminBhasin
# @mezba016 @IamAyan_Sarkar when it Comes In India ???
# I'm waiting for this !! https://t.co/nqjC658ETj
# RT @RanaAyyub: At Kumbh, Covid guard slips: No thermal screening, few masks, 102 test positive. With close to 3.1 million in attendance, mo…
# RT @TheWolfpackIN: Top American Senator Todd Young says that imposing CAATSA sanctions on India for buying the multi-billion-dollar S-400 m…
# RT @BeltandRoadDesk: India, one of world’s oldest civilisations, fervently maintains its religious tradition
#
# https://t.co/MenBnep940
# RT @koosphoria__: Whats happening in india ; a thread/srs
# RT @beombox: tw // rape
#
# 2 boys aged 10 and 11 years old raped a 5 year old girl in india. how much longer will we continue to blame the le…
# RT @sanket: This tweet of the minister has not aged well. 3 days after this tweet, the govt today has opened up many foreign vaccines for e…
# RT @grumpeoldman: The assumption is that there is so much spare vaccine manufacturing capacity in India. Or is it that there are tons of va…
# @unacademy Answers:
# Q1. Reserve Bank of India
# Q2. 2.4
# Q3. 8th September
# #UnacademyFanOfTheMatch
# #LetsCrackIt… https://t.co/HHW5sZYsaS
# RT @DilliDurAst: “Polls and Covid go hand-in hand in Bengal, state now has third highest fatality rate in India”  https://t.co/lgbaciBdn4
# RT @srinivasiyc: Ambulances with patients waiting in lines to be admitted inside the hospital of Ahmedabad Gujrat.
#
# The Situation is only g…
# @TheWolfpackIN After S-400 there is a need to impose sanctions on India as Russia is gaining monies from these mili… https://t.co/gKXk7SOXDg
# RT @mirakamdar: I know so many people in India who want out of what they feel is an increasingly toxic environment on multiple levels, unfo…
# RT @anubha1812: @VarshaEGaikwad Thanks
# Need of the hour and good to see that Maharashtra govt is taking this initiative which will help al…
# RT @htTweets: Amid rising cases of Covid-19, Uttarakhand chief minister Tirath Singh Rawat reduced the timings for night curfew citing upco…
# "It has nothing to do with England or India. No matter where or when, it's the same. Humanity, that is." - Sebastian Michaelis
# RT @RanaAyyub: At Kumbh, Covid guard slips: No thermal screening, few masks, 102 test positive. With close to 3.1 million in attendance, mo…
# RT @GowharGeelani: The apologetic tone and interrogative sentences when it is about the majoritarian discourse. In the case of scapegoats’…
# sostronk night | CSGO INDIA Live STREAM | wolvy2 https://t.co/KUsJLp2z78
# RT @gaurav_kochar: #India likely to get average #monsoon rains in 2021 - @SkymetWeather
#
# India is likely to get average monsoon rains this…
# RT @drshraddha16: #ShameOnCongress
# #iTrustChowkidar
# @isro scientist who labeled as traitor,jailed 4 48 days on false charges by @INCIndia…
# RT @AbhishBanerj: US companies are neck deep in collaboration with the Chinese govt.
#
# But a major Indian business is removed from the Dow J…
# RT @drharshvardhan: It'll be mandatory to conduct post-approval parallel bridging clinical trial as per prescribed provisions.
#
# This decisi…
# RT @saahilmenghani: #Verified
#
# 👉Good news for Indian citizens
#
# 👉India gets a 3rd vaccine
#
# 👉Russia's Sputnik V vaccine given emergency use a…
# RT @RuchiraC: I can't believe that people are having to plead with the CBSE to cancel offline exams. CBSE itself should reconsider offline…
# RT @JayasriRamu: @DrRPNishank
#
# Sir, Please cancel all Board Exams all over India not only CBSE Board. As Per your New Education Policy Eva…
# RT @Stupidosaur: LEMOA (military agreement with US to allow them to use our bases to attack China (and India itself by HAARP, DEW, etc hidd…
# RT @KanwalSibal: Why this obsession with dialogue with Pak? Pak asking for some Indian concession in J&amp;K. Implication is Pak has locus stan…
# Dr. #Ashwani Gupta is an #experienced, passionate and #dynamic #Pediatrician. He is practicing and helping patient… https://t.co/KmnddwgxjB
# RT @BBCIndia: Haridwar: Crowds surging at #KumbhMela as India overtakes Brazil in Covid cases.
#
# Officials say they are struggling to impose…
# RT @RohanV: "Over 48 hours, The Indian Express walked through an area of over 10 km — from the railway station in Haridwar, the iconic Har…
# RT @IainLJBrown: Artificial Intelligence: Your friend in the fight against cyberattacks - The Times of India Blog
#
# Read more here: https://…
# RT @rashatouille: i make handmade polymer clay earrings in india - A THREAD:
# check it out on instagram @/clayed.byrasha
# (link in my bio)…
# RT @OpIndia_com: India has to become a ‘Hindu Rashtra’, or it will be turned into an Islamic nation by 2030: Kerala MLA
# https://t.co/mjW4Al…
# RT @MeghUpdates: India Should Be Declared As A Hindu Rashtra : Kerela MLA P C George
# RT @Vaishal67273846: 13 April will never be forgotten in history of India's independence 🥺
# My heartfelt tribute to the immortal martyrs of…
# RT @GMBents: India salutes Major ✊
#
# #MajorTeaser Trending #1 across the Nation💥💥
#
# - https://t.co/D8DDzmhLjV
#
# #MajorTheFilm
#
# @AdiviSesh @sa…
# RT @willsnellai87: Trending India ✔️
#
#  #தற்குறி_ஸ்டாலின் https://t.co/d35k5NmDcp
# RT @RadharamnDas: The mother of the Police officer who was killed by Muslims, dies of shock. Cremated with her son.
#
# Do we want India to t…
# RT @sanket: This tweet of the minister has not aged well. 3 days after this tweet, the govt today has opened up many foreign vaccines for e…
# RT @MinOfCultureGoI: The Bihu dance is one of the most colourful folk dances of India and the traditional heritage of Assam. The festival h…
# RT @thewire_in: With over 1.2 million cases,  India’s COVID-19 situation is much worse than it was when the Tablighi Jamaat event was held…
# RT @alikeskin_tr: How do you spend Ramadan in Kashmir?
#
# If you have some humanity in you, look at the photo and be ashamed.
#
# The government…
# Credit unambiguously goes to @RahulGandhi.
# RT @AskAnshul: Everyone has opinions. You may agree or disagree but India is not ruled by Sharia where one calls for beheading over disagre…
# RT @DilliDurAst: “according to medical department officials, over 18,169 devotees were tested between 11.30 pm Sunday and 5 pm Monday — 102…
# RT @RituRathaur: Posters asking for beheading of @NarsinghVani ji have been put up in UP by religious bigot Owaisi's AIMIM
#
# Forget security…
# RT @luffy_zoro09: Brazil : Postpones/cancels exams.
# India : kya matlab global pandemic is at it's all time high or india second number pe h…
# Let’s welcome Ugadi with great hope, eagerness &amp; anticipation. Let us look forward to a plentiful of joy, satisfact… https://t.co/gr8zBI6l6H
# RT @anubha1812: @VarshaEGaikwad @cbseindia29 @CambridgeInt @iborganization Thanks
# Need of the hour and good to see that Maharashtra govt i…
# RT @saahilmenghani: 3rd vaccine for India. As per trials, all approved vaccines give protection to you from dying of Covid. In the best cas…
# RT @SadhguruJV: Resurgence of pandemic an indictment of human compulsiveness. Sacrifice of so many of our fellowmen will be laid to waste i…
# @Rezang_La Dad Gifted many cameras back in 1980's
#
# But bought 1st DSLR at 40 to
# Click pictures of beauty of India
# A… https://t.co/GNQh29Sdrf
# RT @Siasuchitra5: India needs Anti-Brahmanism Vaccine, which is found in Mahatma Phule's Literature. India will celebrate #AntiBrahmanismVa…
# RT @dhruv_rathee: 👉Tablighi Jamat
#
# Date: April 2020
# Daily Cases in India: ~500
# People who attended: ~5000
# Godi Media Label: Corona Jihad…
# RT @LawyerInBaking: 2020 March : India ran out of RTPCR test kits because the government sent them to other countries.
# Solution : Thaali Ba…
# RT @NagmaniShrivas2: I and every person who live in india appeal to the government and @cbseindia29
# please @cbseindia29 please take a look…
# RT @DilliDurAst: The most important yet under-reported story in India today is the fudging of Covid death data and there is perhaps no stat…
# RT @IndoPac_Info: #China is planning a mega dam in #Tibet able to produce 3 times the electricity generated by the Three Gorges, the world'…
# RT @akhileshsharma1: Breaking News: All the vaccines which have been granted emergency approval for restricted use by USFDA, EMA, UK, MHRA,…
# @DeepalTrevedie @suchetadalal @rishmunk one way or another, india is burning
# RT @dwnews: Hindu pilgrims flocked to take a holy bath in India's Ganges river, even as the country logged the world's highest tally of new…
# RT @nilanjanaroy: His track record — getting it right on the pandemic, the economy, policy — will not be acknowledged by most of the media,…
# Vivo V21 &amp; Vivo V21 5G are going to launch very soon in India 🇮🇳
#
# ▫️Two Variants are available
#       1)Vivo V21 4G… https://t.co/J0K59SPoLK
# RT @htTweets: Kerala minister KT Jaleel resigned on Tuesday from the Pinarayi Vijayan cabinet, days after the state Lokayukta held him acco…
# 🎊It’s a wrap! #NeuroFemIndia2021 🎊
#
# So 💯 grateful to everyone who chose to participate in this conference. I had an… https://t.co/DMNhILJqPI
# RT @nilanjanaroy: His track record — getting it right on the pandemic, the economy, policy — will not be acknowledged by most of the media,…
# Is our PM follow Corona rule? Different world photo compare with India . Is this man fit for PM chair? https://t.co/j7WJuFRYxG
# @sailor_soshii They were saying people should bring traditional dishes from their region because most of my colleag… https://t.co/0V9g7ikksz
# RT @sanket: This tweet of the minister has not aged well. 3 days after this tweet, the govt today has opened up many foreign vaccines for e…
# RT @SurabhiUpadhyay: Good news- India allows usage of #Pfizer, #Moderna &amp; other #vaccines approved by US/EU/UK/Japanese regulators.
# But ke…
# RT @RanaAyyub: What is left for a virus to kill .....
# RT @MamataOfficial: To protest against the undemocratic and unconstitutional decision of the Election Commission of India, I will sit on dh…
# RT @Lolzz53544865: #cancelboardexams2021 #cancleboardexam2021 CBSE board exams must be cancelled.
# Sir chahe kuch ho me to ab next year aap…
# RT @hemirdesai: Christians are writing on Missionary website that as many churches as they could not put up in 25 yrs of #Corona period, th…
# RT @Orla_Hegarty: Anyone watching #COVID19 needs to pay very close attention to what’s unfolding in Brazil, in India, &amp; parts of Canada, es…
# RT @Mohd_BM_: Hello @ManishTewari
# Why are you not tweeting about #KumbhMela2021?
#
# Are you acting like Sanghi? https://t.co/eccyEPqV6B https…
# RT @woke_netizen07: A second postponement just shows how unplanned the Govt is for boards exams. COVID cases are rising, the medical infras…
# RT @ShamikaRavi: Finally! COVID19 vaccines that have been granted emergency approval for restricted use by USFDA, EMA, UK MHRA, PMDA Japan…
# RT @KenRoth: It's a sign of how bad things are under Myanmar military rule that more than 1,000 people have fled to India since the coup. h…
# RT @pulindsamant: Justice F. Nariman's verdict against #WasimRizvi PIL (which he filed risking own life) / imposing cost on him is shocking…
# RT @globalhlthtwit: A new variant, B.1.617 accounts for a sudden increase of cases in Maharashtra, India. It spreads faster and contains an…
# RT @Rahul_SharmaBJP: Darjeeling is one of the most beautiful and the oldest established cities in India.
#
# It received the first electric co…
# RT @sanket: This tweet of the minister has not aged well. 3 days after this tweet, the govt today has opened up many foreign vaccines for e…
# RT @joezap73: That's what happens when you have unscrupulous power hungry people at the helm of governance= No Governance At All. #SaveIndi…
# RT @sensible56: #ModiFailsIndia
# If only Modi listened to @RahulGandhi
# If only RG was our PM.
#
# Give everyone vaccine, stop 'eventbaazi': Ra…
# RT @narendramodi: Over the next few days, people across India are going to be marking various festivals. These festivals showcase India’s d…
# RT @woke_netizen07: No board or the govt is ready to take efforts. Period.
# RT @CNNnews18: An alternative mode of assessment should be adopted. Why it cannot be adopted and why the board is not taking efforts?: Pres…
# RT @payalbhayana: My friend posted these pics from kumbh 2021.Why international media showing last years pics and so are leftist liberal me…
# RT @koosphoria__: Whats happening in india ; a thread/srs
# RT @thecaravanindia: A Scania audit reveals emails, messages exchanged between Scania India officials and Nitin Gadkari's sons, Sarang and…
# RT @DilliDurAst: The most important yet under-reported story in India today is the fudging of Covid death data and there is perhaps no stat…
# RT @SkymetWeather: September - 116% of LPA (LPA for September = 170.2 mm)
#
# • 30% chance of normal
# • 60% chance of above normal
# • 10% chance…
# RT @AdiviSesh: I promised you #MajorTheFilm is an ALL INDIAN film because
#
# #MajorSandeepUnnikrishnan is INDIA’s SON.
#
# #MajorTeaser Trendi…
# RT @SurabhiUpadhyay: Good news- India allows usage of #Pfizer, #Moderna &amp; other #vaccines approved by US/EU/UK/Japanese regulators.
# But ke…
# RT @woke_netizen07: No board or the govt is ready to take efforts. Period.
# RT @KenRoth: "Initially reluctant to speak out against the coup, India recently changed its stance and strongly condemned Myanmar junta's e…
# RT @lucifer_damned: Last year, one IITian on my fb  explained the “genius of Modi in saving India from Corona by beating utensils through “…
# RT @Salina0077: The system needs to change no doubt about it! @PMOIndia @HMOIndia ji, doesn’t public confidence matter? For 10 months we’re…
# RT @RajivMessage: For recent update by Indian defense expert, please read: https://t.co/CwLlyTptzv
# RT @Omkar_Raii: India &amp; UK can deepen collaboration to bring in disruptive innovations &amp; product creation in #FinTech space and strengthen…
# RT @AbhishBanerj: US companies are neck deep in collaboration with the Chinese govt.
#
# But a major Indian business is removed from the Dow J…
# RT @Salina0077: The system needs to change no doubt about it! @PMOIndia @HMOIndia ji, doesn’t public confidence matter? For 10 months we’re…
# RT @DrGauravGarg4: Government has approved #SputnikV vaccine for emergency use in India.
# We are giving Millions of doses to foreign countr…
# Top 10 Trusted Microfinance #Companies in India 2020 https://t.co/CmoO0o8qJM #business
# RT @AP: India says it is approving the use of all coronavirus vaccines that have been given an emergency nod by the WHO or regulators in th…
# RT @Lolzz53544865: #cancelboardexams2021 #cancleboardexam2021 CBSE board exams must be cancelled.
# Sir chahe kuch ho me to ab next year aap…
# #RoyalMalaysianAirForce (#RMAF) looking for new #fighterjet #Malaysia #JF17 #Pakistan #FA50 #SouthKorea #Tejas… https://t.co/Sf3jvJdemC
# @ZahidGishkori Muhammad Qasim has seen that when India attacks and captures land and Pakistan Army fails, then the… https://t.co/LaXRMMKMYI
# RT @AshwiniKChoubey: On Day-3 of Tika Utsav, India’s Cumulative Vaccination Coverage exceeds 10.85 crore with over 40 Lakh doses given in t…
# @ANI People are losing lives, businesses are getting shut, people are losing their jobs, schools are closed and loo… https://t.co/9BusZHh5Cn
# RT @rashtrapatibhvn: Greetings to fellow citizens on Chaitra Sukladi, Ugadi, Gudi Padwa, Cheti Chand, Navreh, Sajibu Cheiraoba, Vishu &amp; Vai…
# RT @c_aashish: Brilliant thread by @surajbrf on Indian vaccination data - production capacity, short term supply demand mismatches, what to…
# RT @LawyerInBaking: 2020 March : India ran out of RTPCR test kits because the government sent them to other countries.
# Solution : Thaali Ba…
# RT @KirenRijiju: She is Inshah Bashir, Wheelchair Basketball Player from Jammu and Kashmir who has made India proud. She is an inspiration…
# RT @indiacom: Regarding CBSE Board Exams 2021, Kejriwal said some alternative methods could be thought of and students can be promoted this…
# RT @KanwalSibal: Why this obsession with dialogue with Pak? Pak asking for some Indian concession in J&amp;K. Implication is Pak has locus stan…
# RT @Suhelseth: You might also wish us Happy Vaisakhi, Ugadi, Navratri, and tomorrow, Vishu too. Since India IS one of your biggest markets.…

# %%
import json
tweets = []
for line in open('output (4).json', 'r'):
    tweets.append(json.loads(line)["text"])
#print(tweets[:10])

type(tweets[2])
tweets[9]

len(tweets)
# Out:
# 3282

# %%
import pandas as pd

df = pd.DataFrame(tweets, columns=['Tweets'])
df.head(1000)
#data_text = df.Tweets
# Out:
#                                                 Tweets
# 0    RT @Joydas: When Is the Last Election Rally of...
# 1    RT @abir_1729: #cancelboardexam2021\n#cancelbo...
# 2    RT @LiveLawIndia: Can Centre Intervene If A St...
# 3    RT @soompi: #GOT7's #BamBam Pauses Activities ...
# 4    RT @NagpurKaRajini: So Covid in Maharashtra sp...
# ..                                                 ...
# 995  Maha-Kumbh Mela Vs Tablighi Jamaat: Not Compar...
# 996  RT @Pritam68450622: #postponeneetpg \nCbse iaf...
# 997  Where are thier keeping Negative Covid-19 repo...
# 998  RT @dinesh_sir: Thanks for taking decisions fo...
# 999  RT @Shehzad_Ind: Several people of a particula...
#
# [1000 rows x 1 columns]

# %%
data_text = df.Tweets.tolist()

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
#tweets['new'] = tweets.apply(lambda x: re.sub(r"http\S+", "", x))
from nltk.stem.porter import *
import nltk
import numpy as np
df['new'] = df['Tweets'].apply(lambda x: re.sub(r"http\S+", "", x))


#  Removing Twitter Handles (@user)
def remove_pattern(input_txt, pattern):
    r = re.findall(pattern, input_txt)
    for i in r:
        input_txt = re.sub(i, '', input_txt)
        
    return input_txt    



# remove twitter handles (@user)
df['tidy_text'] = np.vectorize(remove_pattern)(df['new'], "@[\w]*")



# remove special characters, numbers, punctuations
df['tidy_text'] = df['tidy_text'].str.replace("[^a-zA-Z#]", " ")

 # Removing Short Words     
df['tidy_text'] = df['tidy_text'].apply(lambda x: ' '.join([w for w in x.split() if len(w)>3]))



# Tokenization
tweets = df.values.tolist()
df['tok'] = df['tidy_text'].apply(lambda x: nltk.word_tokenize(x))


noun = []   
#for  index, row in tweets.iterrows():
for pos, row in df.iterrows():
    noun.append([word for word,pos in nltk.pos_tag(row['tok']) if pos == 'NN' or pos =='NNP' or pos == 'NNS' or pos == 'NNPS'])
    
    
df['nouns'] = noun





tokenized_tweet = df['nouns']



# Stemming

stemmer = PorterStemmer()

tokenized_tweet = tokenized_tweet.apply(lambda x: [stemmer.stem(i) for i in x]) 



docs = tokenized_tweet.tolist()

vocab = set( x for doc in docs for x in doc)
n_terms = len(vocab)

# %%
import nltk
from nltk.tokenize import RegexpTokenizer
from nltk.corpus import stopwords

nltk.download('stopwords')

def remove_links(tweet):

    '''Takes a string and removes web links from it'''
    tweet = re.sub(r'http\S+', '', tweet) # remove http links
    tweet = re.sub(r'bit.ly/\S+', '', tweet) # rempve bitly links
    tweet = tweet.strip('[link]') # remove [links]
    return tweet

def remove_users(tweet):
    '''Takes a string and removes retweet and @user information'''
    tweet = re.sub('(RT\s@[A-Za-z]+[A-Za-z0-9-_]+)', '', tweet) # remove retweet
    tweet = re.sub('(@[A-Za-z]+[A-Za-z0-9-_]+)', '', tweet) # remove tweeted at
    return tweet

my_stopwords = nltk.corpus.stopwords.words('english')
word_rooter = nltk.stem.snowball.PorterStemmer(ignore_stopwords=False).stem
my_punctuation = '!"$%&\'()*+,-./:;<=>?[\\]^_`{|}~•@'

# cleaning master function
def clean_tweet(tweet, bigrams=False):
    tweet = remove_users(tweet)
    tweet = remove_links(tweet)
    tweet = tweet.lower() # lower case
    tweet = re.sub('['+my_punctuation + ']+', ' ', tweet) # strip punctuation
    tweet = re.sub('\s+', ' ', tweet) #remove double spacing
    tweet = re.sub('([0-9]+)', '', tweet) # remove numbers
    tweet_token_list = [word for word in tweet.split(' ')
                            if word not in my_stopwords] # remove stopwords

    tweet_token_list = [word_rooter(word) if '#' not in word else word
                        for word in tweet_token_list] # apply word rooter
    if bigrams:
        tweet_token_list = tweet_token_list+[tweet_token_list[i]+'_'+tweet_token_list[i+1]
                                            for i in range(len(tweet_token_list)-1)]
    tweet = ' '.join(tweet_token_list)
    return tweet

nltk.download('stopwords')

df['clean_tweet'] = df.Tweets.apply(clean_tweet)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
from wordcloud import WordCloud 

allWords = ' '.join([tweets for tweets in df['clean_tweet']])
wordCloud = WordCloud(width = 800, height = 500, random_state = 21, max_font_size = 119).generate(allWords)
plt.imshow(wordCloud, interpolation = "bilinear")
plt.axis('off')
plt.show()

# %%
df.Tweets.unique().shape
# Out:
# (2114,)

# %%
df['is_retweet'] = df['Tweets'].apply(lambda x: x[:2]=='RT')
df['is_retweet'].sum()  # number of retweets

df.loc[df['is_retweet']].Tweets.unique().size

df.groupby(['Tweets']).size().reset_index(name='counts')\
  .sort_values('counts', ascending=False).head(10)
# Out:
#                                                  Tweets  counts
# 1249  RT @SonuSood: C:   Cancel \nB:   Board’s \nS: ...     255
# 1322  RT @TrendPSPK: Friends,\n\nEMERGENCY REQUIREME...      38
# 1696  RT @nidhiindiatv: Delhi CM @ArvindKejriwal req...      34
# 1883  RT @trolllikebroo: Delhi CM comes out in suppo...      19
# 789   RT @DipshikhaGhosh: Please, please wear masks....      19
# 1499  RT @dinesh_sir: Thanks for taking decisions fo...      19
# 1598  RT @johnfraher: 💉Vaccine Tracker Update-April ...      16
# 1025  RT @MahuaMoitra: At Kumbh, Covid guard slips: ...      15
# 1622  RT @latokens: Cities for the post-COVID future...      15
# 1580  RT @imchandanRay: Gov’t should be held respons...      14

# %%
import numpy as np
import matplotlib.pyplot as plt
counts = df.groupby(['Tweets']).size()\
           .reset_index(name='counts')\
           .counts

# define bins for histogram
my_bins = np.arange(0,counts.max()+2, 1)-0.5

# plot histogram of tweet counts
plt.figure()
plt.hist(counts, bins = my_bins)
plt.xlabels = np.arange(1,counts.max()+1, 1)
plt.xlabel('copies of each tweet')
plt.ylabel('frequency')
plt.yscale('log', nonposy='clip')
plt.show()

# %%
def find_retweeted(tweet):
    '''This function will extract the twitter handles of retweed people'''
    return re.findall('(?<=RT\s)(@[A-Za-z]+[A-Za-z0-9-_]+)', tweet)

def find_mentioned(tweet):
    '''This function will extract the twitter handles of people mentioned in the tweet'''
    return re.findall('(?<!RT\s)(@[A-Za-z]+[A-Za-z0-9-_]+)', tweet)  

def find_hashtags(tweet):
    '''This function will extract hashtags'''
    return re.findall('(#[A-Za-z]+[A-Za-z0-9-_]+)', tweet)

# %%
my_tweet = 'RT @our_codingclub: Can @you find #all the #hashtags?'
my_other_tweet = 'Not a retweet. All views @my own'

df['retweeted'] = df.Tweets.apply(find_retweeted)
df['mentioned'] = df.Tweets.apply(find_mentioned)
df['hashtags'] = df.Tweets.apply(find_hashtags)

# %%
df[:10]
# Out:
#                                               Tweets  ...                                       hashtags
# 0  RT @Joydas: When Is the Last Election Rally of...  ...                                             []
# 1  RT @abir_1729: #cancelboardexam2021\n#cancelbo...  ...  [#cancelboardexam2021, #cancelboardexams2021]
# 2  RT @LiveLawIndia: Can Centre Intervene If A St...  ...                                             []
# 3  RT @soompi: #GOT7's #BamBam Pauses Activities ...  ...                               [#GOT7, #BamBam]
# 4  RT @NagpurKaRajini: So Covid in Maharashtra sp...  ...                                             []
# 5  UK economy returns to growth despite Covid res...  ...                                             []
# 6  RT @PGaspirant7: #postponeneetpg \n@profplal\n...  ...                              [#postponeneetpg]
# 7  RT @dinesh_sir: Thanks for taking decisions fo...  ...                                             []
# 8  RT @Nher_who: Now that India is facing Second ...  ...                                             []
# 9  RT @abcnews: Thousands of vulnerable Australia...  ...                                             []
#
# [10 rows x 10 columns]

# %%
hashtags_list_df = df.loc[
                       df.hashtags.apply(
                           lambda hashtags_list: hashtags_list !=[]
                       ),['hashtags']]

flattened_hashtags_df = pd.DataFrame(
    [hashtag for hashtags_list in hashtags_list_df.hashtags
    for hashtag in hashtags_list],
    columns=['hashtag'])

# %%
flattened_hashtags_df[:10]
# Out:
#                  hashtag
# 0   #cancelboardexam2021
# 1  #cancelboardexams2021
# 2                  #GOT7
# 3                #BamBam
# 4        #postponeneetpg
# 5              #Zimbabwe
# 6                #Africa
# 7   #cancelboardexam2021
# 8   #CongratulationsHaji
# 9  #cancelboardexams2021

# %%
flattened_hashtags_df['hashtag'].unique().size
# Out:
# 449

# %%
popular_hashtags = flattened_hashtags_df.groupby('hashtag').size()\
                                        .reset_index(name='counts')\
                                        .sort_values('counts', ascending=False)\
                                        .reset_index(drop=True)

# %%
popular_hashtags[:10]
# Out:
#                      hashtag  counts
# 0      #cancelboardexams2021      56
# 1  #cancelcbseboardexams2021      34
# 2                   #COVID19      33
# 3                     #COVID      20
# 4       #cancelboardexam2021      17
# 5                     #India      14
# 6                     #Covid      13
# 7                      #CBSE      13
# 8             #KumbhMela2021      13
# 9   #SIDEBYSIDE_NEXT_TO_THE8      12

# %%
counts = flattened_hashtags_df.groupby(['hashtag']).size()\
                              .reset_index(name='counts')\
                              .counts

# define bins for histogram                              
my_bins = np.arange(0,counts.max()+2, 5)-0.5

# plot histogram of tweet counts
plt.figure()
plt.hist(counts, bins = my_bins)
plt.xlabels = np.arange(1,counts.max()+1, 1)
plt.xlabel('hashtag number of appearances')
plt.ylabel('frequency')
plt.yscale('log', nonposy='clip')
plt.show()

# %%
min_appearance = 10
# find popular hashtags - make into python set for efficiency
popular_hashtags_set = set(popular_hashtags[
                           popular_hashtags.counts>=min_appearance
                           ]['hashtag'])

hashtags_list_df['popular_hashtags'] = hashtags_list_df.hashtags.apply(
            lambda hashtag_list: [hashtag for hashtag in hashtag_list
                                  if hashtag in popular_hashtags_set])
# drop rows without popular hashtag
popular_hashtags_list_df = hashtags_list_df.loc[
            hashtags_list_df.popular_hashtags.apply(lambda hashtag_list: hashtag_list !=[])]

hashtag_vector_df = popular_hashtags_list_df.loc[:, ['popular_hashtags']]

for hashtag in popular_hashtags_set:
    # make columns to encode presence of hashtags
    hashtag_vector_df['{}'.format(hashtag)] = hashtag_vector_df.popular_hashtags.apply(
        lambda hashtag_list: int(hashtag in hashtag_list))

hashtag_matrix = hashtag_vector_df.drop('popular_hashtags', axis=1)

# %%
import seaborn as sns

correlations = hashtag_matrix.corr()

# plot the correlation matrix
plt.figure(figsize=(10,10))
sns.heatmap(correlations,
    cmap='RdBu',
    vmin=-1,
    vmax=1,
    square = True,
    cbar_kws={'label':'correlation'})
plt.show()

# %%
import nltk
from nltk.tokenize import RegexpTokenizer
from nltk.corpus import stopwords

nltk.download('stopwords')

def remove_links(tweet):

    '''Takes a string and removes web links from it'''
    tweet = re.sub(r'http\S+', '', tweet) # remove http links
    tweet = re.sub(r'bit.ly/\S+', '', tweet) # rempve bitly links
    tweet = tweet.strip('[link]') # remove [links]
    return tweet

def remove_users(tweet):
    '''Takes a string and removes retweet and @user information'''
    tweet = re.sub('(RT\s@[A-Za-z]+[A-Za-z0-9-_]+)', '', tweet) # remove retweet
    tweet = re.sub('(@[A-Za-z]+[A-Za-z0-9-_]+)', '', tweet) # remove tweeted at
    return tweet

my_stopwords = nltk.corpus.stopwords.words('english')
word_rooter = nltk.stem.snowball.PorterStemmer(ignore_stopwords=False).stem
my_punctuation = '!"$%&\'()*+,-./:;<=>?[\\]^_`{|}~•@'

# cleaning master function
def clean_tweet(tweet, bigrams=False):
    tweet = remove_users(tweet)
    tweet = remove_links(tweet)
    tweet = tweet.lower() # lower case
    tweet = re.sub('['+my_punctuation + ']+', ' ', tweet) # strip punctuation
    tweet = re.sub('\s+', ' ', tweet) #remove double spacing
    tweet = re.sub('([0-9]+)', '', tweet) # remove numbers
    tweet_token_list = [word for word in tweet.split(' ')
                            if word not in my_stopwords] # remove stopwords

    tweet_token_list = [word_rooter(word) if '#' not in word else word
                        for word in tweet_token_list] # apply word rooter
    if bigrams:
        tweet_token_list = tweet_token_list+[tweet_token_list[i]+'_'+tweet_token_list[i+1]
                                            for i in range(len(tweet_token_list)-1)]
    tweet = ' '.join(tweet_token_list)
    return tweet

nltk.download('stopwords')

df['clean_tweet'] = df.Tweets.apply(clean_tweet)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
from sklearn.feature_extraction.text import CountVectorizer
vectorizer = CountVectorizer(max_df=0.9, min_df=25, token_pattern='\w+|\$[\d\.]+|\S+')

# apply transformation
tf = vectorizer.fit_transform(df['clean_tweet']).toarray()

# tf_feature_names tells us what word each column in the matric represents
tf_feature_names = vectorizer.get_feature_names()

from sklearn.decomposition import LatentDirichletAllocation

number_of_topics = 10

model = LatentDirichletAllocation(n_components=number_of_topics, random_state=0)

model.fit(tf)
# Out:
# LatentDirichletAllocation(batch_size=128, doc_topic_prior=None,
#                           evaluate_every=-1, learning_decay=0.7,
#                           learning_method='batch', learning_offset=10.0,
#                           max_doc_update_iter=100, max_iter=10,
#                           mean_change_tol=0.001, n_components=10, n_jobs=None,
#                           perp_tol=0.1, random_state=0, topic_word_prior=None,
#                           total_samples=1000000.0, verbose=0)

# %%
def display_topics(model, feature_names, no_top_words):

    topic_dict = {}
    for topic_idx, topic in enumerate(model.components_):
        topic_dict["Topic %d words" % (topic_idx)]= ['{}'.format(feature_names[i])
                        for i in topic.argsort()[:-no_top_words - 1:-1]]
        topic_dict["Topic %d weights" % (topic_idx)]= ['{:.1f}'.format(topic[i])
                        for i in topic.argsort()[:-no_top_words - 1:-1]]
    return pd.DataFrame(topic_dict)

# %%
no_top_words = 10

p = display_topics(model, tf_feature_names, no_top_words)

#df['clean_tweet'][0].split(" ")

# %%
p
# Out:
#   Topic 0 words Topic 0 weights  ... Topic 9 words Topic 9 weights
# 0          exam           712.2  ...             …           299.6
# 1         board           358.1  ...         covid           227.0
# 2         centr           356.6  ...            us           107.6
# 3        cancel           352.1  ...          year           100.5
# 4         becom           345.1  ...        vaccin            87.9
# 5             …           318.9  ...          book            74.8
# 6           let           315.8  ...          last            70.2
# 7         covid           311.1  ...           due            51.7
# 8       student           310.0  ...         peopl            47.7
# 9             ’           294.2  ...           age            44.6
#
# [10 rows x 20 columns]

# %%
from numpy import log, exp
from numpy import argmax
import json
from numpy.random import multinomial

class MovieGroupProcess:
    def __init__(self, K=8, alpha=0.1, beta=0.1, n_iters=30):
        '''
        A MovieGroupProcess is a conceptual model introduced by Yin and Wang 2014 to
        describe their Gibbs sampling algorithm for a Dirichlet Mixture Model for the
        clustering short text documents.
        Reference: http://dbgroup.cs.tsinghua.edu.cn/wangjy/papers/KDD14-GSDMM.pdf
        Imagine a professor is leading a film class. At the start of the class, the students
        are randomly assigned to K tables. Before class begins, the students make lists of
        their favorite films. The teacher reads the role n_iters times. When
        a student is called, the student must select a new table satisfying either:
            1) The new table has more students than the current table.
        OR
            2) The new table has students with similar lists of favorite movies.
        :param K: int
            Upper bound on the number of possible clusters. Typically many fewer
        :param alpha: float between 0 and 1
            Alpha controls the probability that a student will join a table that is currently empty
            When alpha is 0, no one will join an empty table.
        :param beta: float between 0 and 1
            Beta controls the student's affinity for other students with similar interests. A low beta means
            that students desire to sit with students of similar interests. A high beta means they are less
            concerned with affinity and are more influenced by the popularity of a table
        :param n_iters:
        '''
        self.K = K
        self.alpha = alpha
        self.beta = beta
        self.n_iters = n_iters

        # slots for computed variables
        self.number_docs = None
        self.vocab_size = None
        self.cluster_doc_count = [0 for _ in range(K)]
        self.cluster_word_count = [0 for _ in range(K)]
        self.cluster_word_distribution = [{} for i in range(K)]
    @staticmethod
    def from_data(K, alpha, beta, D, vocab_size, cluster_doc_count, cluster_word_count, cluster_word_distribution):
        '''
        Reconstitute a MovieGroupProcess from previously fit data
        :param K:
        :param alpha:
        :param beta:
        :param D:
        :param vocab_size:
        :param cluster_doc_count:
        :param cluster_word_count:
        :param cluster_word_distribution:
        :return:
        '''
        mgp = MovieGroupProcess(K, alpha, beta, n_iters=30)
        mgp.number_docs = D
        mgp.vocab_size = vocab_size
        mgp.cluster_doc_count = cluster_doc_count
        mgp.cluster_word_count = cluster_word_count
        mgp.cluster_word_distribution = cluster_word_distribution
        return mgp

    @staticmethod
    def _sample(p):
        '''
        Sample with probability vector p from a multinomial distribution
        :param p: list
            List of probabilities representing probability vector for the multinomial distribution
        :return: int
            index of randomly selected output
        '''
        return [i for i, entry in enumerate(multinomial(1, p)) if entry != 0][0]
    def fit(self, docs, vocab_size):
        '''
        Cluster the input documents
        :param docs: list of list
            list of lists containing the unique token set of each document
        :param V: total vocabulary size for each document
        :return: list of length len(doc)
            cluster label for each document
        '''
        alpha, beta, K, n_iters, V = self.alpha, self.beta, self.K, self.n_iters, vocab_size

        D = len(docs)
        self.number_docs = D
        self.vocab_size = vocab_size

        # unpack to easy var names
        m_z, n_z, n_z_w = self.cluster_doc_count, self.cluster_word_count, self.cluster_word_distribution
        cluster_count = K
        d_z = [None for i in range(len(docs))]

        # initialize the clusters
        for i, doc in enumerate(docs):

            # choose a random  initial cluster for the doc
            z = self._sample([1.0 / K for _ in range(K)])
            d_z[i] = z
            m_z[z] += 1
            n_z[z] += len(doc)
           
            for word in doc:
                if word not in n_z_w[z]:
                    n_z_w[z][word] = 0
                n_z_w[z][word] += 1

        for _iter in range(n_iters):
            total_transfers = 0
            for i, doc in enumerate(docs):

                # remove the doc from it's current cluster
                z_old = d_z[i]

                m_z[z_old] -= 1
                n_z[z_old] -= len(doc)

                for word in doc:
                    n_z_w[z_old][word] -= 1

                    # compact dictionary to save space
                    if n_z_w[z_old][word] == 0:
                        del n_z_w[z_old][word]

                # draw sample from distribution to find new cluster
                p = self.score(doc)
                z_new = self._sample(p)

                # transfer doc to the new cluster
                if z_new != z_old:
                    total_transfers += 1

                d_z[i] = z_new
                m_z[z_new] += 1
                n_z[z_new] += len(doc)

                for word in doc:
                    if word not in n_z_w[z_new]:
                        n_z_w[z_new][word] = 0
                    n_z_w[z_new][word] += 1

            cluster_count_new = sum([1 for v in m_z if v > 0])
            print("In stage %d: transferred %d clusters with %d clusters populated" % (
            _iter, total_transfers, cluster_count_new))
            if total_transfers == 0 and cluster_count_new == cluster_count and _iter>25:
                print("Converged.  Breaking out.")
                break
            cluster_count = cluster_count_new
        self.cluster_word_distribution = n_z_w
        return d_z

    def score(self, doc):
        '''
        Score a document
        Implements formula (3) of Yin and Wang 2014.
        http://dbgroup.cs.tsinghua.edu.cn/wangjy/papers/KDD14-GSDMM.pdf
        :param doc: list[str]: The doc token stream
        :return: list[float]: A length K probability vector where each component represents
                              the probability of the document appearing in a particular cluster
        '''
        alpha, beta, K, V, D = self.alpha, self.beta, self.K, self.vocab_size, self.number_docs
        m_z, n_z, n_z_w = self.cluster_doc_count, self.cluster_word_count, self.cluster_word_distribution

        p = [0 for _ in range(K)]

        #  We break the formula into the following pieces
        #  p = N1*N2/(D1*D2) = exp(lN1 - lD1 + lN2 - lD2)
        #  lN1 = log(m_z[z] + alpha)
        #  lN2 = log(D - 1 + K*alpha)
        #  lN2 = log(product(n_z_w[w] + beta)) = sum(log(n_z_w[w] + beta))
        #  lD2 = log(product(n_z[d] + V*beta + i -1)) = sum(log(n_z[d] + V*beta + i -1))

        lD1 = log(D - 1 + K * alpha)
        doc_size = len(doc)
        for label in range(K):
            lN1 = log(m_z[label] + alpha)
            lN2 = 0
            lD2 = 0
            for word in doc:
                lN2 += log(n_z_w[label].get(word, 0) + beta)
                for j in range(1, doc_size +1):
                  lD2 += log(n_z[label] + V * beta + j - 1)
            p[label] = exp(lN1 - lD1 + lN2 - lD2)

        # normalize the probability vector
        pnorm = sum(p)
        pnorm = pnorm if pnorm>0 else 1
        return [pp/pnorm for pp in p]

    def choose_best_label(self, doc):
        '''
        Choose the highest probability label for the input document
        :param doc: list[str]: The doc token stream
        :return:
        '''
        p = self.score(doc)
        return argmax(p),max(p)

# %%
mgp = MovieGroupProcess(K= 10, alpha=0.1, beta=0.1, n_iters=30)

# %%
n_terms
# Out:
# 3537

# %%
np.random.seed(0)

# %%
y = mgp.fit(docs ,n_terms)
# Out:
# In stage 0: transferred 2602 clusters with 10 clusters populated
# In stage 1: transferred 1222 clusters with 10 clusters populated
# In stage 2: transferred 777 clusters with 10 clusters populated
# In stage 3: transferred 651 clusters with 10 clusters populated
# In stage 4: transferred 605 clusters with 10 clusters populated
# In stage 5: transferred 555 clusters with 10 clusters populated
# In stage 6: transferred 597 clusters with 10 clusters populated
# In stage 7: transferred 594 clusters with 10 clusters populated
# In stage 8: transferred 602 clusters with 10 clusters populated
# In stage 9: transferred 557 clusters with 10 clusters populated
# In stage 10: transferred 531 clusters with 10 clusters populated
# In stage 11: transferred 525 clusters with 10 clusters populated
# In stage 12: transferred 552 clusters with 10 clusters populated
# In stage 13: transferred 560 clusters with 10 clusters populated
# In stage 14: transferred 539 clusters with 10 clusters populated
# In stage 15: transferred 499 clusters with 10 clusters populated
# In stage 16: transferred 536 clusters with 10 clusters populated
# In stage 17: transferred 519 clusters with 10 clusters populated
# In stage 18: transferred 516 clusters with 10 clusters populated
# In stage 19: transferred 530 clusters with 10 clusters populated
# In stage 20: transferred 528 clusters with 10 clusters populated
# In stage 21: transferred 540 clusters with 10 clusters populated
# In stage 22: transferred 526 clusters with 10 clusters populated
# In stage 23: transferred 523 clusters with 10 clusters populated
# In stage 24: transferred 513 clusters with 10 clusters populated
# In stage 25: transferred 493 clusters with 10 clusters populated
# In stage 26: transferred 501 clusters with 10 clusters populated
# In stage 27: transferred 521 clusters with 10 clusters populated
# In stage 28: transferred 491 clusters with 10 clusters populated
# In stage 29: transferred 483 clusters with 10 clusters populated

# %%
docs
# Out:
# [['elect',
#   'ralli',
#   'narendra',
#   'modi',
#   'west',
#   'bengal',
#   'that',
#   'elect',
#   'commiss',
#   'covid'],
#  ['cancelboardexam', 'student', 'exam', 'date'],
#  ['centr',
#   'interven',
#   'state',
#   'do',
#   'well',
#   'high',
#   'court',
#   'ask',
#   'gujarat',
#   'covid',
#   'situat'],
#  ['got',
#   'bambam',
#   'paus',
#   'activ',
#   'staff',
#   'member',
#   'test',
#   'posit',
#   'covid'],
#  ['covid', 'maharashtra', 'spread', 'modi', 'west', 'bengal', 'peopl'],
#  ['economi', 'growth', 'covid', 'restrict'],
#  ['postponeneetpg', 'covid', 'stay', 'surg', 'wait', 'surg'],
#  ['thank', 'decis', 'safeti', 'student', 'pictur', 'exam', 'pattern'],
#  ['india', 'second', 'covid', 'let', 'hope', 'fund', 'name', 'pmcare'],
#  ['thousand', 'australian', 'covid', 'vaccin'],
#  ['china', 'report', 'covid', 'case'],
#  ['clinic', 'colleagu', 'counti'],
#  ['didn', 'peopl', 'trump', 'covid', 'medicin', 'tissu'],
#  ['cabinet', 'envoy', 'minist', 'salari'],
#  ['couldn', 'money', 'vacat', 'covid', 'trump', 'haven'],
#  ['godi',
#   'media',
#   'silent',
#   'believ',
#   'pleas',
#   'india',
#   'modi',
#   'rawat',
#   'govt'],
#  ['bruce', 'circu'],
#  ['just', 'hour', 'love', 'cycl', 'hell'],
#  ['cancel', 'board', 'student', 'exam', 'exam', 'covid', 'student'],
#  ['stori', 'govern', 'compani', 'order', 'coronaviru'],
#  ['flood', 'toxic', 'misinform', 'covid', 'vaccin'],
#  ['discrimin', 'norm', 'biden', 'rhode', 'island', 'vaccin', 'white', 'covid'],
#  ['cancel', 'board', 'sabhi', 'exam', 'exam', 'covid', 'student'],
#  ['cancel', 'board', 'sabhi', 'exam', 'exam', 'covid', 'student'],
#  ['oxford', 'astrazeneca', 'ireland', 'guidelin', 'vaccin'],
#  ['covid', 'case'],
#  ['cancel', 'board', 'sabhi', 'exam', 'exam', 'covid', 'student'],
#  ['zimbabw', 'term', 'roll', 'africa', 'record', 'leadership', 'acumen'],
#  ['cancelboardexam', 'covid', 'case', 'india', 'cbse', 'board'],
#  ['signatur',
#   'poverti',
#   'program',
#   'angat',
#   'buhay',
#   'offic',
#   'vice',
#   'presid'],
#  ['india', 'second', 'covid', 'let', 'hope', 'fund', 'name', 'pmcare'],
#  ['dexamethason', 'result', 'drug', 'sever', 'death'],
#  ['peopl', 'time', 'congratulationshaji'],
#  ['thing', 'time', 'video', 'topic'],
#  ['cancelboardexam', 'cancelcbseboard', 'govern', 'student'],
#  ['delhi', 'student', 'cbse', 'board', 'delhi', 'student', 'teacher'],
#  ['whistleblow'],
#  ['tumn', 'hardwork', 'wast', 'jaayega', 'becz', 'knowl'],
#  ['coronaviru', 'diseas', 'countri', 'healthcar', 'system', 'situat', 'june'],
#  ['peopl', 'covid', 'lifestyl', 'month'],
#  ['doctor', 'situat', 'student', 'parent'],
#  ['cancelboardexam', 'covid', 'case', 'india', 'cbse', 'board'],
#  ['decis', 'bodi', 'emerg', 'requiremen'],
#  ['chang', 'play', 'yesterday', 'moment', 'rule'],
#  ['friend',
#   'emerg',
#   'requir',
#   'blood',
#   'covid',
#   'place',
#   'trust',
#   'hyderabad',
#   'pleas'],
#  ['wave', 'covid', 'cbse', 'board', 'student'],
#  ['intellig', 'predict', 'futur', 'covid', 'strain', 'treatment', 'observ'],
#  ['delhi',
#   'request',
#   'centr',
#   'govt',
#   'cancelcbseboardexam',
#   'fear',
#   'centr',
#   'covid',
#   'hot'],
#  ['polic',
#   'charg',
#   'organ',
#   'lethbridg',
#   'hous',
#   'parti',
#   'covid',
#   'rule',
#   'covid',
#   'yql'],
#  ['situat', 'everyon', 'exam', 'governmen'],
#  ['germani',
#   'ghana',
#   'feasibl',
#   'studi',
#   'vaccin',
#   'product',
#   'ghana',
#   'lead',
#   'pharm'],
#  ['sarjapura', 'road', 'home', 'collect', 'repli', 'respons', 'worst'],
#  ['decis', 'assess', 'time', 'internala'],
#  ['delhi',
#   'request',
#   'centr',
#   'govt',
#   'cancelcbseboardexam',
#   'fear',
#   'centr',
#   'covid',
#   'hot'],
#  ['pleas', 'mask', 'peopl', 'shift'],
#  ['snap'],
#  ['covid', 'gyno', 'lifestyl', 'explain', 'surpris', 'pregn'],
#  ['cancel', 'board', 'sabhi', 'exam', 'exam', 'covid', 'student'],
#  ['increas', 'vaccin', 'covid', 'economi', 'didi'],
#  ['thank'],
#  ['cancel', 'board', 'student', 'exam', 'exam', 'covid', 'student'],
#  ['worri', 'covid', 'vaccin', 'nobodi'],
#  ['cancel', 'board', 'student', 'exam', 'exam', 'covid', 'student'],
#  ['cancel', 'board', 'sabhi', 'exam', 'exam', 'covid', 'student'],
#  ['latest', 'covid', 'case', 'filipino', 'april', 'case', 'recoveri'],
#  ['gari', 'podcast', 'life', 'know'],
#  ['cbse', 'think', 'board', 'student', 'addmiss', 'colleg'],
#  ['cholera',
#   'epidem',
#   'broke',
#   'kumbh',
#   'mela',
#   'peopl',
#   'week',
#   'sixth',
#   'cholera',
#   'pandem'],
#  ['chidambaram',
#   'teekautsav',
#   'celebr',
#   'should',
#   'crusad',
#   'onli',
#   'histori',
#   'stay'],
#  ['frustrat', 'govern', 'investor', 'underwat'],
#  ['incom', 'economi', 'access', 'covid', 'vaccin', 'intern', 'monetari'],
#  ['vaccin', 'aatmanirbharbharat', 'approv', 'vaccin', 'master'],
#  ['antonio',
#   'superintend',
#   'pedro',
#   'martinez',
#   'year',
#   'respons',
#   'fight',
#   'pandem'],
#  ['friend', 'exam', 'year', 'battl'],
#  ['covid',
#   'patient',
#   'autorikshaw',
#   'visual',
#   'satara',
#   'district',
#   'maharashtra'],
#  ['comment', 'risk', 'covid', 'transmiss', 'hospit', 'shouldn'],
#  ['option', 'publicdebt', 'post', 'covid', 'euroarea'],
#  ['covid', 'life', 'time', 'ala', 'number'],
#  ['microchip', 'pentagon', 'detect', 'covid'],
#  ['covid', 'case'],
#  ['doctor', 'situat', 'student', 'parent'],
#  ['suna',
#   'court',
#   'staff',
#   'judg',
#   'covid',
#   'yahan',
#   'twitter',
#   'kitn',
#   'judg',
#   'khule',
#   'ghoom'],
#  ['futur', 'star', 'spread'],
#  ['covid', 'touch', 'condit', 'anyon', 'physic', 'meme', 'covidmem', 'covid'],
#  ['imag',
#   'machin',
#   'learn',
#   'model',
#   'covid',
#   'diagnosi',
#   'suitabl',
#   'clinic',
#   'diagnost',
#   'imag',
#   'read'],
#  ['feel', 'religion', 'covid', 'danc', 'turn'],
#  ['thank', 'barclay', 'covid', 'commun', 'relief', 'fund'],
#  ['cancelboardexam', 'internalassess', 'amaz', 'thank'],
#  ['cancel', 'board', 'sabhi', 'exam', 'exam', 'covid', 'student'],
#  ['covid', 'driven', 'advanc', 'intellig', 'risk', 'inequ', 'read'],
#  ['effect', 'longcovid', 'account', 'frame', 'polici'],
#  ['side', 'effect', 'time', 'place'],
#  ['gym', 'pub', 'wale', 'would', 'lond'],
#  ['covid',
#   'case',
#   'posit',
#   'rate',
#   'chhattisgarh',
#   'maharashtra',
#   'india',
#   'contin'],
#  ['figur', 'skater', 'practic', 'session', 'osaka', 'rink', 'skater', 'nece'],
#  ['institut', 'measur', 'covid'],
#  ['womxn', 'research', 'middl'],
#  ['america', 'everyth', 'covid', 'line', 'vaccin'],
#  ['covid', 'turnaround', 'fauci'],
#  ['lanka', 'covid', 'death', 'toll', 'read', 'more'],
#  ['everybodi'],
#  ['smriti',
#   'irani',
#   'india',
#   'educ',
#   'minist',
#   'garden',
#   'sanchi',
#   'madhya',
#   'pradesh',
#   'collect'],
#  ['citi', 'covid', 'futur'],
#  ['land',
#   'right',
#   'defend',
#   'lawyer',
#   'pap',
#   'pap',
#   'leader',
#   'secur',
#   'forc'],
#  ['protest', 'covid', 'cleaner', 'redund', 'concern', 'exposur'],
#  ['someon',
#   'explain',
#   'first',
#   'world',
#   'countri',
#   'cant',
#   'their',
#   'shit',
#   'order',
#   'these',
#   'other',
#   'countri'],
#  ['chanc', 'regist', 'ffdforum', 'side', 'event', 'today'],
#  ['everyon', 'rapid', 'covid', 'test', 'result', 'minut'],
#  ['haridwar',
#   'crowd',
#   'kumbhmela',
#   'india',
#   'brazil',
#   'covid',
#   'case',
#   'offici'],
#  ['singl',
#   'rise',
#   'infect',
#   'fatal',
#   'push',
#   'india',
#   'covid',
#   'case',
#   'death',
#   'toll'],
#  ['cancel', 'board', 'sabhi', 'exam', 'exam', 'covid', 'student'],
#  ['worldmort', 'process', 'hope'],
#  ['actor', 'student', 'demand', 'cancelboardexam', 'covid', 'hot'],
#  ['cent', 'travel', 'vacat', 'trip', 'countri', 'resid'],
#  ['cancel', 'board', 'sabhi', 'exam', 'exam', 'covid', 'student'],
#  ['umrah', 'umrah', 'covid', 'umrah', 'world', 'photo', 'credit', 'raheel'],
#  ['cabinet', 'today', 'chang', 'hand', 'govern'],
#  ['covid'],
#  ['urgent',
#   'requir',
#   'plasma',
#   'donor',
#   'someon',
#   'covid',
#   'month',
#   'hospit',
#   'faridabad'],
#  ['thread'],
#  ['futur', 'star', 'spread'],
#  ['terror', 'wage', 'covid', 'wage'],
#  ['covid', 'vaccin', 'mean'],
#  ['folk', 'book', 'patient', 'server'],
#  ['parent', 'kid', 'marco', 'alissa', 'piro', 'student', 'zoom', 'parent'],
#  ['area', 'haridwar', 'railway', 'station', 'pauri', 'ghat', 'arrang'],
#  ['actor', 'student', 'demand', 'cancelboardexam', 'covid', 'hot'],
#  ['delhi',
#   'request',
#   'centr',
#   'govt',
#   'cancelcbseboardexam',
#   'fear',
#   'centr',
#   'covid',
#   'hot'],
#  ['elect', 'commiss', 'india', 'failur', 'covid', 'function'],
#  ['tweet',
#   'delhi',
#   'maharashtra',
#   'kerala',
#   'uttar',
#   'pradesh',
#   'construct',
#   'film',
#   'citi'],
#  ['coast',
#   'region',
#   'dedic',
#   'ramadhan',
#   'prayer',
#   'against',
#   'covid',
#   'effect'],
#  ['major', 'peopl', 'today', 'group', 'covid'],
#  ['year', 'old', 'book'],
#  ['covid',
#   'case',
#   'delhi',
#   'arvind',
#   'kejriw',
#   'say',
#   'cancel',
#   'board',
#   'exam'],
#  ['tell',
#   'peopl',
#   'covid',
#   'hundr',
#   'thousand',
#   'peopl',
#   'year',
#   'death',
#   'rate'],
#  [],
#  ['machin',
#   'predict',
#   'ill',
#   'death',
#   'covid',
#   'patient',
#   'becker',
#   'hospit',
#   'review',
#   'read'],
#  ['bambam', 'halt', 'activ', 'staff', 'member', 'covid', 'posit'],
#  ['cancelboardexam', 'situat', 'covid', 'case', 'board', 'exam', 'myopinion'],
#  ['india',
#   'grant',
#   'emerg',
#   'authoris',
#   'vaccin',
#   'regul',
#   'health',
#   'ministri'],
#  ['fella'],
#  ['unfinish', 'busi', 'offici', 'year', 'universit'],
#  ['covid', 'case', 'india', 'lakh', 'case', 'thank', 'global', 'lead'],
#  ['scientist', 'osun', 'state', 'nigeria', 'test', 'covid'],
#  ['scientist',
#   'expert',
#   'nanosci',
#   'prof',
#   'indrani',
#   'banerji',
#   'gujarat',
#   'central',
#   'univers',
#   'breat'],
#  ['health',
#   'prioriti',
#   'given',
#   'natur',
#   'spread',
#   'covid',
#   'mva',
#   'govern',
#   'feel',
#   'board',
#   'exam'],
#  ['china'],
#  ['cancel', 'board', 'sabhi', 'exam', 'exam', 'covid', 'student'],
#  ['class', 'cbse', 'student', 'board', 'middl'],
#  ['cancel', 'board', 'sabhi', 'exam', 'exam', 'covid', 'student'],
#  ['covid', 'more', 'clean', 'suppli'],
#  ['malaysia', 'covid', 'case', 'today', 'sarawak', 'number', 'infect', 'case'],
#  ['student', 'pressur', 'studi', 'live'],
#  ['wood', 'work', 'staff', 'spill', 'bean'],
#  ['ramadan', 'kareem', 'resid', 'ramadan', 'everyon', 'stay', 'period'],
#  ['thank'],
#  ['brain', 'consumer', 'hedon'],
#  ['sheep', 'play', 'scam'],
#  ['dear', 'covid', 'satur', 'need', 'bed', 'karnataka'],
#  ['actor', 'student', 'demand', 'cancelboardexam', 'covid', 'hot'],
#  ['covid', 'trivia', 'knowledg', 'didn', 'border', 'closur'],
#  ['kumbh', 'covid', 'guard', 'test', 'good', 'modishah', 'yogicm'],
#  ['blatant', 'year', 'twice'],
#  ['covid', 'reach', 'home'],
#  ['come', 'thing'],
#  ['case', 'covid', 'variant', 'south', 'africa', 'lambeth', 'everyon'],
#  ['join',
#   'facebook',
#   'morn',
#   'offici',
#   'launch',
#   'join',
#   'forc',
#   'covid',
#   'ucc'],
#  ['cancel', 'charg', 'refund', 'harass'],
#  ['media', 'report', 'gover'],
#  ['cute', 'china', 'govern', 'respons', 'covid'],
#  ['cancel', 'board', 'sabhi', 'exam', 'exam', 'covid', 'student'],
#  ['thank', 'decis', 'safeti', 'student', 'pictur', 'exam', 'pattern'],
#  ['bambam', 'halt', 'activ', 'staff', 'member', 'covid', 'posit'],
#  ['england', 'book', 'covid'],
#  ['covid', 'case', 'delhi', 'peopl', 'hour', 'case', 'delh'],
#  ['could', 'wasn', 'covid', 'test', 'test'],
#  ['yeah', 'covid'],
#  ['bambam', 'staff', 'member', 'covid', 'statu'],
#  ['cancel', 'board', 'sabhi', 'exam', 'exam', 'covid', 'student'],
#  ['karnan',
#   'offic',
#   'rampag',
#   'continu',
#   'everywher',
#   'open',
#   'weekend',
#   'world',
#   'wide',
#   'collect'],
#  ['dessis', 'maharashtra', 'dessis', 'postpon', 'cbse', 'exam'],
#  ['postpon', 'show', 'govt', 'board', 'covid', 'case', 'infra'],
#  ['delhi', 'student', 'cbse', 'board', 'delhi', 'student', 'teacher'],
#  ['peopl', 'book', 'covid', 'vaccin'],
#  ['book', 'covid', 'vaccin'],
#  ['delhi',
#   'chief',
#   'minist',
#   'arvindkejriw',
#   'appeal',
#   'centr',
#   'cancel',
#   'cbse',
#   'board'],
#  ['core', 'biden', 'summit', 'week', 'stab', 'cut'],
#  ['futur', 'star', 'spread'],
#  ['maulana',
#   'wahiduddin',
#   'khan',
#   'condit',
#   'apollo',
#   'hospit',
#   'sarita',
#   'vihar'],
#  ['island'],
#  ['cancel', 'board', 'sabhi', 'exam', 'exam', 'covid', 'student'],
#  ['health', 'power', 'health', 'risk', 'covid'],
#  ['cancel', 'board', 'sabhi', 'exam', 'exam', 'covid', 'student'],
#  ['delhi',
#   'request',
#   'centr',
#   'govt',
#   'cancelcbseboardexam',
#   'fear',
#   'centr',
#   'covid',
#   'hot'],
#  ['vaccin', 'march', 'care', 'facil', 'group', 'home', 'equiti', 'pleas'],
#  ['rekt', 'protect', 'pfizer', 'vaccin', 'affect'],
#  ['shoot', 'dare'],
#  ['board', 'hematologist', 'histori', 'embol', 'thing'],
#  ['johnson', 'show', 'today', 'qualm', 'attent'],
#  ['cancelboardexam', 'condit', 'graph', 'covid', 'case'],
#  ['hasn', 'decis', 'student'],
#  ['delhi',
#   'request',
#   'centr',
#   'govt',
#   'cancelcbseboardexam',
#   'fear',
#   'centr',
#   'covid',
#   'hot'],
#  ['cancel', 'board', 'sabhi', 'exam', 'exam', 'covid', 'student'],
#  ['deja'],
#  ['fact', 'congreg', 'state', 'govern', 'scare'],
#  ['australia', 'offic', 'spin'],
#  ['fake', 'scienc'],
#  ['putin',
#   'puddin',
#   'scarecrow',
#   'trampstamp',
#   'less',
#   'luthor',
#   'covid',
#   'lumpi',
#   'jeff',
#   'hitler'],
#  ['cancel', 'board', 'sabhi', 'exam', 'exam', 'covid', 'student'],
#  ['children', 'home', 'school', 'school'],
#  ['england', 'book', 'coronaviru', 'vaccin', 'onlin', 'link'],
#  ['cancel', 'board', 'sabhi', 'exam', 'exam', 'covid', 'student'],
#  ['covid',
#   'church',
#   'member',
#   'south',
#   'korea',
#   'declar',
#   'donat',
#   'billion',
#   'worth',
#   'plasma',
#   'cure'],
#  ['cancel', 'board', 'sabhi', 'exam', 'exam', 'covid', 'student'],
#  ['citi', 'covid', 'futur'],
#  ['govern',
#   'inquiri',
#   'russia',
#   'report',
#   'priti',
#   'patel',
#   'bulli',
#   'racism',
#   'covid',
#   'respon'],
#  ['canada',
#   'vaccin',
#   'shortag',
#   'covid',
#   'case',
#   'pass',
#   'rate',
#   'doctor',
#   'vaccin',
#   'repo'],
#  ['hour', 'result', 'genos', 'test', 'research', 'covid', 'machi'],
#  ['everyth', 'conspiraci', 'becom'],
#  ['appoint', 'covid', 'vaccin', 'drive', 'week'],
#  ['book', 'covid', 'vaccin', 'just', 'husband', 'friday'],
#  ['reason', 'world', 'maharashtra', 'effect', 'number'],
#  ['delhi', 'report', 'covid', 'case', 'hour', 'covid'],
#  ['ngo', 'role', 'africa', 'covid', 'vaccin'],
#  ['cancel', 'board', 'sabhi', 'exam', 'exam', 'covid', 'student'],
#  ['myanmar', 'aung', 'charg', 'disast', 'manag', 'covid', 'prot'],
#  ['decis', 'district', 'congress', 'offic', 'chhattisgarh', 'covid', 'hospit'],
#  ['true'],
#  ['pull',
#   'gujarat',
#   'govt',
#   'covid',
#   'situat',
#   'realiti',
#   'state',
#   'govt',
#   'claim'],
#  ['blood', 'pressur', 'prayut', 'chan', 'facebook', 'livestream', 'minist'],
#  ['covid', 'challen'],
#  ['thank', 'decis', 'safeti', 'student', 'pictur', 'exam', 'pattern'],
#  ['sell', 'someth', 'pay', 'sellingcont', 'artistontwitt', 'artwork', 'covid'],
#  ['stori', 'pictur', 'naga', 'sadhu', 'mask', 'ganga'],
#  ['latest', 'mutant', 'covid'],
#  ['violenc', 'riot', 'murder', 'covid', 'russia', 'china', 'iran'],
#  ['work',
#   'technic',
#   'advisori',
#   'group',
#   'covid',
#   'mortal',
#   'assess',
#   'method'],
#  ['check', 'covid', 'death', 'countri', 'nope'],
#  ['credit', 'card', 'scam', 'fraudster', 'cash', 'covid', 'avoid', 'victim'],
#  ['cancel', 'board', 'sabhi', 'exam', 'exam', 'covid', 'student'],
#  ['covid', 'pictur', 'develop', 'job', 'today'],
#  ['covid', 'vaccin', 'appoint', 'kensington', 'sign'],
#  ['someon', 'covidvaccin', 'book', 'visit'],
#  ['covid', 'vaccin', 'appoint', 'chambersburg', 'sign'],
#  ['covid', 'vaccin', 'appoint', 'rite', 'etter', 'sign'],
#  ['covid', 'vaccin', 'appoint', 'rite', 'dover', 'sign'],
#  ['hospit', 'mumbai', 'help', 'covid', 'center', 'kaha', 'mumb'],
#  ['covid', 'vaccin', 'appoint', 'rite', 'york', 'sign'],
#  ['covid', 'vaccin', 'appoint', 'rite', 'spring', 'grove', 'sign'],
#  ['covid', 'vaccin', 'appoint', 'york', 'sign'],
#  ['covid', 'vaccin', 'appoint', 'rite', 'lion', 'sign'],
#  ['covid', 'vaccin', 'appoint', 'rite', 'manchest', 'sign'],
#  ['cancel', 'board', 'sabhi', 'exam', 'exam', 'covid', 'student'],
#  ['india', 'second', 'covid', 'let', 'hope', 'fund', 'name', 'pmcare'],
#  ['doe', 'nation', 'world', 'elect', 'ralli'],
#  ['chief', 'final', 'call', 'market', 'covid', 'outbreak'],
#  ['pleas', 'mask', 'peopl', 'shift'],
#  ['covid', 'spectrum', 'bhola'],
#  ['actor', 'student', 'demand', 'cancelboardexam', 'covid', 'hot'],
#  ['book', 'covid', 'vaccin', 'just', 'husband', 'friday'],
#  ['week', 'tweet'],
#  ['rehash',
#   'demand',
#   'yesterday',
#   'scotland',
#   'hospit',
#   'sector',
#   'covid',
#   'restrict'],
#  ['intern',
#   'polit',
#   'time',
#   'risk',
#   'uncertainti',
#   'covid',
#   'crisi',
#   'beyond',
#   'prorgramm',
#   'registrati'],
#  ['cancel', 'board', 'sabhi', 'exam', 'exam', 'covid', 'student'],
#  ['sigh', 'everyon', 'math', 'school', 'number', 'hugger'],
#  ['examin', 'center', 'covid', 'hotspot', 'delhi', 'centr', 'cancel', 'cbse'],
#  ['paragraph', 'polici', 'failur', 'covid', 'book'],
#  ['delhi', 'arvindkejriw', 'decis', 'conduct', 'boardexam', 'view', 'number'],
#  ['condit'],
#  ['peopl', 'name', 'buri', 'one', 'peopl'],
#  ['yeah', 'citi', 'effect', 'wave', 'till', 'date', 'case', 'occup'],
#  ['sturgeon',
#   'record',
#   'slowest',
#   'school',
#   'hotel',
#   'bar',
#   'restaur',
#   'health',
#   'club'],
#  ['exam', 'covid', 'health', 'children', 'import', 'cancel'],
#  ['year', 'tobacco', 'guid', 'countri', 'way'],
#  ['call', 'mutat', 'south', 'african', 'strain', 'call', 'covid'],
#  ['trial', 'confirm', 'sanot', 'breakthrough', 'treatment'],
#  ['muslim', 'world', 'ramadan', 'commun', 'holi', 'mont'],
#  ['let', 'uccsrckocc'],
#  ['experi',
#   'ethnic',
#   'minor',
#   'prison',
#   'measur',
#   'prevent',
#   'spread',
#   'covid',
#   'prison'],
#  ['imag',
#   'machin',
#   'learn',
#   'model',
#   'covid',
#   'diagnosi',
#   'suitabl',
#   'clinic',
#   'diagnost',
#   'imag',
#   'read'],
#  ['covid', 'hope'],
#  ['break', 'doctor', 'letter', 'grave', 'danger', 'children', 'jab'],
#  ['instruct',
#   'addl',
#   'chief',
#   'seci',
#   'depart',
#   'collector',
#   'municip',
#   'commission',
#   'pho'],
#  ['covid', 'world', 'thank'],
#  ['cancel', 'board', 'sabhi', 'exam', 'exam', 'covid', 'student'],
#  ['covid', 'surg', 'wandsworth', 'lambeth', 'variant', 'case'],
#  ['heart',
#   'account',
#   'hunger',
#   'guatemala',
#   'climat',
#   'chang',
#   'food',
#   'product',
#   'bean',
#   'price'],
#  ['govern',
#   'inquiri',
#   'russia',
#   'report',
#   'priti',
#   'patel',
#   'bulli',
#   'racism',
#   'covid',
#   'respon'],
#  ['covid',
#   'protocol',
#   'faan',
#   'suspend',
#   'driver',
#   'from',
#   'passeng',
#   'airport',
#   'termin'],
#  ['chang', 'play', 'yesterday', 'moment', 'rule'],
#  ['cancel', 'board', 'sabhi', 'exam', 'exam', 'covid', 'student'],
#  ['book', 'test', 'sticker'],
#  ['cancel', 'board', 'sabhi', 'exam', 'exam', 'covid', 'student'],
#  ['haridwar', 'mahakumbh', 'covid', 'case', 'markaz', 'speak'],
#  ['viru', 'hospit', 'govern', 'covid', 'medic', 'aren'],
#  ['inform', 'news', 'stori', 'deceiv', 'reader'],
#  ['cancelboardexam', 'exam', 'covid', 'health', 'children', 'import'],
#  ['covid', 'bazaar', 'launch', 'gon', 'food'],
#  ['week', 'polici', 'panel', 'econom', 'covid', 'april', 'full', 'programm'],
#  ['covid', 'driven', 'advanc', 'intellig', 'risk', 'inequ', 'read'],
#  ['friend',
#   'emerg',
#   'requir',
#   'blood',
#   'covid',
#   'place',
#   'trust',
#   'hyderabad',
#   'pleas'],
#  ['saudi',
#   'arabia',
#   'covid',
#   'case',
#   'exam',
#   'kuwait',
#   'covid',
#   'case',
#   'exam',
#   'india',
#   'covi'],
#  [],
#  ['covid', 'infect', 'singapor', 'dormitori', 'case', 'todayonlin'],
#  ['drug', 'diseas', 'rheumatoid', 'arthriti', 'sclerosi', 'coliti'],
#  ['leadership', 'prepar', 'challeng', 'nation', 'duti', 'bharat', 'mata'],
#  ['vakeelsaab', 'master', 'audienc', 'south', 'star'],
#  ['cancel', 'board', 'sabhi', 'exam', 'exam', 'covid', 'student'],
#  ['year', 'covid', 'take', 'outta'],
#  ['support', 'cancel', 'cbse', 'board', 'case'],
#  ['lancet',
#   'studi',
#   'find',
#   'link',
#   'between',
#   'covid',
#   'variant',
#   'higher',
#   'mortal'],
#  ['mislead'],
#  ['bambam', 'halt', 'activ', 'staff', 'member', 'covid', 'posit'],
#  ['break', 'delhi', 'govern', 'cancel', 'cbse', 'covid', 'situat'],
#  ['aunt', 'need'],
#  ['thank', 'decis', 'safeti', 'student', 'pictur', 'exam', 'pattern'],
#  ['cancel', 'board', 'sabhi', 'exam', 'exam', 'covid', 'student'],
#  ['cancel', 'board', 'sabhi', 'exam', 'exam', 'covid', 'student'],
#  ['look', 'book', 'vaccin'],
#  ['case', 'case', 'basi', 'adult'],
#  ['lancet',
#   'studi',
#   'find',
#   'link',
#   'between',
#   'covid',
#   'variant',
#   'higher',
#   'mortal'],
#  ['compani', 'damag', 'covid', 'fortun', 'read', 'arti'],
#  ['bounc', 'from', 'scene', 'number', 'case'],
#  ['delhi', 'chairman', 'ganga', 'hospit', 'prof', 'rana', 'concern'],
#  ['cancel', 'board', 'sabhi', 'exam', 'exam', 'covid', 'student'],
#  ['morn', 'pleas', 'fund', 'accept', 'approv', 'covid', 'loan'],
#  ['kejriw',
#   'centr',
#   'cancel',
#   'cbse',
#   'board',
#   'covid',
#   'case',
#   'delhi',
#   'cbse',
#   'cbsenew'],
#  ['vaccin', 'tracker', 'updat', 'april', 'dose', 'world', 'rollout'],
#  ['futur', 'star', 'spread'],
#  ['india', 'covid', 'world', 'festiv', 'ralli', 'concern'],
#  ['increas', 'vaccin', 'covid', 'economi', 'didi'],
#  ['year', 'children', 'downright', 'polici'],
#  ['friend',
#   'emerg',
#   'requir',
#   'blood',
#   'covid',
#   'place',
#   'trust',
#   'hyderabad',
#   'pleas'],
#  ['india', 'covid', 'nation', 'vaccin'],
#  ['incom', 'economi', 'access', 'covid', 'vaccin', 'intern', 'monetari'],
#  ['actor', 'student', 'demand', 'cancelboardexam', 'covid', 'hot'],
#  ['vaccin', 'week', 'week'],
#  ['everyon', 'wandsworth', 'covid', 'test', 'asap', 'help'],
#  ['delhi', 'student', 'cbse', 'board', 'delhi', 'student', 'teacher'],
#  ['maulana',
#   'wahiduddin',
#   'khan',
#   'condit',
#   'apollo',
#   'hospit',
#   'sarita',
#   'vihar'],
#  ['becki', 'covid', 'yesterday', 'shot', 'stake', 'right'],
#  ['cbse', 'cancel', 'board', 'sabhi', 'exam', 'cancelboardexam'],
#  ['hour',
#   'indian',
#   'express',
#   'area',
#   'railway',
#   'station',
#   'haridwar',
#   'icon'],
#  ['sar', 'viru', 'studi', 'viru', 'demis', 'chang', 'season'],
#  ['covax', 'hope', 'covid', 'vaccin'],
#  ['terror', 'wage', 'covid', 'wage'],
#  ['bambam', 'staff', 'member', 'covid', 'statu'],
#  ['day', 'covid'],
#  ['cancel', 'board', 'sabhi', 'exam', 'exam', 'covid', 'student'],
#  ['today', 'goodby', 'covid', 'testymctestfac', 'covi'],
#  ['covid', 'other', 'avoid'],
#  ['covid', 'shot', 'shit'],
#  ['cancel', 'board', 'sabhi', 'exam', 'exam', 'covid', 'student'],
#  ['crisi', 'come', 'person', 'covid', 'expert'],
#  ['thank', 'decis', 'safeti', 'student', 'pictur', 'exam', 'pattern'],
#  ['post', 'syndrom', 'round', 'decad'],
#  ['peopl', 'covid', 'westminsterhour', 'call'],
#  ['cancel', 'board', 'sabhi', 'exam', 'exam', 'covid', 'student'],
#  ['year', 'trump', 'hydroxychloroquin', 'fantasi', 'cure', 'covid'],
#  ['delhi',
#   'request',
#   'centr',
#   'govt',
#   'cancelcbseboardexam',
#   'fear',
#   'centr',
#   'covid',
#   'hot'],
#  ['ugadi', 'see', 'peopl', 'covid', 'pleas', 'stay', 'wear', 'mask'],
#  ['peopl', 'hand'],
#  ['covid',
#   'case',
#   'delhi',
#   'arvind',
#   'kejriw',
#   'say',
#   'cancel',
#   'board',
#   'exam'],
#  ['maharaja', 'busi', 'class', 'coupon'],
#  ['govt',
#   'fast',
#   'track',
#   'emerg',
#   'approv',
#   'covid',
#   'vaccin',
#   'eua',
#   'detail'],
#  ['covid', 'workshop', 'spray', 'better'],
#  ['someon', 'hospit', 'armpit'],
#  ['cholera',
#   'epidem',
#   'broke',
#   'kumbh',
#   'mela',
#   'peopl',
#   'week',
#   'sixth',
#   'cholera',
#   'pandem'],
#  ['antibodi', 'cocktail', 'treat', 'covid', 'studi'],
#  ['world', 'vaccin', 'place'],
#  ['covid', 'wave', 'centr', 'mull', 'cbse', 'board'],
#  ['video', 'mumbai', 'bodi', 'garbag', 'bag', 'patient', 'heart', 'share'],
#  ['cancel', 'board', 'sabhi', 'exam', 'exam', 'covid', 'student'],
#  ['govt', 'vaccin', 'pfizer', 'moderna', 'india', 'compani'],
#  ['vaccin', 'fast', 'nutrit', 'reassur', 'observ'],
#  ['year', 'gran', 'caus', 'gaff', 'someon', 'home', 'polic'],
#  ['peopl',
#   'diseas',
#   'prioriti',
#   'recipi',
#   'covid',
#   'vaccin',
#   'pleas',
#   'doctor',
#   'determin'],
#  ['covid', 'case', 'hour', 'delhi', 'arvind', 'kejriw'],
#  ['resurg', 'indict', 'compuls', 'sacrific', 'fellowmen', 'wast'],
#  ['tablighi', 'spat', 'doc', 'hospit', 'nurs', 'quarantin'],
#  ['care', 'rate', 'watch', 'team', 'time'],
#  ['watch', 'peopl', 'year', 'need'],
#  ['cnbctv',
#   'exclus',
#   'mechan',
#   'trial',
#   'covid',
#   'vaccin',
#   'pfizer',
#   'moderna'],
#  ['commun', 'chest', 'korea', 'year'],
#  ['cancel', 'board', 'sabhi', 'exam', 'exam', 'covid', 'student'],
#  ['mark', 'daatestadi', 'eroju', 'covid', 'rampag', 'rampag', 'vakeelsa'],
#  ['ministri', 'health', 'well', 'vaccin', 'blitz', 'site', 'monday'],
#  ['compani', 'damag', 'covid', 'fortun', 'read', 'arti'],
#  ['cancel', 'board', 'sabhi', 'exam', 'exam', 'covid', 'student'],
#  ['leachon', 'hold', 'astrazeneca', 'covid', 'vaccin', 'individu', 'year'],
#  ['astrazeneca',
#   'covid',
#   'vaccin',
#   'headlin',
#   'report',
#   'blood',
#   'clot',
#   'drug',
#   'safeti'],
#  ['scienc', 'journal', 'trail', 'evid', 'articl', 'amateur'],
#  ['covid', 'rest', 'human'],
#  ['latest', 'forecast', 'economi', 'level', 'estim', 'sept'],
#  ['india', 'covid', 'world', 'festiv', 'ralli', 'concern'],
#  ['cancel', 'board', 'sabhi', 'exam', 'exam', 'covid', 'student'],
#  ['speechless',
#   'make',
#   'mockeri',
#   'scienc',
#   'medicin',
#   'banelectionralliesincovid',
#   'covid',
#   'covid'],
#  ['vaccin', 'tracker', 'updat', 'april', 'dose', 'world', 'rollout'],
#  ['futur', 'star', 'spread'],
#  ['pleas', 'mask', 'peopl', 'shift'],
#  ['bar', 'restaur', 'covid', 'school', 'swalanyeti'],
#  ['cancel', 'board', 'sabhi', 'exam', 'exam', 'covid', 'student'],
#  ['cancel', 'board', 'sabhi', 'exam', 'exam', 'covid', 'student'],
#  ['scientist', 'osun', 'state', 'nigeria', 'test', 'covid'],
#  ['kick', 'covid', 'campaign', 'uccsrckocc'],
#  ['delhi',
#   'request',
#   'centr',
#   'govt',
#   'cancelcbseboardexam',
#   'fear',
#   'centr',
#   'covid',
#   'hot'],
#  ['medicin', 'shortag', 'mileag', 'constitu', 'gujarat', 'chief'],
#  ['precaut', 'dozen', 'covid', 'case', 'metr'],
#  ['day',
#   'case',
#   'elect',
#   'state',
#   'tamil',
#   'nadu',
#   'kerala',
#   'west',
#   'bengal'],
#  ['data', 'day', 'patient', 'health', 'life'],
#  ['covid', 'surg', 'wandsworth', 'lambeth', 'variant', 'case'],
#  ['firm', 'servic', 'compani', 'mombasa', 'nairobi', 'courier', 'servic'],
#  ['queue', 'ambul', 'govt', 'hospit', 'ahmedabad', 'featur'],
#  ['video', 'sreedharan', 'power', 'develop'],
#  ['australia',
#   'news',
#   'naaman',
#   'zhou',
#   'senat',
#   'inquiri',
#   'appear',
#   'cupuw',
#   'quot'],
#  ['cancel',
#   'cbse',
#   'class',
#   'board',
#   'exam',
#   'student',
#   'trend',
#   'cancelboardexam',
#   'twitter',
#   'covid',
#   'case'],
#  ['cancel', 'board', 'sabhi', 'exam', 'exam', 'covid', 'student'],
#  ['ontario', 'school', 'person', 'covid', 'case'],
#  ['coronaviru', 'covid', 'world', 'case', 'insight'],
#  ['cancel', 'board', 'sabhi', 'exam', 'exam', 'covid', 'student'],
#  ['test', 'checkup', 'lunch', 'time', 'team', 'test', 'careless'],
#  ['remark',
#   'congress',
#   'presid',
#   'sonia',
#   'gandhi',
#   'meet',
#   'congress',
#   'state',
#   'congress',
#   'minist',
#   'allianc'],
#  ['emerg',
#   'friend',
#   'bhopal',
#   'hospitalis',
#   'covid',
#   'mother',
#   'hospit',
#   'citi'],
#  ['cancel', 'board', 'sabhi', 'exam', 'exam', 'covid', 'student'],
#  ['cancel', 'board', 'sabhi', 'exam', 'exam', 'covid', 'student'],
#  ['avail', 'albertson', 'safeway', 'arapaho', 'road', 'centenni', 'access'],
#  ['must', 'sail', 'yacht'],
#  ['plan', 'wear', 'vaccin'],
#  ['violenc', 'riot', 'murder', 'covid', 'russia', 'china', 'iran'],
#  ['opposit', 'danger', 'covid', 'inflat', 'pleas', 'pakistan'],
#  ['day', 'covid'],
#  ['tran', 'songkran', 'home', 'hope', 'covid', 'planrathavit'],
#  ['wait', 'subsid', 'disast', 'brexit', 'mind'],
#  ['doctor', 'duti', 'night', 'travel'],
#  ['cbse', 'decis', 'boardexam', 'covid', 'case', 'factor', 'preced', 'exist'],
#  ['dessis', 'maharashtra', 'dessis', 'postpon', 'cbse', 'exam'],
#  ['part', 'mccd', 'covid'],
#  ['scotland', 'develop', 'fund'],
#  ['centr', 'place', 'regist'],
#  ['coronaviru', 'factsvsmyth', 'manag', 'covid', 'patient', 'emerg'],
#  ['covid', 'event', 'guy', 'appeal'],
#  ['britain', 'immun', 'infect', 'covid', 'peak', 'drop'],
#  ['darpa', 'covid', 'microchip', 'claim', 'surveil', 'purpos', 'oann'],
#  ['news', 'link', 'book'],
#  ['friend',
#   'emerg',
#   'requir',
#   'blood',
#   'covid',
#   'place',
#   'trust',
#   'hyderabad',
#   'pleas'],
#  ['pleas', 'mask', 'peopl', 'shift'],
#  ['florida', 'report', 'covid', 'death', 'time', 'month'],
#  ['channel', 'markaz'],
#  ['thi', 'covid', 'case', 'delhi', 'hour', 'delhi', 'veri'],
#  ['peopl', 'heart', 'washington', 'new', 'post'],
#  ['welcom', 'covid', 'event', 'banelectionralliesincovid', 'alert', 'covid'],
#  ['futur', 'star', 'spread'],
#  ['cancel', 'board', 'sabhi', 'exam', 'exam', 'covid', 'student'],
#  ['convers', 'villag', 'covid', 'india', 'hindu', 'obey', 'rule', 'home'],
#  ['form', 'entertain', 'tuesday', 'morn', 'covid', 'unit', 'monitor'],
#  ['cancel', 'board', 'sabhi', 'exam', 'exam', 'covid', 'student'],
#  ['india', 'beat', 'brazil', 'world', 'countri', 'covid'],
#  ['india', 'track', 'emerg', 'approv', 'covid', 'vaccin'],
#  ['month', 'sinc', 'covid', 'popul'],
#  ['delhi',
#   'request',
#   'centr',
#   'govt',
#   'cancelcbseboardexam',
#   'fear',
#   'centr',
#   'covid',
#   'hot'],
#  ['household', 'busi', 'covid', 'loan'],
#  ['failur', 'trudeau', 'govern', 'canadian', 'jake', 'tapper'],
#  ['parent', 'kid', 'marco', 'alissa', 'piro', 'student', 'zoom', 'parent'],
#  ['problem', 'covid', 'chaat', 'masala'],
#  [],
#  ['support', 'cancel', 'cbse', 'board', 'case'],
#  [],
#  ['germani',
#   'ghana',
#   'feasibl',
#   'studi',
#   'vaccin',
#   'product',
#   'ghana',
#   'lead',
#   'pharm'],
#  ['break', 'countri', 'talli', 'covid', 'infect', 'case'],
#  ['video', 'sreedharan', 'power', 'develop'],
#  ['vakeelsaab', 'master', 'audienc', 'south', 'star'],
#  ['vaccin', 'bed', 'hospit', 'plan'],
#  ['covid', 'driven', 'advanc', 'intellig', 'risk', 'inequ'],
#  ['cooper', 'everyth', 'everi', 'person', 'lockdo'],
#  ['ordeal', 'post', 'mortem', 'death', 'peopl'],
#  ['figur', 'skater', 'practic', 'session', 'osaka', 'rink', 'skater', 'nece'],
#  ['cancelboardexam'],
#  ['vaccin', 'tracker', 'updat', 'april', 'dose', 'world', 'rollout'],
#  ['inadequ',
#   'report',
#   'covid',
#   'studi',
#   'sex',
#   'gender',
#   'equiti',
#   'research',
#   'sager'],
#  ['tata',
#   'motor',
#   'break',
#   'jaguar',
#   'land',
#   'rover',
#   'retail',
#   'sale',
#   'fiscal',
#   'continu',
#   'recoveri',
#   'from',
#   'covid',
#   'impa'],
#  ['maharashtra', 'board', 'cancelboardexam', 'cancelboardexam'],
#  ['novemb', 'lane', 'covid', 'contract', 'trust', 'govt'],
#  ['resurg', 'indict', 'compuls', 'sacrific', 'fellowmen', 'wast'],
#  ['cancel', 'board', 'sabhi', 'exam', 'exam', 'covid', 'student'],
#  ['percent', 'peopl', 'covid', 'bracket'],
#  ['moham', 'salah', 'liverpool', 'match', 'club', 'absenc', 'covid'],
#  ['today',
#   'guidanc',
#   'danish',
#   'hirpara',
#   'ordin',
#   'garbada',
#   'school',
#   'teacher'],
#  ['delhi',
#   'request',
#   'centr',
#   'govt',
#   'cancelcbseboardexam',
#   'fear',
#   'centr',
#   'covid',
#   'hot'],
#  ['cancel', 'board', 'sabhi', 'exam', 'exam', 'covid', 'student'],
#  ['think'],
#  ['that',
#   'silli',
#   'smile',
#   'when',
#   'ask',
#   'where',
#   'took',
#   'covid',
#   'money',
#   'didrutokillkenei'],
#  [],
#  ['citi', 'covid', 'futur'],
#  ['paragraph', 'polici', 'failur', 'covid', 'book'],
#  ['support', 'student', 'cbse', 'board', 'delhi', 'student'],
#  ['export', 'recoveri', 'februari', 'month', 'year', 'late'],
#  ['assam', 'case', 'posit', 'maharashtra', 'test', 'case', 'posit', 'mahar'],
#  ['everyon', 'wandsworth', 'lambeth', 'covid', 'test', 'case'],
#  ['songkran', 'year', 'covid', 'meanphiravich', 'meantro'],
#  ['cancel', 'board', 'sabhi', 'exam', 'exam', 'covid', 'student'],
#  ['request', 'centr', 'cancel', 'cbse', 'exam', 'delhi'],
#  ['media', 'israel', 'covid', 'recoveri', 'palestinian', 'yara'],
#  ['pleas', 'mask', 'peopl', 'shift'],
#  ['firm', 'servic', 'compani', 'mombasa', 'nairobi', 'courier', 'servic'],
#  ['view', 'covid', 'protocol', 'today', 'mahakumbh', 'watch', 'video', 'dog'],
#  ['time', 'conspiraci', 'theorist'],
#  ['close', 'land', 'right', 'defend', 'lawyer', 'pap', 'secur', 'forc'],
#  ['feel', 'covid', 'time', 'meme', 'covidmem', 'covid'],
#  ['year', 'look', 'minimi'],
#  ['bracket', 'covid', 'jab', 'peopl', 'book', 'mine'],
#  ['delhi',
#   'request',
#   'centr',
#   'govt',
#   'cancelcbseboardexam',
#   'fear',
#   'centr',
#   'covid',
#   'hot'],
#  ['mistak', 'covid', 'clubhous', 'room', 'shit', 'rampant'],
#  ['friend',
#   'emerg',
#   'requir',
#   'blood',
#   'covid',
#   'place',
#   'trust',
#   'hyderabad',
#   'pleas'],
#  ['cancel', 'board', 'sabhi', 'exam', 'exam', 'covid', 'student'],
#  ['covid', 'life', 'time', 'ala', 'number'],
#  ['uddhav',
#   'balasaheb',
#   'thackeray',
#   'meet',
#   'state',
#   'task',
#   'forc',
#   'avail',
#   'oxygen',
#   'bed'],
#  ['invit',
#   'state',
#   'crime',
#   'journal',
#   'special',
#   'issu',
#   'panel',
#   'covid',
#   'pandem',
#   'state',
#   'crime'],
#  ['pedati',
#   'iowa',
#   'state',
#   'director',
#   'school',
#   'district',
#   'mask',
#   'requir',
#   'student'],
#  [],
#  ['willl', 'chang'],
#  ['pill', 'someth', 'danger'],
#  ['achiev'],
#  ['govern', 'inquiri', 'covid', 'corrupt', 'death', 'toll'],
#  ['folk', 'akufo', 'addo', 'twitter', 'death'],
#  ['hello',
#   'abdullah',
#   'raiss',
#   'consolid',
#   'list',
#   'resourc',
#   'match',
#   'covid'],
#  ['priyanka', 'posit'],
#  ['benefit',
#   'integr',
#   'cooper',
#   'outweigh',
#   'cost',
#   'trade',
#   'uganda',
#   'kenya'],
#  ['agre', 'someon', 'mom', 'death', 'expens', 'covid', 'hardship'],
#  ['covid', 'infect', 'filipino', 'case'],
#  ['today', 'india', 'covid', 'case', 'govern', 'decis', 'cancelboa'],
#  ['citi', 'covid', 'futur'],
#  ['clinic', 'colleagu', 'counti'],
#  ['israel', 'border', 'covid', 'polici', 'aust'],
#  ['thank', 'risk', 'covid'],
#  ['covid',
#   'diagnost',
#   'exam',
#   'back',
#   'artifici',
#   'intellig',
#   'roll',
#   'season',
#   'busi',
#   'wire',
#   'read'],
#  ['today', 'cum', 'visit', 'barnard', 'castl', 'death', 'sub'],
#  ['subsid', 'climat', 'scaremong', 'alrea'],
#  ['england', 'book', 'vaccin'],
#  ['alhamdulillah', 'day', 'covid', 'thank'],
#  [],
#  ['covid', 'shot'],
#  ['come', 'thing'],
#  ['cancel', 'board', 'sabhi', 'exam', 'exam', 'covid', 'student'],
#  ['cancel', 'board', 'sabhi', 'exam', 'exam', 'covid', 'student'],
#  ['disunit', 'johnson'],
#  ['coronaviru', 'fragment', 'ringwood', 'area', 'pleas', 'symptom'],
#  ['covid', 'ontario', 'world'],
#  ['break', 'report', 'covid', 'case', 'filipino', 'year'],
#  ['young', 'doctor', 'covid', 'vaccin', 'full', 'video'],
#  ['ramadanmubarak', 'month', 'woe', 'covid', 'pray'],
#  ['friend',
#   'emerg',
#   'requir',
#   'blood',
#   'covid',
#   'place',
#   'trust',
#   'hyderabad',
#   'pleas'],
#  ['great', 'wave', 'covid'],
#  ['friend',
#   'emerg',
#   'requir',
#   'blood',
#   'covid',
#   'place',
#   'trust',
#   'hyderabad',
#   'pleas'],
#  ['delhi',
#   'request',
#   'centr',
#   'govt',
#   'cancelcbseboardexam',
#   'fear',
#   'centr',
#   'covid',
#   'hot'],
#  ['covid'],
#  ['court', 'covid', 'mad'],
#  ['thank', 'cancelcbseboardexam'],
#  ['visual',
#   'bhim',
#   'ambedkar',
#   'memori',
#   'hospit',
#   'raipur',
#   'chhattisgarh',
#   'covid',
#   'case'],
#  ['peopl', 'book', 'covid', 'websit'],
#  ['right', 'event', 'test'],
#  ['cancel', 'board', 'sabhi', 'exam', 'exam', 'covid', 'student'],
#  ['india',
#   'fast',
#   'track',
#   'emerg',
#   'approv',
#   'covid',
#   'vaccin',
#   'india',
#   'new'],
#  ['mening', 'fluid', 'leak', 'covid', 'pubm'],
#  ['year', 'parent', 'teacher', 'risk', 'infect', 'kid', 'attitud'],
#  ['futur', 'star', 'spread'],
#  ['posit', 'covid', 'test', 'fear', 'clay', 'plot', 'twist'],
#  ['friend',
#   'emerg',
#   'requir',
#   'blood',
#   'covid',
#   'place',
#   'trust',
#   'hyderabad',
#   'pleas'],
#  ['death', 'count', 'covid', 'peopl', 'week'],
#  ['time', 'guy', 'stage', 'bloke', 'stand', 'town'],
#  ['india', 'second', 'covid', 'let', 'hope', 'fund', 'name', 'pmcare'],
#  ['uganda', 'measur', 'spread', 'covid', 'secur', 'agenc', 'multin'],
#  ['covid',
#   'patient',
#   'patient',
#   'hour',
#   'lack',
#   'oxygen',
#   'suppli',
#   'nalasopara'],
#  ['delhi', 'student', 'cbse', 'board', 'delhi', 'student', 'teacher'],
#  ['christin',
#   'holgat',
#   'execut',
#   'prime',
#   'minist',
#   'scott',
#   'morrison',
#   'bullypm'],
#  ['member',
#   'staff',
#   'drink',
#   'allerton',
#   'manor',
#   'golf',
#   'cours',
#   'seater',
#   'beer',
#   'garden'],
#  ['head', 'spring', 'step'],
#  ['case', 'anyon', 'hotlin', 'photo', 'hospit', 'provinc'],
#  ['victori', 'corona', 'seeker'],
#  ['reason', 'policymak', 'washington', 'upset', 'china', 'covid'],
#  ['cancel', 'board', 'sabhi', 'exam', 'exam', 'covid', 'student'],
#  ['cancel', 'board', 'sabhi', 'exam', 'exam', 'covid', 'student'],
#  ['citi', 'covid', 'futur'],
#  ['fashion',
#   'media',
#   'student',
#   'christi',
#   'blog',
#   'post',
#   'fashion',
#   'documentari',
#   'cost'],
#  ['vaccin',
#   'shouldn',
#   'anyon',
#   'complac',
#   'shock',
#   'case',
#   'twitter',
#   'friend',
#   'vaccin'],
#  ['govern', 'justifi', 'hospit', 'whetherspoon'],
#  ['covid',
#   'onlin',
#   'coronaviru',
#   'vaccin',
#   'monitor',
#   'studi',
#   'particip',
#   'email'],
#  ['friend',
#   'emerg',
#   'requir',
#   'blood',
#   'covid',
#   'place',
#   'trust',
#   'hyderabad',
#   'pleas'],
#  ['case', 'covid', 'mother'],
#  ['covid',
#   'will',
#   'stop',
#   'from',
#   'celebr',
#   'wheein',
#   'solo',
#   'wheein',
#   'mini',
#   'album',
#   'redd',
#   'wheein',
#   'water',
#   'color',
#   'wheein'],
#  ['incom', 'economi', 'access', 'covid', 'vaccin', 'intern', 'monetari'],
#  ['share', 'remov', 'sustain', 'index', 'myanmar', 'milit'],
#  ['covid', 'announc', 'maharashtra', 'hour'],
#  ['april',
#   'personnel',
#   'burgo',
#   'arirang',
#   'brgi',
#   'cadacad',
#   'town',
#   'crime',
#   'prevent',
#   'muncip'],
#  ['wave', 'covid', 'cbse', 'board', 'student'],
#  ['covid', 'countri', 'world'],
#  ['full',
#   'mark',
#   'hindu',
#   'machineri',
#   'covid',
#   'mess',
#   'maharashtra',
#   'kerala'],
#  ['remind', 'killer', 'larg', 'joseph', 'scott', 'pemberton'],
#  ['day', 'ravi', 'shankar', 'prasad', 'rahul', 'gandhi', 'vaccin'],
#  ['middaynew', 'centr', 'approv', 'covid', 'vaccin', 'countri'],
#  ['increas', 'vaccin', 'covid', 'economi', 'didi'],
#  ['germani',
#   'ghana',
#   'feasibl',
#   'studi',
#   'vaccin',
#   'product',
#   'ghana',
#   'lead',
#   'pharm'],
#  ['fact', 'congreg', 'state', 'govern', 'scare'],
#  ['cancel', 'board', 'sabhi', 'exam', 'exam', 'covid', 'student'],
#  ['delhi',
#   'request',
#   'centr',
#   'govt',
#   'cancelcbseboardexam',
#   'fear',
#   'centr',
#   'covid',
#   'hot'],
#  ['show', 'peopl', 'clue', 'covid', 'jeremyvin'],
#  ['pleas', 'mask', 'peopl', 'shift'],
#  ['april', 'number', 'covid', 'case', 'number', 'death'],
#  ['thank', 'bhai', 'love'],
#  ['board', 'idea', 'carrier', 'student', 'conduct', 'covid', 'norm'],
#  ['maharashtra', 'politician', 'covid', 'case', 'assam'],
#  ['mumbaikar', 'shot', 'covid', 'vaccin', 'pune', 'hand', 'lakh', 'pune'],
#  ['scamdem', 'confus', 'hundr', 'test', 'posit', 'covid', 'be', 'fulli'],
#  ['fein', 'come'],
#  ['video', 'sreedharan', 'power', 'develop'],
#  ['fuck', 'nphet', 'time', 'doom', 'gloom', 'peopl', 'covid'],
#  ['wave', 'covid', 'cbse', 'board', 'student'],
#  ['violenc', 'riot', 'murder', 'covid', 'russia', 'china', 'iran'],
#  ['racist', 'broadcast', 'liar', 'shame', 'nhk', 'nhk', 'racist'],
#  ['book', 'covid', 'vaccin'],
#  ['cancelboardexam', 'protocol', 'dispers', 'exam'],
#  ['case', 'maharashtra'],
#  ['delhi',
#   'request',
#   'centr',
#   'govt',
#   'cancelcbseboardexam',
#   'fear',
#   'centr',
#   'covid',
#   'hot'],
#  ['cancel', 'board', 'sabhi', 'exam', 'exam', 'covid', 'student'],
#  ['learn', 'covid', 'transform', 'organ'],
#  ['detail', 'covid', 'fund', 'india'],
#  ['vaccin', 'aatmanirbharbharat', 'approv', 'vaccin'],
#  ['peopl', 'book', 'covid', 'vaccin'],
#  ['year', 'gran', 'caus', 'gaff', 'someon', 'home', 'polic'],
#  ['covid',
#   'wast',
#   'archaeolog',
#   'help',
#   'shape',
#   'polici',
#   'paper',
#   'open',
#   'access'],
#  ['bihar', 'mla', 'covid', 'norm'],
#  ['peopl', 'treatment', 'england'],
#  ['centr', 'place', 'regist'],
#  ['friend',
#   'emerg',
#   'requir',
#   'blood',
#   'covid',
#   'place',
#   'trust',
#   'hyderabad',
#   'pleas'],
#  ['third', 'employe', 'covid', 'purpos'],
#  ['pandem', 'anyon', 'hand', 'covid', 'point'],
#  ['mening', 'fluid', 'leak', 'covid', 'pubm'],
#  ['friend',
#   'emerg',
#   'requir',
#   'blood',
#   'covid',
#   'place',
#   'trust',
#   'hyderabad',
#   'pleas'],
#  [],
#  ['ramadan', 'gaza', 'famili', 'condit', 'today', 'covid'],
#  ['futur', 'star', 'spread'],
#  ['cancel', 'board', 'sabhi', 'exam', 'exam', 'covid', 'student'],
#  ['who', 'covid', 'warrior'],
#  ['land',
#   'right',
#   'defend',
#   'lawyer',
#   'pap',
#   'pap',
#   'leader',
#   'secur',
#   'forc'],
#  ['delhi', 'decis', 'cancel', 'cbse', 'exam', 'speed', 'student', 'health'],
#  ['thank', 'decis', 'safeti', 'student', 'pictur', 'exam', 'pattern'],
#  ['cancel', 'board', 'sabhi', 'exam', 'exam', 'covid', 'student'],
#  ['tip', 'covid', 'infect', 'indoor', 'sunlight'],
#  ['friend',
#   'emerg',
#   'requir',
#   'blood',
#   'covid',
#   'place',
#   'trust',
#   'hyderabad',
#   'pleas'],
#  ['husband', 'colleagu', 'gentleman', 'month', 'group'],
#  ['coronaviru', 'young', 'peopl', 'area', 'membership', 'covid', 'medic'],
#  ['covid',
#   'death',
#   'children',
#   'poverti',
#   'homeless',
#   'increas',
#   'food',
#   'bank',
#   'usag'],
#  ['hear', 'roller', 'coaster', 'theme', 'park', 'england', 'wale', 'scream'],
#  ['postponeneetpg', 'cbse', 'mppsc', 'exam', 'candid'],
#  ['assam', 'case', 'posit', 'maharashtra', 'test', 'case', 'posit', 'mahar'],
#  ['thank', 'thousand', 'covid', 'summit', 'thank', 'prof'],
#  ['countri', 'coron', 'inquest', 'covid', 'death', 'home'],
#  ['spread', 'news', 'devote', 'citi'],
#  ['insur',
#   'kenya',
#   'record',
#   'underwrit',
#   'profit',
#   'year',
#   'healthcar',
#   'claim',
#   'hosp'],
#  ['cancel', 'board', 'sabhi', 'exam', 'exam', 'covid', 'student'],
#  ['patient', 'covid', 'delhi', 'year', 'countri'],
#  ['cancel', 'board', 'sabhi', 'exam', 'exam', 'covid', 'student'],
#  ['pleas', 'mask', 'peopl', 'shift'],
#  ['women', 'covid', 'vaccin', 'diseas'],
#  ['mening', 'fluid', 'leak', 'covid', 'pubm'],
#  ['day', 'ravi', 'shankar', 'prasad', 'rahul', 'gandhi', 'vaccin'],
#  ['cancel', 'board', 'sabhi', 'exam', 'exam', 'covid', 'student'],
#  ['ray', 'offer', 'tool', 'covid', 'artificialintellig', 'datasci', 'day'],
#  ['pleas', 'mask', 'peopl', 'shift'],
#  ['record', 'india', 'covid', 'case', 'bitcoin', 'let'],
#  ['pleas', 'suggest', 'covid', 'famili'],
#  ['aren', 'bracket', 'covid'],
#  ['rememb',
#   'yesjulz',
#   'patient',
#   'zero',
#   'covid',
#   'florida',
#   'airport',
#   'doctor',
#   'lmao'],
#  ['friend',
#   'emerg',
#   'requir',
#   'blood',
#   'covid',
#   'place',
#   'trust',
#   'hyderabad',
#   'pleas'],
#  ['friend',
#   'emerg',
#   'requir',
#   'blood',
#   'covid',
#   'place',
#   'trust',
#   'hyderabad',
#   'pleas'],
#  ['earth', 'vaccin', 'scientist', 'china', 'chinaliedandpeopl'],
#  ['peopl', 'world', 'scientist', 'thing', 'covid', 'sceptic', 'realist'],
#  ['friend', 'famili', 'covid', 'appropri', 'behaviour', 'break', 'transmiss'],
#  ['thank', 'support', 'voic', 'authori'],
#  ['mean', 'chanc', 'antibodi', 'mean'],
#  ['homeless', 'covid', 'evict', 'avalanch', 'june', 'peopl', 'victoria'],
#  ['speaker', 'cooper', 'legislatur', 'restrict', 'letter'],
#  ['scam', 'advis', 'covid', 'reduct', 'council', 'council', 'refund', 'advi'],
#  ['kumbh', 'covid', 'guard', 'test', 'good', 'modishah', 'yogicm'],
#  ['got',
#   'bambam',
#   'paus',
#   'activ',
#   'staff',
#   'member',
#   'test',
#   'posit',
#   'covid'],
#  ['covid', 'live', 'respons', 'resea'],
#  ['covid', 'mamamoo', 'growth', 'report', 'revenu', 'increas'],
#  ['need', 'guarante', 'school', 'closur'],
#  ['sturgeon',
#   'record',
#   'slowest',
#   'school',
#   'hotel',
#   'bar',
#   'restaur',
#   'health',
#   'club',
#   'slow'],
#  ['covid', 'case', 'hour', 'delhi', 'arvind', 'kejriw'],
#  ['cancel', 'board', 'sabhi', 'exam', 'exam', 'covid', 'student'],
#  ['delhi',
#   'request',
#   'centr',
#   'govt',
#   'cancelcbseboardexam',
#   'fear',
#   'centr',
#   'covid',
#   'hot'],
#  ['wan', 'manufactur', 'plant', 'covid', 'look'],
#  ['govern', 'fast', 'approv', 'covid', 'vaccin', 'emergen'],
#  ['media',
#   'muslim',
#   'tablighi',
#   'jamaat',
#   'covid',
#   'hotspot',
#   'muslim',
#   'super',
#   'spreader',
#   'media'],
#  ['thank', 'support', 'voic', 'authori'],
#  ['day', 'covid'],
#  ['gudipadwa',
#   'wish',
#   'occas',
#   'gudipadwa',
#   'ugadi',
#   'chetichand',
#   'year',
#   'bring'],
#  ['dear', 'covid', 'satur', 'need', 'bed', 'karnataka'],
#  ['songkran', 'year', 'covid', 'meanphiravich', 'meantro'],
#  ['learn', 'covid', 'transform', 'organ', 'sustainabil'],
#  ['cancel', 'board', 'sabhi', 'exam', 'exam', 'covid', 'student'],
#  ['robot', 'covid'],
#  ['cancel', 'board', 'sabhi', 'exam', 'exam', 'covid', 'student'],
#  ['million'],
#  ['covid', 'england', 'offer', 'moderna', 'vaccin', 'roll'],
#  ['thank', 'decis', 'safeti', 'student', 'pictur', 'exam', 'pattern'],
#  ['actor', 'student', 'demand', 'cancelboardexam', 'covid', 'hot'],
#  ['cancel', 'board', 'sabhi', 'exam', 'exam', 'covid', 'student'],
#  ['week', 'after', 'covid', 'vaccin'],
#  ['kumbh', 'covid', 'guard', 'test', 'good', 'modishah', 'yogicm'],
#  ['realiz', 'bioweapon', 'function'],
#  ['cancel', 'board', 'delhi', 'appeal', 'cbse', 'covid', 'case', 'delhi'],
#  ['cancel', 'board', 'sabhi', 'exam', 'exam', 'covid', 'student'],
#  ['thank', 'question'],
#  ['hour',
#   'indian',
#   'express',
#   'area',
#   'railway',
#   'station',
#   'haridwar',
#   'icon'],
#  ['transmiss', 'covid', 'hvac', 'system'],
#  ['england', 'book', 'covid'],
#  ['mentalhealth', 'tsunami', 'hit', 'covid', 'earthquak', 'covid', 'patient'],
#  ['list', 'covid', 'symptom', 'cough', 'fever'],
#  ['cancel', 'board', 'sabhi', 'exam', 'exam', 'covid', 'student'],
#  ['young', 'peopl'],
#  ['delhi', 'centr', 'cancel', 'cbse', 'exam', 'covid', 'patient', 'year'],
#  ['thank', 'decis', 'safeti', 'student', 'pictur', 'exam', 'pattern'],
#  ['covid', 'surg', 'london', 'south', 'african', 'variant', 'case', 'project'],
#  ['postpon', 'show', 'govt', 'board', 'covid', 'case', 'infra'],
#  ['movi', 'theatr', 'covid', 'fear', 'comment'],
#  ['umrah', 'umrah', 'covid', 'umrah', 'world', 'photo', 'credit', 'raheel'],
#  ['govern', 'link', 'vaccin', 'advers', 'effect', 'data', 'buri', 'page'],
#  ['covid', 'vaccin', 'exampl', 'effect', 'wave'],
#  ['cancelboardexam', 'protocol', 'dispers', 'exam'],
#  ['site', 'streatham', 'covid', 'test', 'collect', 'home', 'test', 'appoint'],
#  ['point', 'risk', 'covid'],
#  ['activist',
#   'actor',
#   'vira',
#   'sathidar',
#   'nation',
#   'award',
#   'film',
#   'court',
#   'tuesday'],
#  ['stupid', 'rise', 'covid', 'infect', 'johnson', 'announc', 'anoth'],
#  ['week', 'tweet'],
#  ['cancel', 'board', 'sabhi', 'exam', 'exam', 'covid', 'student'],
#  ['case', 'anyon', 'hotlin', 'photo', 'hospit', 'provinc'],
#  ['week', 'tweet'],
#  ['peopl', 'life', 'world'],
#  ['peopl', 'mask', 'work', 'shift'],
#  ['spreader', 'shahi', 'snan', 'event', 'particip', 'light', 'covi'],
#  ['covid', 'casualti', 'know', 'govern'],
#  ['citi', 'covid', 'futur'],
#  ['rule', 'sens', 'mckeith', 'rule'],
#  ['scotland', 'caution', 'damag', 'citizen', 'lockdown', 'panacea'],
#  ['need', 'europ', 'franc', 'netherland', 'work'],
#  [],
#  ['news',
#   'number',
#   'casualti',
#   'covid',
#   'septemb',
#   'huge',
#   'thank',
#   'scientist',
#   'armi'],
#  ['opposit', 'danger', 'covid', 'inflat', 'pleas', 'pakistan'],
#  ['pfizer',
#   'say',
#   'experiment',
#   'mrna',
#   'vaccin',
#   'could',
#   'massiv',
#   'scale',
#   'depopul'],
#  ['delhi',
#   'request',
#   'centr',
#   'govt',
#   'cancelcbseboardexam',
#   'fear',
#   'centr',
#   'covid',
#   'hot'],
#  ['project', 'profit', 'organis', 'govern', 'pork', 'barrel', 'polit'],
#  ['cancel', 'board', 'sabhi', 'exam', 'exam', 'covid', 'student'],
#  ['ironi', 'covid', 'spread', 'pass', 'viru'],
#  ['investig', 'countri', 'amount', 'peopl', 'reaction'],
#  ['blood', 'clot', 'covid', 'risk'],
#  ['today',
#   'countri',
#   'daili',
#   'covid',
#   'epidem',
#   'forecast',
#   'vaccin',
#   'figur'],
#  ['dear', 'covid', 'satur', 'need', 'bed', 'karnataka'],
#  ['peopl', 'doubl', 'figur', 'number'],
#  ['thank', 'cancelboardexam'],
#  ['aspen',
#   'institut',
#   'utah',
#   'state',
#   'univers',
#   'youth',
#   'incom',
#   'home',
#   'sport'],
#  ['covid', 'crisi', 'focu'],
#  ['delhi', 'centr', 'cancel', 'cbse', 'exam', 'covid', 'patient', 'year'],
#  ['merck', 'govern', 'merck', 'covid', 'drug'],
#  ['part', 'show', 'covid', 'doin'],
#  ['institut', 'measur', 'covid'],
#  ['day', 'type', 'recoveri', 'covid', 'recess', 'popul'],
#  ['germani',
#   'ghana',
#   'feasibl',
#   'studi',
#   'vaccin',
#   'product',
#   'ghana',
#   'lead',
#   'pharm'],
#  ['death', 'pakistan', 'record', 'number', 'covid', 'death', 'year'],
#  ['friend',
#   'emerg',
#   'requir',
#   'blood',
#   'covid',
#   'place',
#   'trust',
#   'hyderabad',
#   'pleas'],
#  ['scientist', 'osun', 'state', 'nigeria', 'test', 'covid'],
#  ['peopl', 'peopl', 'down', 'syndrom', 'covid', 'vaccin'],
#  ['health', 'care', 'envi', 'world', 'jake', 'tapper', 'failur', 'trudeau'],
#  ['increas', 'vaccin', 'covid', 'economi', 'didi'],
#  ['europ', 'materi', 'covid', 'vaccin', 'product', 'adar', 'poonawalla'],
#  ['food', 'import', 'bill', 'food', 'home'],
#  ['data',
#   'technolog',
#   'expert',
#   'bart',
#   'peeter',
#   'michiel',
#   'keyzer',
#   'solid',
#   'technolog'],
#  ['search',
#   'plasmadonor',
#   'vizag',
#   'covid',
#   'patient',
#   'recent',
#   'covid',
#   'evarina'],
#  ['death', 'pakistan', 'record', 'number', 'covid', 'death', 'year'],
#  ['fear'],
#  ['hour', 'result', 'genos', 'test', 'research', 'covid', 'machi'],
#  ['action',
#   'mask',
#   'covid',
#   'assam',
#   'state',
#   'health',
#   'reaction',
#   'assam',
#   'record',
#   'increas'],
#  ['cancel', 'board', 'sabhi', 'exam', 'exam', 'covid', 'student'],
#  ['maharashtra',
#   'mumbai',
#   'metropolitan',
#   'region',
#   'redempt',
#   'everi',
#   'hospit'],
#  ['vaccin', 'tracker', 'updat', 'april', 'dose', 'world', 'rollout'],
#  ['vaccin', 'tracker', 'updat', 'april', 'dose', 'world', 'rollout'],
#  ['vaccin', 'tracker', 'updat', 'april', 'dose', 'world', 'rollout'],
#  ['covid', 'book', 'england'],
#  ['thistl', 'centr', 'year', 'phone', 'carphon'],
#  ['cancel', 'board', 'sabhi', 'exam', 'exam', 'covid', 'student'],
#  ['india', 'second', 'covid', 'let', 'hope', 'fund', 'name', 'pmcare'],
#  ['cancel', 'board', 'sabhi', 'exam', 'exam', 'covid', 'student'],
#  ['vaccin', 'tracker', 'updat', 'april', 'dose', 'world', 'rollout'],
#  ['vaccin', 'tracker', 'updat', 'april', 'dose', 'world', 'rollout'],
#  ['bank', 'account', 'scammer', 'senior', 'otp', 'second', 'guid'],
#  ['vaccin', 'tracker', 'updat', 'april', 'dose', 'world', 'rollout'],
#  ['covid', 'casualti', 'know', 'govern'],
#  ['newslett', 'spring', 'edit', 'covid', 'respons'],
#  ['vaccin', 'tracker', 'updat', 'april', 'dose', 'world', 'rollout'],
#  ['covid',
#   'pandem',
#   'long',
#   'from',
#   'over',
#   'viru',
#   'variant',
#   'stop',
#   'chief'],
#  ['vaccin', 'tracker', 'updat', 'april', 'dose', 'world', 'rollout'],
#  ['karnan', 'collect', 'releas', 'spike', 'covid', 'case', 'feat'],
#  ['uttarakhand',
#   'just',
#   'doesn',
#   'say',
#   'shouldn',
#   'compar',
#   'kumbh',
#   'markaz',
#   'spot',
#   'analysi'],
#  ['machin', 'model', 'covid', 'studi', 'tech', 'xplore', 'read'],
#  ['thing', 'time', 'video', 'topic'],
#  ['vaccin', 'aatmanirbharbharat', 'approv', 'vaccin'],
#  ['govt', 'emerg', 'approv', 'covid', 'vaccin', 'emerg', 'authorisatio'],
#  ['dear',
#   'amidst',
#   'covid',
#   'number',
#   'case',
#   'scenario',
#   'maharashtra',
#   'legit'],
#  ['cancel', 'board', 'sabhi', 'exam', 'exam', 'covid', 'student'],
#  ['daniil', 'medvedev', 'covid', 'test'],
#  ['data', 'marin', 'declin', 'experiment', 'covid', 'vaccin'],
#  ['citi', 'covid', 'futur'],
#  ['shri',
#   'mahesh',
#   'anghan',
#   'worker',
#   'councillor',
#   'surat',
#   'municip',
#   'corpor'],
#  ['peopl', 'world', 'scientist', 'thing', 'covid', 'sceptic', 'realist'],
#  ['gennova',
#   'addit',
#   'govt',
#   'fund',
#   'india',
#   'first',
#   'covid',
#   'vaccin',
#   'candid'],
#  ['covid',
#   'case',
#   'maharashtra',
#   'state',
#   'govern',
#   'slot',
#   'properti',
#   'registratio'],
#  ['shubh', 'navratri', 'hindu', 'follow', 'sanatan', 'dharma'],
#  ['pfizer', 'moderna'],
#  ['shri',
#   'mahesh',
#   'anghan',
#   'worker',
#   'councillor',
#   'surat',
#   'municip',
#   'corpor'],
#  ['vaccin', 'worst', 'book', 'experi', 'confirm', 'email', 'text'],
#  ['california',
#   'citi',
#   'erect',
#   'fenc',
#   'covid',
#   'mandat',
#   'burbank',
#   'foxnew'],
#  ['visual', 'ambedkar', 'hospit', 'raipur', 'bodi', 'covid', 'patient'],
#  ['cancel', 'board', 'sabhi', 'exam', 'exam', 'covid', 'student'],
#  ['garden', 'yesterday', 'tabl', 'servic', 'fault', 'governmen'],
#  ['everyon', 'maryland', 'covid', 'vaccin', 'druid', 'hill', 'appoint', 'day'],
#  ['rememb', 'covid', 'posit', 'meant', 'control'],
#  ['doctor', 'visit', 'chest', 'pneumon', 'infect', 'approx'],
#  ['modi'],
#  ['resid', 'everyon', 'live', 'work', 'lambeth'],
#  ['look', 'covid', 'debat', 'women', 'access', 'mosqu', 'peopl'],
#  ['india', 'covid', 'world', 'festiv', 'ralli', 'concern'],
#  ['cancel', 'board', 'sabhi', 'exam', 'exam', 'covid', 'student'],
#  ['everyon', 'rapid', 'covid', 'test', 'result', 'minut'],
#  ['alissa', 'piro', 'student', 'zoom', 'person', 'come'],
#  ['thailand', 'report', 'covid', 'case', 'songkran', 'holiday', 'begin'],
#  ['actor', 'student', 'demand', 'cancelboardexam', 'covid', 'hot'],
#  ['covid',
#   'women',
#   'leadership',
#   'icraf',
#   'professor',
#   'catherin',
#   'muthuri',
#   'agroforestri',
#   'role'],
#  ['solut', 'child', 'refuge', 'well'],
#  ['year', 'old', 'europ', 'impact', 'covid'],
#  ['imagin', 'tweet'],
#  ['covid', 'case', 'india', 'lakh', 'case', 'thank', 'global', 'lead'],
#  ['report', 'outlin', 'approach', 'backlog', 'covid', 'care', 'action'],
#  ['appl',
#   'googl',
#   'block',
#   'covid',
#   'updat',
#   'privaci',
#   'ground',
#   'track',
#   'trace'],
#  ['peopl',
#   'covid',
#   'kumbh',
#   'lakh',
#   'devote',
#   'haridwar',
#   'monday',
#   'screeni'],
#  ['germani',
#   'ghana',
#   'produc',
#   'covid',
#   'vaccin',
#   'nigeria',
#   'vaccin',
#   'europ'],
#  ['anyon', 'live', 'borough', 'book', 'covid'],
#  ['delhi',
#   'request',
#   'centr',
#   'govt',
#   'cancelcbseboardexam',
#   'fear',
#   'centr',
#   'covid',
#   'hot'],
#  ['cancel', 'board', 'sabhi', 'exam', 'exam', 'covid', 'student'],
#  ['request', 'centr', 'cancel', 'cbse', 'exam', 'delhi'],
#  ['friend',
#   'emerg',
#   'requir',
#   'blood',
#   'covid',
#   'place',
#   'trust',
#   'hyderabad',
#   'pleas'],
#  ['covid', 'relationship', 'start', 'haunt'],
#  ['friend',
#   'emerg',
#   'requir',
#   'blood',
#   'covid',
#   'place',
#   'trust',
#   'hyderabad',
#   'pleas'],
#  ['india', 'second', 'covid', 'let', 'hope', 'fund', 'name', 'pmcare'],
#  ['list', 'covid', 'symptom', 'cough', 'fever'],
#  ['opposit', 'leader', 'pleas', 'onlin', 'petit'],
#  [],
#  ['germani',
#   'ghana',
#   'feasibl',
#   'studi',
#   'vaccin',
#   'product',
#   'ghana',
#   'lead',
#   'pharm'],
#  ['delhi',
#   'high',
#   'court',
#   'hazrat',
#   'nizamuddin',
#   'markaz',
#   'covid',
#   'case',
#   'delhit',
#   'extr'],
#  ['everyon', 'covid', 'case', 'hell', 'govt', 'aren'],
#  ['deliveri', 'day', 'covid', 'project', 'partnership', 'wednesday', 'friday'],
#  ['intellig', 'covid', 'read', 'arti'],
#  ['exam', 'covid', 'health', 'children', 'import', 'cancel'],
#  ['peopl', 'book', 'covid', 'vaccin'],
#  ['pleas', 'exam', 'april', 'thursday', 'student', 'issu'],
#  ['covid', 'vaccin'],
#  ['travel', 'train', 'railway', 'covid', 'guidelin', 'newspo'],
#  [],
#  ['backlog', 'licens', 'licens', 'renew', 'covid', 'impl'],
#  ['delhi',
#   'arvind',
#   'kejriw',
#   'delhi',
#   'govern',
#   'appeal',
#   'cbse',
#   'board',
#   'assessm'],
#  ['cancel', 'board', 'sabhi', 'exam', 'exam', 'covid', 'student'],
#  ['pressur', 'someth', 'board', 'ics', 'cbse', 'board', 'postpon'],
#  [],
#  ['covid', 'england', 'moderna', 'rollout', 'covid', 'vaccin', 'vaccin'],
#  ['dawn',
#   'break',
#   'unit',
#   'kingdom',
#   'reflect',
#   'time',
#   'greensil',
#   'cameron',
#   'inquiri',
#   'time',
#   'covid'],
#  ['fuck', 'chines', 'person', 'mamanthan', 'covid'],
#  ['cholera',
#   'epidem',
#   'broke',
#   'kumbh',
#   'mela',
#   'peopl',
#   'week',
#   'sixth',
#   'cholera',
#   'pandem'],
#  ['vakeelsaab', 'master', 'audienc', 'south', 'star'],
#  ['commun', 'chest', 'korea', 'year'],
#  ['govt', 'emerg', 'approv', 'covid', 'vaccin', 'emerg', 'authoris', 'fore'],
#  ['trump', 'chief', 'join', 'fan', 'covid', 'technolog'],
#  ['covid', 'vaccin', 'anyon', 'link'],
#  ['year', 'gran', 'caus', 'gaff', 'someon', 'home', 'polic'],
#  ['death', 'pakistan', 'record', 'number', 'covid', 'death', 'year'],
#  ['mumbai',
#   'fund',
#   'urdu',
#   'bhavan',
#   'enough',
#   'fund',
#   'dispos',
#   'covid',
#   'death',
#   'bodi',
#   'properli',
#   'plastic',
#   'polythen'],
#  ['tran', 'woman', 'keep', 'bill', 'groceri'],
#  ['britain', 'covid', 'vaccin', 'rollout', 'moderna', 'shot', 'england'],
#  ['everybodi', 'includ', 'delay'],
#  ['work', 'morn', 'mascara', 'whilst', 'test', 'life', 'woman', 'covid'],
#  ['blog', 'post', 'tran'],
#  ['vaccin'],
#  ['thank', 'link', 'tag', 'follow', 'version', 'pandem', 'unprecedentedtim'],
#  ['govt',
#   'fast',
#   'track',
#   'emerg',
#   'approv',
#   'covid',
#   'vaccin',
#   'humanitywillwin'],
#  ['risk',
#   'assess',
#   'covid',
#   'patient',
#   'clinicalai',
#   'technolog',
#   'help',
#   'covid',
#   'patient'],
#  ['friend',
#   'emerg',
#   'requir',
#   'blood',
#   'covid',
#   'place',
#   'trust',
#   'hyderabad',
#   'pleas'],
#  [],
#  ['leachon', 'hold', 'astrazeneca', 'covid', 'vaccin', 'individu', 'year'],
#  ['covid',
#   'patient',
#   'lack',
#   'oxygen',
#   'maharashtra',
#   'vasai',
#   'near',
#   'mumbai'],
#  ['year', 'christin', 'holgat', 'covid', 'year', 'scott', 'morrison', 'world'],
#  ['news', 'portal', 'news', 'hospit', 'covid'],
#  [],
#  ['cancel', 'board', 'sabhi', 'exam', 'exam', 'covid', 'student'],
#  ['centr',
#   'fast',
#   'track',
#   'emerg',
#   'approv',
#   'covid',
#   'vaccin',
#   'huge',
#   'step'],
#  ['announc', 'review', 'greensil', 'state', 'state'],
#  ['cancelboardexam', 'covid', 'case', 'india', 'cbse', 'board'],
#  ['guy', 'case', 'covid', 'patient', 'home', 'stat', 'learn'],
#  ['burn', 'colleagu', 'staff', 'nurs', 'covid', 'rotat'],
#  ['nation', 'embarrass', 'govern', 'respons'],
#  ['maharashtra', 'board', 'cancelboardexam', 'cancelboardexam'],
#  ['covid', 'vaccin', 'protect', 'rate'],
#  [],
#  ['covid',
#   'updat',
#   'april',
#   'sourc',
#   'lobo',
#   'municip',
#   'health',
#   'offic',
#   'stay',
#   'loboan'],
#  ['insur',
#   'kenya',
#   'record',
#   'underwrit',
#   'profit',
#   'year',
#   'healthcar',
#   'claim',
#   'hosp'],
#  ['joshua', 'furi', 'even', 'time', 'covid', 'fight'],
#  ['covidvaccin'],
#  ['risk', 'upsid', 'threat', 'lockdown', 'resurg'],
#  ['india', 'second', 'covid', 'let', 'hope', 'fund', 'name', 'pmcare'],
#  ['young', 'peopl'],
#  ['first', 'isol', 'center', 'yuva', 'sanskruti', 'trust', 'bed', 'capac'],
#  ['rehash',
#   'demand',
#   'yesterday',
#   'scotland',
#   'hospit',
#   'sector',
#   'covid',
#   'restrict'],
#  ['hope', 'felt', 'okay'],
#  ['health', 'human', 'fair', 'access', 'vaccin'],
#  ['health',
#   'prioriti',
#   'given',
#   'natur',
#   'spread',
#   'covid',
#   'mva',
#   'govern',
#   'feel',
#   'board',
#   'exam'],
#  ['month', 'covid'],
#  ['peopl', 'pictur', 'hous', 'london', 'spread'],
#  ['team', 'kumbh', 'point', 'flaw', 'pilgrim'],
#  ['sourc'],
#  ['point', 'covid', 'acquaint', 'vadodara'],
#  ['folk',
#   'today',
#   'crook',
#   'prof',
#   'glen',
#   'hara',
#   'covid',
#   'british',
#   'politi'],
#  ['someth', 'neetpg', 'postponeneetpg'],
#  ['cancel', 'board', 'sabhi', 'exam', 'exam', 'covid', 'student'],
#  ['delhi', 'word', 'school', 'hotspot', 'cancelboardexam'],
#  ['found', 'locat', 'locat', 'availabl', 'sign'],
#  ['doctor', 'covid', 'center'],
#  ['death', 'pakistan', 'record', 'number', 'covid', 'death', 'year'],
#  ['post', 'offic', 'oper', 'govt', 'push', 'privatis'],
#  ['scotland', 'caution', 'england', 'parti', 'covid'],
#  ['friend', 'friend', 'life', 'need', 'help', 'anyon', 'covid'],
#  ['start', 'pfizer', 'oxford', 'astrazeneca'],
#  ['gardai', 'reloc', 'child', 'refuge', 'greec', 'stori'],
#  ['cancel', 'board', 'sabhi', 'exam', 'exam', 'covid', 'student'],
#  ['day', 'test', 'heart', 'attack', 'stroke', 'covid', 'death', 'statisti'],
#  ['cancel', 'board', 'sabhi', 'exam', 'exam', 'covid', 'student'],
#  ['pfizer'],
#  ['covid', 'wait'],
#  ['drdo', 'covid', 'hospit', 'bed', 'facil', 'delhi'],
#  ['peopl', 'book', 'covid', 'vaccin'],
#  ['superb', 'news', 'covidvaccin'],
#  ['pleas', 'help', 'covid', 'help'],
#  ['covid', 'person', 'ramadan', 'muslim', 'valu'],
#  ['covid'],
#  ['cancel', 'board', 'sabhi', 'exam', 'exam', 'covid', 'student'],
#  ['bambam', 'staff', 'member', 'covid', 'statu'],
#  ['come', 'thing'],
#  ['lakh', 'doctor', 'neet', 'mani', 'covid', 'duti'],
#  ['covid',
#   'vaccin',
#   'shot',
#   'midnight',
#   'friday',
#   'dearborn',
#   'help',
#   'observ',
#   'muslim',
#   'shot'],
#  ['grandmoth', 'blood', 'clot', 'groin', 'calf'],
#  ['full',
#   'mark',
#   'hindu',
#   'machineri',
#   'covid',
#   'mess',
#   'maharashtra',
#   'kerala'],
#  ['thank', 'decis', 'safeti', 'student', 'pictur', 'exam', 'pattern'],
#  ['north', 'carolina', 'health', 'expert', 'vaccin', 'goal', 'demand'],
#  ['covid',
#   'report',
#   'mandatori',
#   'april',
#   'peopl',
#   'punjab',
#   'delhi',
#   'maharashtra'],
#  ['anim', 'world', 'mask', 'glove'],
#  ['govern',
#   'should',
#   'relief',
#   'student',
#   'board',
#   'exam',
#   'year',
#   'lakh',
#   'covid',
#   'case'],
#  ['figur', 'skater', 'practic', 'session', 'osaka', 'rink', 'skater', 'nece'],
#  ['year', 'tori', 'auster', 'noth', 'live', 'standard', 'measur', 'suicid'],
#  ['maharashtra',
#   'mumbai',
#   'metropolitan',
#   'region',
#   'redempt',
#   'everi',
#   'hospit'],
#  ['machin', 'diagnosi', 'covid', 'blood', 'test', 'decis', 'tree', 'graph'],
#  ['dear'],
#  ['cancel', 'board', 'sabhi', 'exam', 'exam', 'covid', 'student'],
#  ['cancel', 'board', 'sabhi', 'exam', 'exam', 'covid', 'student'],
#  ['media', 'testimoni', 'danger', 'experiment'],
#  ['covid',
#   'border',
#   'corner',
#   'minnesota',
#   'northwest',
#   'angl',
#   'unabl',
#   'reach'],
#  ['leadership', 'prepar', 'challeng', 'nation', 'duti', 'bharat', 'mata'],
#  ['cancel', 'board', 'sabhi', 'exam', 'exam', 'covid', 'student'],
#  ['covid', 'infect', 'india'],
#  ['cancel', 'board', 'sabhi', 'exam', 'exam', 'covid', 'student'],
#  ['actor', 'student', 'demand', 'cancelboardexam', 'covid', 'hot'],
#  ['articl', 'letter'],
#  ['surpris', 'fraudster', 'shift', 'payment', 'covid', 'pandem'],
#  ['cancel', 'board', 'sabhi', 'exam', 'exam', 'covid', 'student'],
#  ['citi', 'busi', 'democrat', 'noth', 'audac'],
#  ['risk', 'stil'],
#  ['cancel', 'board', 'sabhi', 'exam', 'exam', 'covid', 'student'],
#  ['covid', 'case', 'hour', 'delhi', 'read', 'number', 'mask', 'stay'],
#  ['share', 'remov', 'sustain', 'index', 'myanmar', 'milit'],
#  ['noth', 'test', 'trace', 'test', 'week', 'system', 'pub'],
#  ['memori', 'outrag', 'year', 'part', 'street'],
#  ['class', 'cbse', 'student', 'board', 'middl'],
#  ['whistleblow'],
#  ['tablet', 'manufactur', 'machin', 'thank', 'covid'],
#  ['state'],
#  ['issu', 'vaccin'],
#  ['pleas', 'help', 'covid', 'help'],
#  ['vaccin', 'aatmanirbharbharat', 'approv', 'vaccin'],
#  ['cancel', 'board', 'sabhi', 'exam', 'exam', 'covid', 'student'],
#  ['friend',
#   'emerg',
#   'requir',
#   'blood',
#   'covid',
#   'place',
#   'trust',
#   'hyderabad',
#   'pleas'],
#  ['maha',
#   'kumbh',
#   'mela',
#   'tablighi',
#   'jamaat',
#   'compar',
#   'reason',
#   'rawat',
#   'think'],
#  ['postponeneetpg', 'cbse', 'mppsc', 'exam', 'candid'],
#  ['thier', 'covid', 'report'],
#  ['thank', 'decis', 'safeti', 'student', 'pictur', 'exam', 'pattern'],
#  ['peopl', 'hindu', 'clubhous', 'target', 'kumbh', 'covid', 'without'],
#  ...]

# %%
import numpy as np
doc_count = np.array(mgp.cluster_doc_count)

print('Number_of_documents per topic:', doc_count)
print('*'*20)
# Out:
# Number_of_documents per topic: [328 380 349 347 291 346 338 376 297 230]
# ********************

# %%
doc_count
# Out:
# array([328, 380, 349, 347, 291, 346, 338, 376, 297, 230])

# %%
temp = mgp.cluster_word_distribution

# %%
temp
# Out:
# [{'absolut': 1,
#   'abund': 1,
#   'accent': 1,
#   'access': 1,
#   'achh': 1,
#   'actor': 13,
#   'admit': 1,
#   'agenc': 2,
#   'ahmedabad': 2,
#   'aimim': 1,
#   'almost': 1,
#   'alumnu': 1,
#   'amaz': 1,
#   'ambedkar': 2,
#   'ambul': 3,
#   'analyst': 1,
#   'anti': 1,
#   'anticip': 1,
#   'anyon': 1,
#   'appeal': 3,
#   'archaeolog': 1,
#   'area': 7,
#   'aren': 1,
#   'arrang': 1,
#   'arvindkejriw': 5,
#   'ask': 1,
#   'assess': 1,
#   'asymptomat': 1,
#   'atla': 2,
#   'augment': 1,
#   'auto': 1,
#   'autorikshaw': 1,
#   'bashir': 2,
#   'basketbal': 1,
#   'beach': 1,
#   'becz': 1,
#   'bed': 4,
#   'begin': 1,
#   'behead': 7,
#   'bhai': 1,
#   'bhakdi': 1,
#   'bhim': 1,
#   'bigot': 1,
#   'bloomberg': 1,
#   'board': 3,
#   'boardexam': 4,
#   'bodi': 2,
#   'boost': 1,
#   'brain': 1,
#   'break': 2,
#   'breath': 1,
#   'brecur': 1,
#   'bump': 1,
#   'burn': 1,
#   'busi': 17,
#   'call': 3,
#   'cameron': 1,
#   'canada': 1,
#   'cancel': 12,
#   'cancelboardexam': 20,
#   'cancelcbseboardexam': 35,
#   'caption': 1,
#   'care': 2,
#   'carrier': 1,
#   'carver': 1,
#   'case': 10,
#   'cbse': 14,
#   'cbseboardexam': 1,
#   'cell': 2,
#   'center': 6,
#   'centr': 80,
#   'chairman': 1,
#   'checkpoint': 1,
#   'chennaicorpor': 1,
#   'chhattisgarh': 3,
#   'chief': 6,
#   'child': 2,
#   'children': 3,
#   'chines': 10,
#   'choic': 2,
#   'citi': 33,
#   'citizenship': 1,
#   'clean': 1,
#   'climateemergencyweek': 1,
#   'close': 1,
#   'collabor': 10,
#   'colleg': 5,
#   'compani': 13,
#   'compuls': 5,
#   'concern': 2,
#   'conduct': 2,
#   'confer': 2,
#   'congress': 3,
#   'consequ': 1,
#   'consumer': 1,
#   'convers': 1,
#   'cord': 2,
#   'covid': 129,
#   'covidcar': 1,
#   'curb': 1,
#   'cycl': 1,
#   'danger': 4,
#   'david': 1,
#   'day': 4,
#   'death': 4,
#   'debt': 1,
#   'decis': 35,
#   'defenc': 1,
#   'defend': 4,
#   'delhi': 57,
#   'demand': 13,
#   'depart': 1,
#   'departmen': 1,
#   'depict': 1,
#   'descript': 2,
#   'destroy': 1,
#   'devote': 9,
#   'dharma': 1,
#   'disagr': 6,
#   'distanc': 2,
#   'district': 3,
#   'doctor': 11,
#   'dozen': 1,
#   'drdo': 1,
#   'duti': 2,
#   'eager': 1,
#   'either': 1,
#   'emerg': 2,
#   'emergen': 1,
#   'enterpris': 1,
#   'euroarea': 1,
#   'even': 1,
#   'everest': 1,
#   'everi': 5,
#   'everyo': 1,
#   'everyon': 13,
#   'exam': 27,
#   'examin': 1,
#   'exampl': 1,
#   'exist': 1,
#   'express': 7,
#   'face': 1,
#   'facil': 4,
#   'factor': 1,
#   'famili': 3,
#   'famou': 1,
#   'farmincom': 1,
#   'fauci': 1,
#   'fear': 38,
#   'featur': 1,
#   'feel': 1,
#   'fellowmen': 5,
#   'final': 1,
#   'flight': 1,
#   'follow': 5,
#   'foods': 1,
#   'forc': 4,
#   'forget': 1,
#   'former': 2,
#   'founder': 1,
#   'franc': 2,
#   'friend': 1,
#   'futur': 30,
#   'gang': 1,
#   'ganga': 3,
#   'gangaram': 1,
#   'gardai': 1,
#   'ghat': 1,
#   'golf': 1,
#   'govt': 43,
#   'grante': 3,
#   'grate': 1,
#   'gratitud': 1,
#   'grave': 2,
#   'greec': 1,
#   'greensil': 1,
#   'gudipadwa': 1,
#   'guidelin': 1,
#   'gujarat': 2,
#   'gujrat': 1,
#   'guysss': 1,
#   'half': 1,
#   'hanafi': 1,
#   'happi': 7,
#   'hardwork': 1,
#   'haridwar': 8,
#   'hasn': 3,
#   'heal': 1,
#   'health': 3,
#   'hedon': 1,
#   'hell': 2,
#   'help': 7,
#   'hindu': 2,
#   'hit': 1,
#   'hold': 1,
#   'hope': 3,
#   'hospit': 25,
#   'hot': 47,
#   'hotspot': 1,
#   'hour': 15,
#   'httweet': 1,
#   'husband': 1,
#   'icon': 7,
#   'immun': 2,
#   'india': 34,
#   'indian': 7,
#   'indict': 5,
#   'initi': 1,
#   'inshah': 1,
#   'inspir': 1,
#   'internala': 1,
#   'internalassess': 1,
#   'interview': 1,
#   'issu': 1,
#   'itali': 1,
#   'jaayega': 1,
#   'jab': 3,
#   'jagmeet': 2,
#   'jammu': 1,
#   'just': 1,
#   'kaha': 1,
#   'karachi': 1,
#   'kashmir': 2,
#   'kaushal': 1,
#   'keep': 3,
#   'kisn': 2,
#   'kiwi': 1,
#   'knowl': 1,
#   'kumbh': 1,
#   'lack': 2,
#   'lahor': 1,
#   'lakh': 2,
#   'land': 4,
#   'larg': 1,
#   'lawyer': 4,
#   'leader': 5,
#   'letter': 3,
#   'life': 2,
#   'line': 1,
#   'link': 2,
#   'littl': 1,
#   'lnjp': 1,
#   'loan': 1,
#   'lockdown': 1,
#   'love': 3,
#   'maharashtra': 11,
#   'mani': 1,
#   'march': 1,
#   'market': 8,
#   'marketplac': 1,
#   'mask': 4,
#   'masterstrok': 1,
#   'mathew': 1,
#   'mboril': 1,
#   'measur': 3,
#   'medium': 1,
#   'memori': 2,
#   'metropolitan': 5,
#   'michael': 1,
#   'michigan': 1,
#   'microfin': 1,
#   'middaynew': 1,
#   'migrant': 2,
#   'mike': 1,
#   'minist': 3,
#   'monday': 4,
#   'more': 1,
#   'move': 3,
#   'multin': 1,
#   'mumb': 1,
#   'mumbai': 9,
#   'naga': 1,
#   'nalasopara': 3,
#   'navratri': 7,
#   'near': 1,
#   'need': 1,
#   'neet': 1,
#   'neurofemindia': 1,
#   'news': 9,
#   'newspo': 1,
#   'nifti': 1,
#   'night': 3,
#   'note': 1,
#   'number': 5,
#   'offic': 2,
#   'offici': 4,
#   'onlin': 2,
#   'opd': 1,
#   'open': 1,
#   'opinion': 6,
#   'option': 1,
#   'organis': 1,
#   'outbreak': 1,
#   'outrag': 1,
#   'owaisi': 1,
#   'oxygen': 6,
#   'pain': 2,
#   'pakistan': 2,
#   'pandem': 2,
#   'pap': 7,
#   'paper': 2,
#   'part': 3,
#   'patient': 16,
#   'pattern': 19,
#   'pauri': 1,
#   'peac': 2,
#   'peopl': 3,
#   'pfizer': 1,
#   'pictur': 20,
#   'pill': 1,
#   'place': 3,
#   'playbook': 1,
#   'player': 1,
#   'polici': 1,
#   'portal': 1,
#   'post': 2,
#   'poster': 1,
#   'preced': 1,
#   'premier': 1,
#   'press': 1,
#   'preval': 1,
#   'prof': 1,
#   'progress': 1,
#   'proud': 1,
#   'publicdebt': 1,
#   'queue': 2,
#   'railway': 10,
#   'raipur': 2,
#   'ramadanmubarak': 1,
#   'rana': 1,
#   'reach': 1,
#   'read': 2,
#   'rece': 1,
#   'recei': 2,
#   'receiv': 1,
#   'reconsid': 1,
#   'redempt': 5,
#   'refuge': 3,
#   'region': 8,
#   'regist': 2,
#   'reloc': 1,
#   'remind': 1,
#   'report': 1,
#   'request': 44,
#   'requiremen': 1,
#   'resurg': 5,
#   'reuter': 1,
#   'right': 5,
#   'rishi': 1,
#   'roadmap': 1,
#   'rock': 1,
#   'rush': 2,
#   'sacrific': 5,
#   'sadhu': 1,
#   'safeti': 21,
#   'salman': 1,
#   'samajh': 1,
#   'sampl': 1,
#   'sanatan': 1,
#   'satara': 1,
#   'satisfact': 1,
#   'savin': 1,
#   'schol': 3,
#   'scholarship': 3,
#   'scientist': 1,
#   'screeni': 1,
#   'scriptur': 1,
#   'sect': 1,
#   'secur': 7,
#   'seriou': 1,
#   'servic': 1,
#   'shake': 1,
#   'shape': 1,
#   'sharia': 6,
#   'sharma': 1,
#   'shem': 1,
#   'shortag': 3,
#   'shot': 1,
#   'shubh': 1,
#   'shut': 1,
#   'singh': 1,
#   'situat': 2,
#   'smimer': 1,
#   'snag': 1,
#   'snan': 1,
#   'solut': 2,
#   'someth': 2,
#   'sonusood': 2,
#   'speechless': 1,
#   'speed': 3,
#   'spoke': 1,
#   'spread': 22,
#   'spreader': 2,
#   'star': 14,
#   'station': 9,
#   'stay': 1,
#   'step': 3,
#   'stephen': 1,
#   'stock': 4,
#   'stori': 2,
#   'street': 1,
#   'student': 44,
#   'studentslivesmatt': 1,
#   'sucharit': 1,
#   'sudan': 1,
#   'summer': 3,
#   'sunak': 1,
#   'sunday': 1,
#   'sunn': 1,
#   'sunni': 1,
#   'suppli': 3,
#   'supremecourt': 1,
#   'surat': 1,
#   'surgeri': 2,
#   'survivor': 1,
#   'tag': 2,
#   'tatagroup': 1,
#   'tayari': 1,
#   'terrifi': 1,
#   'tesla': 1,
#   'thank': 34,
#   'thankyou': 1,
#   'three': 1,
#   'time': 3,
#   'tip': 1,
#   'tomorrow': 7,
#   'toronto': 2,
#   'town': 1,
#   'trade': 2,
#   'train': 1,
#   'transcrib': 1,
#   'travel': 3,
#   'tri': 1,
#   'tumn': 1,
#   'turnaround': 1,
#   'ugadi': 8,
#   'uganda': 1,
#   'ukrain': 1,
#   'ummm': 1,
#   'understand': 2,
#   'unfinish': 1,
#   'unfol': 1,
#   'univers': 2,
#   'universit': 1,
#   'unprecedentedtim': 2,
#   'vaisakhi': 6,
#   'vasai': 1,
#   'vehicl': 1,
#   'ventil': 1,
#   'version': 2,
#   'victim': 1,
#   'video': 1,
#   'view': 2,
#   'virologist': 1,
#   'vishu': 6,
#   'visual': 3,
#   'voic': 1,
#   'warrior': 1,
#   'washroom': 1,
#   'wast': 9,
#   'way': 1,
#   'well': 1,
#   'wheelchair': 1,
#   'woke': 1,
#   'worker': 1,
#   'wrap': 1,
#   'wtoera': 1,
#   'yeadon': 2,
#   'year': 7,
#   'yesterday': 3},
#  {'abus': 1,
#   'access': 8,
#   'acknowledg': 1,
#   'advanc': 3,
#   'advis': 1,
#   'africa': 1,
#   'airborn': 1,
#   'airport': 2,
#   'ala': 2,
#   'alcohol': 1,
#   'allah': 1,
#   'amateur': 3,
#   'ameen': 1,
#   'america': 3,
#   'anandacharya': 1,
#   'andrew': 1,
#   'anirban': 2,
#   'antibodi': 1,
#   'anxieti': 1,
#   'anyon': 1,
#   'anyth': 7,
#   'apolog': 1,
#   'applic': 1,
#   'approv': 12,
#   'april': 2,
#   'area': 3,
#   'armi': 2,
#   'articl': 7,
#   'artistontwitt': 1,
#   'artwork': 1,
#   'aspir': 1,
#   'attent': 3,
#   'audac': 2,
#   'augment': 5,
#   'aust': 1,
#   'australia': 5,
#   'author': 2,
#   'awar': 1,
#   'ayurved': 1,
#   'backlash': 1,
#   'backward': 1,
#   'bangladeshi': 1,
#   'bank': 1,
#   'barrier': 1,
#   'barrington': 1,
#   'base': 1,
#   'basket': 5,
#   'bbcnew': 1,
#   'beat': 10,
#   'becom': 5,
#   'benefit': 2,
#   'bhopal': 1,
#   'bibi': 1,
#   'biden': 1,
#   'biggest': 1,
#   'bill': 2,
#   'blind': 1,
#   'blog': 3,
#   'bloodi': 2,
#   'board': 7,
#   'bolsanaro': 1,
#   'border': 1,
#   'bounc': 1,
#   'bowman': 1,
#   'brazil': 13,
#   'break': 2,
#   'bring': 3,
#   'brit': 1,
#   'brooklyn': 1,
#   'bruce': 1,
#   'bsdk': 1,
#   'budesonid': 1,
#   'budget': 1,
#   'build': 1,
#   'burbank': 1,
#   'busi': 4,
#   'california': 2,
#   'calosha': 1,
#   'campaign': 3,
#   'canada': 9,
#   'canadian': 2,
#   'cancel': 12,
#   'cancelboardexam': 5,
#   'car': 1,
#   'care': 7,
#   'career': 1,
#   'carolina': 1,
#   'case': 29,
#   'categor': 1,
#   'cathedra': 1,
#   'caus': 1,
#   'center': 1,
#   'chairman': 1,
#   'challen': 1,
#   'challeng': 2,
#   'chanc': 6,
#   'channel': 1,
#   'chief': 1,
#   'children': 18,
#   'chile': 1,
#   'chri': 1,
#   'christi': 1,
#   'christin': 1,
#   'chuslim': 1,
#   'circu': 1,
#   'citi': 12,
#   'claim': 4,
#   'clearli': 1,
#   'click': 4,
#   'clubhous': 1,
#   'clue': 1,
#   'cnbc': 2,
#   'coach': 1,
#   'coll': 1,
#   'come': 6,
#   'commission': 1,
#   'commun': 2,
#   'compani': 2,
#   'companytax': 1,
#   'complac': 2,
#   'concern': 1,
#   'concert': 1,
#   'conduct': 3,
#   'confid': 2,
#   'congratul': 1,
#   'conn': 1,
#   'conspiraci': 3,
#   'consum': 1,
#   'cooper': 3,
#   'core': 1,
#   'coronaviru': 7,
#   'coronaviruspandem': 1,
#   'cost': 3,
#   'countri': 9,
#   'cours': 2,
#   'covid': 158,
#   'covidvaccin': 7,
#   'cowork': 1,
#   'cricket': 2,
#   'crisi': 2,
#   'crowd': 6,
#   'curat': 1,
#   'currenc': 1,
#   'current': 1,
#   'cut': 2,
#   'cyberattack': 1,
#   'daatestadi': 2,
#   'damn': 1,
#   'dancer': 1,
#   'data': 4,
#   'day': 10,
#   'deal': 1,
#   'death': 1,
#   'debat': 2,
#   'decad': 1,
#   'decisi': 2,
#   'declar': 1,
#   'declin': 1,
#   'defens': 1,
#   'definit': 1,
#   'delay': 1,
#   'deliveri': 1,
#   'demand': 1,
#   'democrat': 3,
#   'denier': 1,
#   'depress': 1,
#   'determin': 1,
#   'die': 1,
#   'differ': 1,
#   'disburs': 1,
#   'diseas': 3,
#   'dispers': 2,
#   'disrupt': 1,
#   'distinct': 1,
#   'doctor': 4,
#   'documentari': 1,
#   'dog': 1,
#   'doin': 1,
#   'domain': 1,
#   'dosag': 1,
#   'doubl': 2,
#   'doubt': 4,
#   'downright': 1,
#   'driven': 3,
#   'driver': 2,
#   'earn': 1,
#   'eas': 1,
#   'econo': 1,
#   'econom': 2,
#   'economi': 6,
#   'ecosystem': 1,
#   'educ': 1,
#   'efficaci': 1,
#   'email': 2,
#   'emerg': 11,
#   'encount': 2,
#   'england': 2,
#   'envi': 1,
#   'erect': 1,
#   'eroju': 2,
#   'europ': 1,
#   'even': 1,
#   'eventprof': 1,
#   'everi': 1,
#   'everybodi': 2,
#   'everyth': 3,
#   'evid': 5,
#   'exam': 17,
#   'exclus': 2,
#   'expert': 5,
#   'export': 1,
#   'extra': 1,
#   'eye': 1,
#   'faan': 2,
#   'facebook': 1,
#   'fact': 4,
#   'failur': 3,
#   'fair': 2,
#   'fake': 1,
#   'fanatic': 1,
#   'farm': 1,
#   'fashion': 2,
#   'februari': 2,
#   'fein': 1,
#   'fenc': 1,
#   'fertil': 1,
#   'fight': 3,
#   'figur': 1,
#   'filmi': 3,
#   'flood': 1,
#   'follow': 1,
#   'foxnew': 1,
#   'fragment': 1,
#   'fraud': 1,
#   'freedom': 1,
#   'friend': 4,
#   'from': 3,
#   'full': 3,
#   'furi': 1,
#   'gadkari': 1,
#   'game': 3,
#   'gender': 1,
#   'girl': 4,
#   'globalhealth': 1,
#   'goal': 1,
#   'godmorningmonday': 1,
#   'godzilla': 4,
#   'godzillavskong': 1,
#   'govern': 6,
#   'govt': 9,
#   'great': 5,
#   'groceri': 1,
#   'growth': 1,
#   'half': 1,
#   'hand': 4,
#   'happen': 1,
#   'haridwar': 4,
#   'have': 1,
#   'health': 32,
#   'healthcar': 5,
#   'heart': 1,
#   'hide': 1,
#   'hinducalendar': 1,
#   'hist': 1,
#   'hit': 3,
#   'holgat': 1,
#   'holi': 2,
#   'hong': 1,
#   'horrif': 1,
#   'horror': 2,
#   'horrormovi': 1,
#   'hosp': 2,
#   'hospit': 1,
#   'hospitalis': 1,
#   'hous': 2,
#   'household': 3,
#   'human': 4,
#   'hvac': 1,
#   'hyderabad': 1,
#   'ideolog': 1,
#   'imm': 1,
#   'impact': 4,
#   'import': 13,
#   'includ': 1,
#   'incom': 5,
#   'india': 48,
#   'indiafightscorona': 1,
#   'indiana': 1,
#   'indonesia': 1,
#   'inequ': 4,
#   'infect': 1,
#   'infra': 7,
#   'insid': 1,
#   'insight': 1,
#   'insur': 2,
#   'integr': 1,
#   'intellig': 4,
#   'intern': 5,
#   'ipl': 2,
#   'iron': 1,
#   'irresponsib': 1,
#   'israel': 6,
#   'jake': 2,
#   'japan': 7,
#   'jasli': 3,
#   'jeremyvin': 1,
#   'job': 3,
#   'johnson': 1,
#   'joshua': 1,
#   'journal': 3,
#   'june': 1,
#   'justic': 1,
#   'kakapora': 1,
#   'kant': 1,
#   'keep': 2,
#   'kenya': 3,
#   'kenyan': 1,
#   'khairi': 1,
#   'kick': 2,
#   'kid': 1,
#   'kilometr': 1,
#   'kind': 3,
#   'kiritsomaiya': 2,
#   'kong': 5,
#   'kumbhmela': 9,
#   'lapd': 1,
#   'late': 1,
#   'laughter': 1,
#   'law': 1,
#   'lead': 1,
#   'leader': 1,
#   'legislatur': 1,
#   'length': 1,
#   'lesson': 1,
#   'letter': 5,
#   'life': 21,
#   'light': 1,
#   'literaci': 1,
#   'live': 6,
#   'loan': 3,
#   'lockdo': 1,
#   'lockdown': 3,
#   'look': 4,
#   'love': 1,
#   'lowest': 1,
#   'mahakumbh': 2,
#   'mahapatra': 2,
#   'maharaj': 1,
#   'malaysia': 1,
#   'mandat': 1,
#   'mandir': 1,
#   'manish': 5,
#   'mark': 2,
#   'markaz': 2,
#   'marxist': 1,
#   'masculi': 1,
#   'mask': 3,
#   'matlab': 2,
#   'matter': 6,
#   'mayhem': 1,
#   'mcyttwt': 2,
#   'mean': 3,
#   'media': 4,
#   'medic': 4,
#   'membership': 1,
#   'mentemia': 1,
#   'mess': 1,
#   'mhra': 10,
#   'micha': 1,
#   'militari': 1,
#   'min': 1,
#   'mine': 1,
#   'minimi': 1,
#   'misinform': 4,
#   'mistak': 2,
#   'monday': 1,
#   'monetari': 5,
#   'month': 6,
#   'moodi': 2,
#   'mortal': 1,
#   'mosqu': 4,
#   'mother': 3,
#   'murder': 6,
#   'muslim': 1,
#   'nadu': 1,
#   'namz': 1,
#   'nariman': 1,
#   'nation': 2,
#   'need': 1,
#   'neetpg': 2,
#   'neglect': 1,
#   'new': 14,
#   'news': 4,
#   'newyear': 1,
#   'ngo': 1,
#   'nobodi': 4,
#   'nolockdownpleas': 1,
#   'norm': 2,
#   'north': 1,
#   'norway': 1,
#   'note': 1,
#   'noth': 9,
#   'number': 9,
#   'octob': 2,
#   'offic': 10,
#   'offici': 3,
#   'okr': 1,
#   'old': 2,
#   'omar': 1,
#   'ontario': 3,
#   'oper': 1,
#   'opinion': 2,
#   'outweigh': 1,
#   'owner': 1,
#   'oxford': 1,
#   'palestinian': 1,
#   'pandem': 7,
#   'panel': 2,
#   'parallel': 2,
#   'part': 7,
#   'parti': 1,
#   'passeng': 2,
#   'pathet': 1,
#   'patient': 5,
#   'pay': 1,
#   'peacekeep': 2,
#   'peer': 1,
#   'peop': 1,
#   'peopl': 20,
#   'perform': 1,
#   'person': 14,
#   'pfizer': 2,
#   'philosophi': 1,
#   'physiotherapist': 1,
#   'pleas': 14,
#   'plzzzzzzzzzzzzzzzzzzzzzzzzzzzzz': 1,
#   'pmda': 5,
#   'polic': 5,
#   'polici': 4,
#   'popul': 3,
#   'pose': 1,
#   'post': 9,
#   'postpon': 9,
#   'postponeneetpg': 2,
#   'power': 4,
#   'premis': 1,
#   'prepar': 3,
#   'pressley': 1,
#   'prim': 1,
#   'primari': 1,
#   'prioriti': 2,
#   'privatis': 1,
#   'problem': 1,
#   'product': 2,
#   'prof': 1,
#   'profit': 2,
#   'programm': 2,
#   'project': 1,
#   'proof': 1,
#   'propheci': 1,
#   'protocol': 6,
#   'provid': 1,
#   'provinc': 1,
#   'provis': 2,
#   'pseudo': 1,
#   'pubg': 1,
#   'public': 2,
#   'pulwama': 1,
#   'punjab': 1,
#   'push': 1,
#   'qualm': 1,
#   'rama': 1,
#   'rampag': 4,
#   'rampal': 1,
#   'rampant': 1,
#   'rape': 8,
#   'rat': 2,
#   'rate': 8,
#   'rcbvsrh': 1,
#   'read': 5,
#   'recess': 1,
#   'recipi': 1,
#   'record': 6,
#   'recoveri': 5,
#   'regul': 4,
#   'religion': 3,
#   'rememb': 1,
#   'republ': 2,
#   'research': 3,
#   'resili': 1,
#   'restor': 1,
#   'restrict': 1,
#   'resurg': 1,
#   'rethink': 1,
#   'reveal': 1,
#   'review': 1,
#   'ringwood': 1,
#   'risk': 6,
#   'role': 1,
#   'room': 1,
#   'round': 1,
#   'rout': 3,
#   'royal': 1,
#   'rubber': 1,
#   'saen': 1,
#   'samvad': 1,
#   'sancti': 1,
#   'sanctuari': 1,
#   'sanskriti': 1,
#   'sant': 1,
#   'saviour': 1,
#   'scania': 1,
#   'scene': 1,
#   'school': 5,
#   'scienc': 8,
#   'scotland': 1,
#   'search': 6,
#   'sebastian': 1,
#   'sell': 1,
#   'sellingcont': 1,
#   'seriou': 5,
#   'shahi': 1,
#   'share': 7,
#   'shirt': 1,
#   'shit': 3,
#   'shock': 4,
#   'shot': 3,
#   'shouldn': 1,
#   'show': 15,
#   'sinc': 1,
#   'singapor': 1,
#   'situat': 2,
#   'snan': 1,
#   'societi': 2,
#   'someth': 6,
#   'sorri': 1,
#   'speak': 1,
#   'speaker': 1,
#   'spin': 1,
#   'spot': 3,
#   'sprea': 5,
#   'sque': 1,
#   'stab': 1,
#   'stand': 1,
#   'stat': 1,
#   'step': 3,
#   'stone': 2,
#   'stress': 1,
#   'student': 9,
#   'studi': 3,
#   'style': 1,
#   'suefox': 1,
#   'summit': 1,
#   'superb': 1,
#   'support': 1,
#   'surg': 1,
#   'suspend': 2,
#   'symptom': 2,
#   'syndrom': 1,
#   'system': 7,
#   'tamil': 1,
#   'tapper': 2,
#   'tax': 1,
#   'teacher': 2,
#   'team': 3,
#   'termin': 2,
#   'theorist': 1,
#   'therapi': 1,
#   'therevelationsofdaniel': 1,
#   'thing': 7,
#   'thirti': 1,
#   'thnx': 1,
#   'thread': 11,
#   'threat': 3,
#   'threaten': 1,
#   'throw': 1,
#   'tiger': 2,
#   'time': 23,
#   'tiwari': 5,
#   'tlaib': 1,
#   'tobi': 1,
#   'today': 6,
#   'topic': 2,
#   'toward': 1,
#   'toxic': 1,
#   'trade': 1,
#   'trail': 3,
#   'tran': 2,
#   'transmiss': 3,
#   'trial': 2,
#   'trio': 1,
#   'trudeau': 3,
#   'truth': 2,
#   'tucker': 1,
#   'twitter': 1,
#   'type': 1,
#   'uccsrckocc': 2,
#   'uganda': 1,
#   'underwrit': 2,
#   'union': 1,
#   'univers': 2,
#   'unmiss': 2,
#   'upsid': 1,
#   'usfda': 10,
#   'vaccin': 47,
#   'vaccineforal': 2,
#   'vakeelsa': 2,
#   'verdict': 1,
#   'video': 8,
#   'view': 5,
#   'wait': 1,
#   'wane': 1,
#   'washington': 1,
#   'wasimrizvi': 1,
#   'watch': 4,
#   'wave': 2,
#   'wealth': 2,
#   'week': 11,
#   'what': 3,
#   'whistleblow': 1,
#   'woak': 1,
#   'woman': 3,
#   'women': 2,
#   'word': 1,
#   'work': 3,
#   'worker': 1,
#   'world': 10,
#   'worri': 2,
#   'yara': 1,
#   'year': 29,
#   'yesterday': 2,
#   'young': 7,
#   'your': 1,
#   'zabramunda': 1},
#  {'aaaaaaaaaaaaaa': 1,
#   'aarogya': 1,
#   'aatmanirbharbharat': 8,
#   'abandon': 1,
#   'accept': 2,
#   'access': 1,
#   'activ': 1,
#   'actual': 1,
#   'acumen': 1,
#   'addit': 1,
#   'advers': 3,
#   'advi': 1,
#   'advic': 4,
#   'advis': 2,
#   'affect': 1,
#   'afoot': 1,
#   'africa': 3,
#   'akhanda': 2,
#   'alway': 1,
#   'alygoni': 2,
#   'amend': 1,
#   'amid': 1,
#   'anim': 1,
#   'annoy': 1,
#   'applic': 1,
#   'appoint': 3,
#   'approv': 35,
#   'april': 4,
#   'arclightcinema': 1,
#   'argentina': 1,
#   'arkansan': 1,
#   'arriv': 2,
#   'artist': 1,
#   'astrazeneca': 3,
#   'astro': 2,
#   'atleast': 1,
#   'attack': 2,
#   'australia': 3,
#   'australian': 1,
#   'author': 1,
#   'authoris': 4,
#   'authorisatio': 1,
#   'autumn': 1,
#   'ayub': 1,
#   'back': 1,
#   'backlog': 1,
#   'baghi': 1,
#   'bahama': 1,
#   'baisakhi': 3,
#   'baloon': 1,
#   'bash': 1,
#   'bath': 2,
#   'battl': 1,
#   'becki': 1,
#   'bed': 2,
#   'behaviour': 1,
#   'behe': 1,
#   'belat': 2,
#   'believ': 1,
#   'beliv': 1,
#   'bhagvan': 1,
#   'bhakt': 1,
#   'bhaktan': 1,
#   'bharos': 1,
#   'bhasin': 4,
#   'bimaru': 4,
#   'blitz': 1,
#   'book': 3,
#   'bookmark': 1,
#   'breakthrough': 1,
#   'brilliant': 1,
#   'build': 1,
#   'bullshit': 1,
#   'buri': 1,
#   'burn': 1,
#   'byrasha': 1,
#   'cabinet': 1,
#   'candid': 1,
#   'capac': 2,
#   'care': 1,
#   'career': 1,
#   'case': 4,
#   'cell': 1,
#   'cent': 1,
#   'center': 2,
#   'centr': 5,
#   'chabahar': 1,
#   'chain': 1,
#   'chair': 1,
#   'chal': 1,
#   'chang': 3,
#   'charg': 1,
#   'chart': 1,
#   'check': 2,
#   'cheer': 1,
#   'cheltenham': 1,
#   'chickenpox': 1,
#   'child': 1,
#   'circumst': 2,
#   'citi': 3,
#   'citizen': 1,
#   'claim': 2,
#   'clay': 2,
#   'clubhous': 1,
#   'cnbctv': 1,
#   'comment': 1,
#   'compani': 2,
#   'compar': 2,
#   'confirm': 2,
#   'conspiraci': 1,
#   'convers': 2,
#   'corona': 14,
#   'coronaviru': 3,
#   'could': 1,
#   'couldn': 1,
#   'council': 3,
#   'count': 1,
#   'countr': 1,
#   'countri': 22,
#   'coupl': 1,
#   'courag': 1,
#   'court': 3,
#   'covi': 2,
#   'covid': 106,
#   'cremat': 1,
#   'cri': 1,
#   'criticis': 1,
#   'crypto': 2,
#   'cryptocurr': 2,
#   'daili': 3,
#   'damn': 1,
#   'data': 2,
#   'databas': 1,
#   'day': 34,
#   'daylight': 1,
#   'dcga': 1,
#   'dead': 1,
#   'death': 5,
#   'declar': 5,
#   'deforest': 1,
#   'deja': 1,
#   'delhi': 1,
#   'deliveri': 1,
#   'demand': 5,
#   'democraci': 2,
#   'deni': 1,
#   'depopul': 1,
#   'dept': 1,
#   'desh': 1,
#   'destroy': 1,
#   'detail': 4,
#   'deter': 1,
#   'devil': 1,
#   'dhimmi': 1,
#   'didi': 8,
#   'differ': 3,
#   'director': 3,
#   'dist': 1,
#   'dose': 1,
#   'drop': 1,
#   'drug': 5,
#   'druid': 2,
#   'ear': 1,
#   'east': 1,
#   'economi': 14,
#   'edinburgh': 1,
#   'effect': 2,
#   'electricvehicl': 1,
#   'email': 1,
#   'emerg': 27,
#   'emergen': 1,
#   'emphasi': 1,
#   'entertain': 1,
#   'epidem': 1,
#   'equiti': 1,
#   'eua': 3,
#   'europ': 1,
#   'european': 1,
#   'event': 3,
#   'everyon': 2,
#   'exampl': 1,
#   'exclus': 3,
#   'excus': 2,
#   'execut': 1,
#   'exodu': 2,
#   'expans': 1,
#   'expect': 1,
#   'experi': 3,
#   'experiment': 1,
#   'explor': 1,
#   'expos': 1,
#   'facil': 1,
#   'fact': 2,
#   'fan': 2,
#   'fast': 17,
#   'father': 1,
#   'fault': 1,
#   'fear': 5,
#   'fight': 4,
#   'figur': 1,
#   'first': 4,
#   'flight': 1,
#   'fore': 2,
#   'forecast': 1,
#   'foreign': 1,
#   'form': 1,
#   'free': 1,
#   'freee': 1,
#   'frustrat': 2,
#   'fund': 3,
#   'futur': 4,
#   'fxcking': 1,
#   'fyi': 1,
#   'galleri': 1,
#   'gandhi': 16,
#   'gang': 3,
#   'garden': 2,
#   'gay': 1,
#   'gener': 1,
#   'gennova': 1,
#   'georg': 5,
#   'glove': 1,
#   'godi': 1,
#   'good': 4,
#   'goodby': 1,
#   'gover': 1,
#   'govern': 15,
#   'governmen': 5,
#   'governor': 1,
#   'govt': 34,
#   'grant': 1,
#   'grip': 1,
#   'group': 3,
#   'growth': 3,
#   'gudipadwa': 1,
#   'guidelin': 1,
#   'gujarat': 2,
#   'gupta': 1,
#   'hair': 1,
#   'hancock': 1,
#   'handler': 1,
#   'handmad': 1,
#   'haseen': 4,
#   'haven': 1,
#   'health': 4,
#   'heart': 2,
#   'hello': 7,
#   'help': 3,
#   'henc': 1,
#   'highway': 1,
#   'hill': 2,
#   'himach': 1,
#   'hindi': 14,
#   'hindu': 16,
#   'histori': 1,
#   'hoga': 1,
#   'home': 7,
#   'hosp': 3,
#   'hospit': 6,
#   'hospitalis': 1,
#   'hous': 1,
#   'huge': 2,
#   'humanitywillwin': 1,
#   'idhar': 1,
#   'ignor': 2,
#   'iitian': 6,
#   'imagin': 3,
#   'immigr': 1,
#   'imo': 1,
#   'incompet': 2,
#   'increas': 9,
#   'indi': 1,
#   'india': 107,
#   'indian': 2,
#   'infect': 1,
#   'inho': 1,
#   'injuri': 1,
#   'instagram': 1,
#   'instc': 1,
#   'intellig': 4,
#   'into': 1,
#   'intoxic': 1,
#   'investor': 2,
#   'iran': 1,
#   'irelan': 1,
#   'ireland': 1,
#   'island': 1,
#   'isol': 2,
#   'issu': 1,
#   'ivan': 1,
#   'jamaat': 3,
#   'jasli': 2,
#   'jasmin': 4,
#   'jasminbhasin': 2,
#   'jurisdict': 2,
#   'kais': 1,
#   'kalava': 1,
#   'kangaroo': 1,
#   'kasab': 1,
#   'kaunsa': 1,
#   'keep': 4,
#   'kennedi': 2,
#   'kerela': 5,
#   'kid': 2,
#   'kidhar': 1,
#   'kitno': 1,
#   'kiya': 1,
#   'kogi': 1,
#   'kumbh': 3,
#   'kumbhmela': 7,
#   'leadership': 2,
#   'legacywebshow': 1,
#   'legal': 2,
#   'liger': 1,
#   'link': 3,
#   'listen': 1,
#   'live': 4,
#   'loan': 2,
#   'locat': 2,
#   'major': 3,
#   'mamamoo': 1,
#   'manila': 1,
#   'march': 3,
#   'mark': 1,
#   'market': 1,
#   'maryland': 2,
#   'mask': 1,
#   'massiv': 2,
#   'master': 2,
#   'matt': 1,
#   'mckeith': 1,
#   'meant': 1,
#   'mechan': 1,
#   'media': 13,
#   'meet': 1,
#   'mein': 2,
#   'member': 1,
#   'metro': 1,
#   'michigan': 2,
#   'midday': 1,
#   'middaynew': 1,
#   'millio': 1,
#   'million': 1,
#   'millionair': 3,
#   'mind': 2,
#   'minist': 12,
#   'ministri': 2,
#   'moderna': 6,
#   'modi': 18,
#   'modiji': 1,
#   'moment': 5,
#   'monday': 1,
#   'money': 6,
#   'monitor': 1,
#   'mood': 1,
#   'morn': 2,
#   'most': 2,
#   'move': 6,
#   'movi': 2,
#   'mrna': 2,
#   'mughali': 4,
#   'muslim': 3,
#   'must': 3,
#   'muzlim': 1,
#   'narendra': 2,
#   'nation': 3,
#   'necess': 1,
#   'negvac': 1,
#   'network': 1,
#   'new': 3,
#   'newmarket': 1,
#   'news': 4,
#   'newspap': 1,
#   'newspot': 1,
#   'ngma': 1,
#   'nice': 2,
#   'none': 1,
#   'nope': 2,
#   'northern': 1,
#   'nutrit': 2,
#   'obey': 2,
#   'observ': 5,
#   'obsess': 1,
#   'offens': 1,
#   'okay': 1,
#   'onc': 1,
#   'opposit': 1,
#   'oppress': 1,
#   'other': 3,
#   'outbreak': 1,
#   'outland': 1,
#   'oxford': 3,
#   'packag': 1,
#   'page': 1,
#   'pakistan': 4,
#   'palmoil': 1,
#   'parisagr': 1,
#   'patient': 3,
#   'patinet': 1,
#   'peg': 1,
#   'peopl': 7,
#   'person': 1,
#   'pessim': 1,
#   'pfizer': 11,
#   'pharma': 3,
#   'photo': 1,
#   'photographi': 2,
#   'place': 2,
#   'plan': 2,
#   'plasma': 1,
#   'play': 4,
#   'pleas': 5,
#   'pledg': 1,
#   'plot': 1,
#   'pmmodiji': 1,
#   'poiso': 1,
#   'pokerstar': 1,
#   'polici': 9,
#   'polit': 2,
#   'polym': 1,
#   'port': 1,
#   'portug': 1,
#   'posit': 2,
#   'postmortem': 1,
#   'pradesh': 1,
#   'prasad': 13,
#   'predict': 3,
#   'prevent': 1,
#   'prime': 2,
#   'procur': 1,
#   'produc': 1,
#   'product': 4,
#   'programm': 1,
#   'protect': 2,
#   'pub': 1,
#   'public': 4,
#   'pull': 1,
#   'rabbit': 1,
#   'radheshyam': 1,
#   'raga': 1,
#   'raha': 1,
#   'rahul': 17,
#   'ramadan': 1,
#   'rana': 1,
#   'rashtra': 5,
#   'ravi': 13,
#   'rawat': 1,
#   'reaction': 2,
#   'realiti': 2,
#   'reason': 1,
#   'reassur': 2,
#   'recommend': 2,
#   'record': 10,
#   'redfield': 1,
#   'reduct': 1,
#   'refund': 1,
#   'refusa': 1,
#   'regul': 7,
#   'rehash': 3,
#   'rekt': 1,
#   'releas': 1,
#   'religion': 3,
#   'repeat': 1,
#   'report': 9,
#   'requir': 1,
#   'rescu': 1,
#   'research': 2,
#   'resid': 1,
#   'restrict': 7,
#   'retweet': 1,
#   'revenu': 1,
#   'right': 3,
#   'robert': 3,
#   'rochel': 1,
#   'roll': 1,
#   'rule': 8,
#   'russia': 1,
#   'sabs': 4,
#   'sail': 1,
#   'sale': 1,
#   'same': 4,
#   'sanghi': 6,
#   'sanjay': 1,
#   'sanot': 1,
#   'sanskruti': 1,
#   'sarkaruvaaripaata': 1,
#   'say': 1,
#   'scale': 1,
#   'scam': 3,
#   'scientist': 1,
#   'scotland': 3,
#   'sector': 3,
#   'sens': 4,
#   'servic': 2,
#   'sewag': 1,
#   'shameoncongress': 1,
#   'shamshan': 1,
#   'shankar': 13,
#   'sheep': 1,
#   'shot': 2,
#   'should': 7,
#   'sikh': 1,
#   'silent': 1,
#   'site': 1,
#   'situat': 5,
#   'snap': 1,
#   'societi': 4,
#   'someth': 1,
#   'speak': 1,
#   'spokesman': 1,
#   'sport': 1,
#   'sputnik': 4,
#   'sputnikv': 2,
#   'ssot': 1,
#   'stake': 3,
#   'standoff': 1,
#   'start': 2,
#   'state': 10,
#   'statement': 2,
#   'statisti': 2,
#   'step': 5,
#   'storag': 1,
#   'strain': 3,
#   'stroke': 2,
#   'subject': 1,
#   'suffer': 1,
#   'summer': 1,
#   'suppli': 3,
#   'suprem': 2,
#   'sync': 1,
#   'tabl': 2,
#   'tablighi': 3,
#   'tali': 1,
#   'target': 2,
#   'taxpay': 5,
#   'tech': 1,
#   'teenag': 1,
#   'temperatur': 2,
#   'term': 3,
#   'test': 4,
#   'testymctestfac': 1,
#   'text': 1,
#   'thali': 1,
#   'than': 1,
#   'thank': 1,
#   'theater': 1,
#   'theatr': 1,
#   'theme': 1,
#   'theori': 2,
#   'thi': 1,
#   'thier': 1,
#   'thing': 1,
#   'thousand': 2,
#   'thread': 6,
#   'till': 1,
#   'titleroar': 1,
#   'today': 14,
#   'tour': 1,
#   'track': 21,
#   'traitor': 1,
#   'travel': 1,
#   'treatment': 4,
#   'trend': 4,
#   'trial': 3,
#   'trip': 1,
#   'trudeaucovidcolludingpm': 1,
#   'true': 1,
#   'truli': 1,
#   'trump': 3,
#   'trust': 1,
#   'tuesday': 3,
#   'tuesdaymotiv': 1,
#   'tweet': 24,
#   'twist': 1,
#   'ugadi': 1,
#   'underwat': 2,
#   'unit': 2,
#   'unprofession': 1,
#   'urg': 3,
#   'utensil': 6,
#   'vacat': 2,
#   'vaccin': 134,
#   'ventil': 1,
#   'verifi': 1,
#   'version': 1,
#   'vijayendra': 1,
#   'vika': 1,
#   'villag': 4,
#   'visa': 2,
#   'vision': 1,
#   'voic': 1,
#   'waah': 1,
#   'wait': 3,
#   'walenski': 1,
#   'warn': 2,
#   'wate': 1,
#   'wave': 10,
#   'wear': 2,
#   'week': 3,
#   'well': 2,
#   'westerni': 1,
#   'white': 1,
#   'wide': 1,
#   'wife': 2,
#   'without': 1,
#   'women': 1,
#   'work': 1,
#   'world': 12,
#   'worst': 1,
#   'yacht': 1,
#   'year': 6,
#   'yesterday': 9,
#   'yogi': 1,
#   'york': 1,
#   'yuva': 1,
#   'zimbabw': 1,
#   'zone': 2},
#  {'abdullah': 1,
#   'academ': 2,
#   'access': 2,
#   'account': 4,
#   'adapt': 1,
#   'aerosol': 1,
#   'africa': 3,
#   'african': 2,
#   'against': 1,
#   'agreement': 2,
#   'airdri': 1,
#   'airport': 3,
#   'aiwaji': 1,
#   'akshaykumar': 1,
#   'alarm': 4,
#   'albertson': 1,
#   'alden': 1,
#   'allow': 1,
#   'ambassador': 2,
#   'ambedekar': 1,
#   'ambedkar': 1,
#   'amen': 1,
#   'amitshah': 1,
#   'amount': 1,
#   'angat': 1,
#   'anghan': 3,
#   'angl': 1,
#   'anniversari': 1,
#   'announc': 5,
#   'anoth': 1,
#   'answer': 5,
#   'antigen': 1,
#   'apolog': 1,
#   'appoint': 1,
#   'approx': 1,
#   'april': 12,
#   'arapaho': 1,
#   'architect': 1,
#   'area': 1,
#   'armi': 2,
#   'assam': 14,
#   'assist': 1,
#   'associ': 1,
#   'attack': 1,
#   'attende': 1,
#   'audienc': 7,
#   'audit': 3,
#   'aunti': 1,
#   'auspol': 1,
#   'avail': 1,
#   'avoid': 1,
#   'babu': 3,
#   'ball': 1,
#   'bank': 11,
#   'base': 2,
#   'bazaar': 1,
#   'be': 1,
#   'belief': 1,
#   'best': 2,
#   'between': 1,
#   'beyond': 1,
#   'bharat': 1,
#   'bhuvneshwar': 3,
#   'biggest': 1,
#   'bihu': 1,
#   'billionair': 1,
#   'birth': 1,
#   'black': 1,
#   'blame': 1,
#   'bless': 1,
#   'bodi': 1,
#   'border': 2,
#   'boss': 1,
#   'brazil': 1,
#   'break': 4,
#   'bring': 1,
#   'britain': 2,
#   'british': 2,
#   'briton': 1,
#   'broadcast': 2,
#   'brother': 1,
#   'buhay': 1,
#   'build': 1,
#   'bullypm': 2,
#   'busi': 1,
#   'call': 4,
#   'card': 2,
#   'careless': 1,
#   'carlo': 5,
#   'case': 62,
#   'cash': 1,
#   'casualti': 1,
#   'caus': 2,
#   'caution': 1,
#   'centenni': 1,
#   'certif': 1,
#   'champion': 1,
#   'chanc': 5,
#   'chaprasi': 1,
#   'checkup': 1,
#   'chennai': 1,
#   'chest': 4,
#   'chetichand': 2,
#   'chhattisgarh': 1,
#   'children': 2,
#   'china': 14,
#   'chinaliedandpeopl': 1,
#   'chindi': 1,
#   'chines': 1,
#   'chip': 1,
#   'christian': 1,
#   'christin': 3,
#   'church': 1,
#   'citi': 2,
#   'citizen': 5,
#   'claim': 2,
#   'clinic': 2,
#   'clot': 1,
#   'cluster': 2,
#   'coast': 1,
#   'collect': 3,
#   'colleg': 3,
#   'coloni': 2,
#   'commemor': 1,
#   'commun': 9,
#   'concern': 1,
#   'condit': 2,
#   'confus': 1,
#   'consolid': 1,
#   'constitut': 4,
#   'contain': 1,
#   'contam': 1,
#   'contin': 1,
#   'contribut': 1,
#   'control': 2,
#   'corner': 1,
#   'cornwal': 1,
#   'coron': 2,
#   'corona': 6,
#   'corpor': 4,
#   'correct': 1,
#   'cough': 3,
#   'could': 1,
#   'councillor': 3,
#   'countri': 15,
#   'covid': 149,
#   'covidiot': 1,
#   'credit': 4,
#   'crisi': 1,
#   'croatia': 1,
#   'crook': 1,
#   'crowd': 1,
#   'cruel': 2,
#   'csgo': 1,
#   'cure': 1,
#   'curfew': 1,
#   'cute': 1,
#   'dahilkay': 1,
#   'damag': 1,
#   'danc': 6,
#   'daniil': 7,
#   'dare': 1,
#   'darpa': 3,
#   'date': 4,
#   'daunt': 2,
#   'death': 9,
#   'dedic': 1,
#   'desanti': 1,
#   'deshbhagti': 1,
#   'detect': 1,
#   'diamond': 1,
#   'digihermit': 1,
#   'digniti': 1,
#   'disast': 1,
#   'discov': 2,
#   'distract': 2,
#   'doctor': 5,
#   'document': 3,
#   'donor': 1,
#   'doom': 1,
#   'dormitori': 1,
#   'dose': 1,
#   'download': 1,
#   'dozen': 2,
#   'drop': 1,
#   'dua': 1,
#   'earn': 1,
#   'earth': 2,
#   'east': 1,
#   'econom': 2,
#   'economi': 3,
#   'educ': 2,
#   'effect': 5,
#   'eid': 1,
#   'electr': 1,
#   'engl': 1,
#   'england': 4,
#   'estim': 1,
#   'evarki': 1,
#   'even': 1,
#   'event': 4,
#   'everyon': 13,
#   'examin': 1,
#   'exchang': 1,
#   'execut': 2,
#   'experi': 1,
#   'export': 1,
#   'facilit': 1,
#   'faculti': 2,
#   'fake': 1,
#   'famili': 5,
#   'farmer': 1,
#   'fatf': 1,
#   'father': 1,
#   'feat': 1,
#   'fella': 1,
#   'fema': 1,
#   'festiv': 2,
#   'fever': 3,
#   'ffdforum': 1,
#   'figur': 1,
#   'filipino': 3,
#   'financ': 1,
#   'first': 1,
#   'florida': 3,
#   'folk': 2,
#   'food': 2,
#   'footag': 1,
#   'forecast': 1,
#   'fossil': 1,
#   'foster': 1,
#   'frame': 1,
#   'fraudster': 1,
#   'friend': 2,
#   'fuck': 4,
#   'fuel': 1,
#   'fulli': 1,
#   'gangwar': 2,
#   'gaza': 1,
#   'give': 1,
#   'glen': 1,
#   'gloom': 2,
#   'gon': 1,
#   'gorg': 1,
#   'govern': 8,
#   'govt': 2,
#   'grade': 2,
#   'graviti': 1,
#   'grey': 1,
#   'gudipadwa': 3,
#   'guid': 3,
#   'guy': 1,
#   'haarp': 1,
#   'hackney': 1,
#   'hairdress': 1,
#   'happybirthdaypmmodi': 1,
#   'hara': 1,
#   'hardli': 1,
#   'haunt': 1,
#   'hazmat': 1,
#   'healer': 1,
#   'health': 1,
#   'hello': 2,
#   'heritag': 1,
#   'hidd': 1,
#   'histori': 1,
#   'holgat': 4,
#   'holi': 1,
#   'home': 14,
#   'homeless': 1,
#   'honor': 1,
#   'hospit': 1,
#   'hotel': 2,
#   'huge': 1,
#   'human': 2,
#   'hundr': 2,
#   'hypothesi': 1,
#   'idiot': 1,
#   'illn': 1,
#   'imagin': 2,
#   'immun': 1,
#   'increas': 3,
#   'inculc': 1,
#   'indi': 8,
#   'india': 85,
#   'infect': 22,
#   'inform': 1,
#   'inhuman': 1,
#   'inquest': 2,
#   'into': 1,
#   'investig': 2,
#   'ipl': 1,
#   'iran': 3,
#   'islam': 1,
#   'jallianwalabaghmassacr': 2,
#   'januari': 1,
#   'jayanti': 1,
#   'joblesssincemodi': 1,
#   'john': 1,
#   'johnson': 1,
#   'join': 4,
#   'joke': 4,
#   'joseph': 3,
#   'journalist': 1,
#   'jude': 1,
#   'kakati': 1,
#   'kareem': 2,
#   'karnan': 1,
#   'kashmir': 2,
#   'keaney': 1,
#   'keonjhar': 1,
#   'khiladi': 1,
#   'killer': 3,
#   'kit': 5,
#   'kiwa': 1,
#   'korea': 4,
#   'kumar': 5,
#   'lakh': 1,
#   'lambeth': 9,
#   'land': 1,
#   'larg': 3,
#   'latest': 4,
#   'launch': 2,
#   'leader': 2,
#   'leagu': 1,
#   'learn': 2,
#   'lemoa': 1,
#   'leni': 2,
#   'letscrackit': 5,
#   'level': 3,
#   'liar': 1,
#   'licenc': 1,
#   'list': 7,
#   'live': 4,
#   'lizel': 2,
#   'lmao': 2,
#   'lockdown': 6,
#   'london': 5,
#   'longcovid': 1,
#   'loos': 1,
#   'lord': 1,
#   'love': 1,
#   'lunch': 1,
#   'made': 2,
#   'magazin': 1,
#   'mahar': 6,
#   'maharashtr': 1,
#   'maharashtra': 18,
#   'mahesh': 3,
#   'malaysia': 1,
#   'mamanthan': 1,
#   'manifest': 1,
#   'march': 5,
#   'marichjhapi': 1,
#   'massacr': 1,
#   'master': 13,
#   'match': 2,
#   'math': 1,
#   'meanphiravich': 3,
#   'meant': 2,
#   'meantro': 3,
#   'medic': 3,
#   'medvedev': 7,
#   'memori': 2,
#   'messag': 3,
#   'metr': 1,
#   'microchip': 3,
#   'mileston': 1,
#   'million': 1,
#   'minist': 12,
#   'minnesota': 1,
#   'minu': 1,
#   'mislead': 1,
#   'missionari': 1,
#   'money': 1,
#   'mont': 6,
#   'month': 8,
#   'moon': 1,
#   'morden': 1,
#   'morrison': 4,
#   'movement': 2,
#   'mubarak': 2,
#   'municip': 3,
#   'munshi': 1,
#   'murder': 3,
#   'music': 1,
#   'muslim': 6,
#   'mutant': 2,
#   'mutat': 1,
#   'narr': 1,
#   'ndma': 1,
#   'news': 2,
#   'nhk': 2,
#   'nigeria': 5,
#   'night': 3,
#   'none': 2,
#   'nonsens': 4,
#   'northwest': 1,
#   'novavax': 1,
#   'nphet': 2,
#   'nsdc': 1,
#   'ntrkoratalasiva': 1,
#   'number': 8,
#   'oann': 2,
#   'occas': 2,
#   'occup': 1,
#   'offic': 2,
#   'ongo': 1,
#   'oper': 1,
#   'opposit': 3,
#   'osun': 4,
#   'otherwis': 2,
#   'otp': 2,
#   'outbr': 1,
#   'outcom': 1,
#   'outlet': 1,
#   'palestin': 1,
#   'pall': 1,
#   'panacea': 1,
#   'pandey': 1,
#   'parafield': 1,
#   'partner': 1,
#   'patient': 3,
#   'patron': 1,
#   'pavilion': 1,
#   'peak': 2,
#   'pemberton': 3,
#   'pentagon': 1,
#   'peopl': 21,
#   'peopleasia': 1,
#   'percentag': 1,
#   'period': 2,
#   'permi': 1,
#   'perpetr': 1,
#   'person': 4,
#   'peterborough': 1,
#   'petti': 1,
#   'philippin': 1,
#   'photo': 3,
#   'place': 4,
#   'player': 2,
#   'pleas': 2,
#   'pneumon': 1,
#   'pod': 1,
#   'polici': 2,
#   'policymak': 1,
#   'politi': 1,
#   'politician': 5,
#   'poll': 3,
#   'posit': 21,
#   'postponeneetpg': 1,
#   'poverti': 2,
#   'power': 1,
#   'practic': 2,
#   'pray': 1,
#   'prayer': 2,
#   'precaut': 1,
#   'premchand': 1,
#   'presid': 2,
#   'prime': 4,
#   'principl': 1,
#   'priti': 1,
#   'priyanka': 1,
#   'produc': 1,
#   'prof': 6,
#   'program': 2,
#   'project': 1,
#   'properti': 1,
#   'protocol': 1,
#   'publish': 1,
#   'pulseghana': 1,
#   'purchas': 1,
#   'purpos': 2,
#   'push': 1,
#   'qatar': 1,
#   'racist': 4,
#   'raheel': 2,
#   'rahulgandhi': 2,
#   'raiss': 1,
#   'ramadan': 16,
#   'ramadanmubarak': 1,
#   'ramadhan': 2,
#   'ramzan': 2,
#   'rate': 3,
#   'rayyan': 1,
#   'reach': 8,
#   'reaction': 2,
#   'realist': 2,
#   'realm': 2,
#   'reason': 5,
#   'rebootingireland': 1,
#   'recov': 1,
#   'recoveri': 3,
#   'regim': 1,
#   'region': 1,
#   'regist': 1,
#   'registratio': 1,
#   'relam': 2,
#   'relationship': 1,
#   'releas': 2,
#   'relentless': 1,
#   'rememb': 5,
#   'remind': 3,
#   'repli': 1,
#   'report': 4,
#   'resea': 1,
#   'reserv': 7,
#   'resid': 4,
#   'resignsturgeon': 1,
#   'resourc': 2,
#   'respons': 6,
#   'restrict': 3,
#   'right': 2,
#   'riot': 3,
#   'rise': 4,
#   'road': 3,
#   'robredo': 1,
#   'royal': 1,
#   'rtpcr': 4,
#   'rubi': 1,
#   'rummag': 1,
#   'russia': 3,
#   'safeway': 1,
#   'sage': 2,
#   'saharan': 1,
#   'said': 1,
#   'salaar': 1,
#   'sanctuari': 1,
#   'santosh': 2,
#   'sarawak': 1,
#   'sarjapura': 1,
#   'satyajit': 1,
#   'scam': 2,
#   'scamdem': 1,
#   'scammer': 2,
#   'scar': 2,
#   'sceptic': 2,
#   'school': 1,
#   'scientist': 10,
#   'scotland': 1,
#   'scott': 6,
#   'season': 1,
#   'second': 2,
#   'sector': 1,
#   'self': 2,
#   'senior': 2,
#   'sensor': 1,
#   'sept': 1,
#   'septemb': 9,
#   'seri': 2,
#   'seriou': 1,
#   'shake': 1,
#   'shame': 1,
#   'shatranj': 1,
#   'shoot': 1,
#   'shore': 1,
#   'shott': 1,
#   'shri': 4,
#   'side': 5,
#   'sighti': 1,
#   'signatur': 1,
#   'singapor': 1,
#   'sister': 1,
#   'site': 1,
#   'skill': 1,
#   'slaughter': 1,
#   'slot': 1,
#   'solut': 2,
#   'someon': 1,
#   'songkran': 3,
#   'sostronk': 1,
#   'south': 12,
#   'southafrican': 1,
#   'souza': 1,
#   'specialist': 1,
#   'spike': 5,
#   'srivastava': 2,
#   'sscgd': 1,
#   'star': 9,
#   'start': 3,
#   'stat': 1,
#   'state': 7,
#   'statu': 1,
#   'stay': 3,
#   'stayathomechalleng': 1,
#   'step': 1,
#   'stop': 1,
#   'stori': 1,
#   'strain': 1,
#   'stream': 1,
#   'streatham': 1,
#   'strengthen': 3,
#   'studio': 1,
#   'stupid': 1,
#   'style': 1,
#   'suit': 1,
#   'summit': 1,
#   'summon': 1,
#   'surat': 4,
#   'surfac': 1,
#   'surg': 13,
#   'surnam': 1,
#   'surveil': 2,
#   'symptom': 3,
#   'tactic': 1,
#   'talk': 3,
#   'talli': 1,
#   'team': 1,
#   'telepathi': 1,
#   'templ': 4,
#   'test': 42,
#   'thaali': 2,
#   'thalapathi': 1,
#   'thalapathyvijay': 1,
#   'thank': 5,
#   'they': 1,
#   'thing': 3,
#   'thousand': 3,
#   'three': 1,
#   'thursday': 1,
#   'tibet': 1,
#   'till': 2,
#   'time': 10,
#   'tira': 1,
#   'tobacco': 1,
#   'today': 12,
#   'todayonlin': 1,
#   'tomorrow': 3,
#   'total': 2,
#   'transmiss': 1,
#   'travel': 1,
#   'trend': 2,
#   'ugadi': 2,
#   'umrah': 6,
#   'unabl': 1,
#   'unacademyfanofthematch': 5,
#   'union': 4,
#   'upset': 1,
#   'usag': 1,
#   'vaccin': 8,
#   'vakeelsaab': 7,
#   'valu': 2,
#   'varia': 2,
#   'variant': 8,
#   'vice': 3,
#   'victim': 2,
#   'violenc': 4,
#   'virtual': 1,
#   'visit': 1,
#   'vote': 5,
#   'wait': 1,
#   'wandsworth': 9,
#   'washington': 1,
#   'wasn': 2,
#   'watch': 3,
#   'wave': 2,
#   'way': 1,
#   'websit': 1,
#   'west': 1,
#   'westbeng': 1,
#   'westminsterhour': 2,
#   'wher': 1,
#   'will': 5,
#   'wish': 3,
#   'woe': 1,
#   'wolvi': 1,
#   'woman': 1,
#   'wonder': 2,
#   'work': 2,
#   'worker': 4,
#   'world': 8,
#   'worri': 2,
#   'worst': 2,
#   'wright': 2,
#   'xinjiang': 1,
#   'yeah': 2,
#   'year': 21,
#   'yesjulz': 2,
#   'yourself': 2,
#   'yourselv': 1,
#   'zero': 2},
#  {'abet': 1,
#   'activist': 6,
#   'actor': 2,
#   'advisor': 1,
#   'advisori': 1,
#   'agroforestri': 1,
#   'airhead': 1,
#   'alan': 1,
#   'allah': 1,
#   'allahabad': 1,
#   'amer': 1,
#   'amidst': 4,
#   'analysi': 1,
#   'anjuman': 1,
#   'anthoni': 1,
#   'anyon': 7,
#   'appl': 2,
#   'appropri': 1,
#   'arrang': 1,
#   'asap': 1,
#   'aspen': 1,
#   'assassin': 3,
#   'assess': 2,
#   'assist': 1,
#   'aster': 1,
#   'asthmat': 1,
#   'attend': 14,
#   'aunt': 2,
#   'auster': 2,
#   'award': 1,
#   'behaviour': 2,
#   'bharat': 4,
#   'bhubaneswar': 3,
#   'black': 1,
#   'block': 2,
#   'blood': 62,
#   'bradford': 1,
#   'break': 2,
#   'bristol': 1,
#   'canada': 2,
#   'case': 5,
#   'catherin': 1,
#   'celebr': 1,
#   'chaitanyatamhan': 2,
#   'challeng': 6,
#   'chile': 13,
#   'clinicalai': 1,
#   'cogniz': 1,
#   'cold': 2,
#   'comment': 1,
#   'committe': 1,
#   'comorbid': 1,
#   'competit': 1,
#   'cont': 1,
#   'contract': 1,
#   'copper': 1,
#   'coronamem': 1,
#   'coronaviru': 2,
#   'correspond': 1,
#   'cours': 1,
#   'court': 6,
#   'covid': 181,
#   'crisi': 1,
#   'current': 1,
#   'cytokin': 1,
#   'danger': 8,
#   'dawn': 2,
#   'dear': 4,
#   'deiti': 1,
#   'deploy': 1,
#   'deserv': 1,
#   'detail': 1,
#   'director': 1,
#   'disgust': 1,
#   'distanc': 1,
#   'district': 1,
#   'doctor': 2,
#   'door': 2,
#   'doug': 1,
#   'dragonboat': 1,
#   'dream': 1,
#   'duti': 4,
#   'earthquak': 1,
#   'emerg': 67,
#   'employe': 1,
#   'energi': 2,
#   'episod': 1,
#   'ethnic': 2,
#   'eudaimonia': 1,
#   'europ': 3,
#   'evarina': 1,
#   'everyday': 1,
#   'everyon': 3,
#   'everyth': 1,
#   'evil': 1,
#   'exhibit': 1,
#   'experi': 1,
#   'experiment': 1,
#   'explos': 1,
#   'fabric': 1,
#   'factsvsmyth': 2,
#   'famili': 5,
#   'fault': 1,
#   'feat': 1,
#   'felt': 2,
#   'festiv': 3,
#   'fight': 2,
#   'film': 1,
#   'fluid': 7,
#   'fluorid': 2,
#   'footag': 1,
#   'forc': 1,
#   'ford': 1,
#   'foreign': 2,
#   'foundat': 4,
#   'fram': 1,
#   'franc': 2,
#   'fraudster': 1,
#   'friend': 80,
#   'frontlin': 1,
#   'gandhi': 4,
#   'gari': 2,
#   'gether': 1,
#   'glad': 1,
#   'gloom': 2,
#   'goal': 2,
#   'gon': 1,
#   'good': 16,
#   'googl': 2,
#   'govind': 1,
#   'govt': 1,
#   'grabe': 1,
#   'great': 2,
#   'ground': 4,
#   'group': 4,
#   'guard': 32,
#   'gujjar': 1,
#   'gurgaon': 1,
#   'guzzler': 2,
#   'gym': 2,
#   'handl': 1,
#   'haridwar': 2,
#   'harvard': 1,
#   'hasn': 2,
#   'healthcar': 2,
#   'heart': 1,
#   'heiko': 1,
#   'help': 18,
#   'high': 1,
#   'hit': 1,
#   'home': 1,
#   'hoon': 1,
#   'hope': 3,
#   'hospit': 2,
#   'hugger': 1,
#   'hyderabad': 62,
#   'icraf': 1,
#   'ill': 1,
#   'incom': 1,
#   'increas': 1,
#   'india': 5,
#   'indira': 1,
#   'indo': 1,
#   'indonesia': 12,
#   'indoor': 2,
#   'infact': 1,
#   'infect': 1,
#   'inflat': 7,
#   'inject': 1,
#   'injuri': 2,
#   'innoc': 1,
#   'inspir': 2,
#   'institut': 4,
#   'intend': 1,
#   'interest': 1,
#   'interfer': 2,
#   'intezamia': 1,
#   'involv': 1,
#   'iowa': 1,
#   'ironi': 1,
#   'islam': 2,
#   'issuanc': 1,
#   'itun': 1,
#   'jail': 1,
#   'justic': 1,
#   'jyoti': 1,
#   'kalyan': 1,
#   'kent': 3,
#   'kitamura': 1,
#   'know': 2,
#   'kumbh': 37,
#   'kushan': 1,
#   'kutch': 1,
#   'lane': 1,
#   'leader': 1,
#   'leadership': 6,
#   'leak': 7,
#   'legit': 2,
#   'level': 4,
#   'life': 11,
#   'limelig': 1,
#   'live': 2,
#   'lond': 2,
#   'look': 6,
#   'lung': 3,
#   'maa': 1,
#   'maharashtra': 2,
#   'make': 3,
#   'malaysia': 13,
#   'manag': 4,
#   'mascara': 1,
#   'masjid': 1,
#   'mask': 24,
#   'mass': 1,
#   'mata': 4,
#   'math': 1,
#   'mathur': 1,
#   'mccd': 1,
#   'measur': 7,
#   'media': 4,
#   'mela': 6,
#   'mening': 7,
#   'mentalhealth': 1,
#   'method': 1,
#   'mexico': 12,
#   'migrant': 1,
#   'mild': 1,
#   'million': 1,
#   'minghao': 12,
#   'minor': 3,
#   'modern': 1,
#   'modishah': 15,
#   'molecul': 1,
#   'morn': 6,
#   'mortal': 1,
#   'motu': 1,
#   'muthuri': 1,
#   'nagar': 1,
#   'nagpur': 1,
#   'nalla': 1,
#   'nation': 6,
#   'navi': 1,
#   'need': 11,
#   'nehru': 4,
#   'netherland': 2,
#   'news': 2,
#   'next': 12,
#   'noth': 3,
#   'novemb': 2,
#   'number': 6,
#   'okay': 2,
#   'onlin': 2,
#   'ontario': 1,
#   'opposit': 8,
#   'order': 2,
#   'otherwis': 1,
#   'outbreak': 1,
#   'outdoor': 1,
#   'oximet': 1,
#   'pacif': 1,
#   'paint': 1,
#   'pakistan': 7,
#   'pandem': 4,
#   'part': 4,
#   'pass': 1,
#   'passport': 1,
#   'patient': 10,
#   'payment': 1,
#   'pedati': 1,
#   'peopl': 29,
#   'peshawar': 1,
#   'petit': 3,
#   'philippin': 12,
#   'phillipin': 1,
#   'physiotherapist': 2,
#   'pic': 6,
#   'place': 72,
#   'plasmadonor': 1,
#   'plea': 1,
#   'pleas': 103,
#   'pneumonia': 1,
#   'podcast': 2,
#   'poet': 2,
#   'poster': 1,
#   'prayer': 1,
#   'prepar': 4,
#   'prevent': 2,
#   'price': 2,
#   'prioriti': 1,
#   'prison': 2,
#   'privaci': 2,
#   'problem': 4,
#   'professor': 3,
#   'pub': 3,
#   'pubm': 6,
#   'purpos': 1,
#   'rajasthan': 1,
#   'ralli': 1,
#   'rann': 1,
#   'read': 3,
#   'realiti': 1,
#   'reason': 1,
#   'recent': 3,
#   'remdesivir': 2,
#   'remdesvir': 1,
#   'report': 2,
#   'requir': 64,
#   'respir': 1,
#   'result': 2,
#   'risk': 5,
#   'rmaf': 1,
#   'ro': 1,
#   'role': 2,
#   'romero': 1,
#   'rosagh': 1,
#   'royalmalaysianairforc': 1,
#   'rule': 1,
#   'sath': 1,
#   'sathidar': 2,
#   'scenario': 4,
#   'school': 3,
#   'search': 1,
#   'secur': 1,
#   'see': 1,
#   'shahi': 1,
#   'shift': 21,
#   'shigeru': 1,
#   'shouldn': 1,
#   'sidebysid': 12,
#   'sigh': 1,
#   'sign': 1,
#   'signific': 1,
#   'situat': 2,
#   'snan': 1,
#   'someon': 1,
#   'sonia': 1,
#   'sorri': 4,
#   'southkorea': 1,
#   'sport': 3,
#   'spread': 4,
#   'standard': 2,
#   'state': 4,
#   'stay': 3,
#   'storm': 2,
#   'student': 1,
#   'studi': 2,
#   'suck': 2,
#   'suggest': 1,
#   'suicid': 3,
#   'sunlight': 1,
#   'suprem': 1,
#   'surpris': 1,
#   'system': 1,
#   'tabl': 1,
#   'technic': 1,
#   'technolog': 1,
#   'teja': 1,
#   'test': 35,
#   'testimoni': 1,
#   'thane': 1,
#   'them': 2,
#   'thing': 1,
#   'third': 1,
#   'thought': 2,
#   'tip': 1,
#   'tori': 2,
#   'trace': 3,
#   'track': 2,
#   'transmiss': 2,
#   'transplant': 1,
#   'trust': 64,
#   'tsunami': 1,
#   'tue': 2,
#   'tuesday': 2,
#   'type': 3,
#   'uccsrckocc': 1,
#   'ugadi': 1,
#   'univers': 1,
#   'updat': 2,
#   'utah': 1,
#   'variant': 3,
#   'viewpoint': 1,
#   'vira': 2,
#   'virasathidar': 2,
#   'viru': 6,
#   'vizag': 1,
#   'voluntari': 1,
#   'vulner': 2,
#   'wale': 2,
#   'wandsworth': 1,
#   'want': 2,
#   'watch': 1,
#   'way': 1,
#   'wear': 1,
#   'week': 1,
#   'well': 1,
#   'whilst': 1,
#   'whistleblow': 1,
#   'woman': 1,
#   'women': 1,
#   'woohooo': 1,
#   'work': 10,
#   'worker': 3,
#   'worldwid': 12,
#   'would': 2,
#   'yawa': 1,
#   'year': 9,
#   'yogicm': 15,
#   'yogurt': 1,
#   'youth': 1},
#  {'abs': 1,
#   'absenc': 1,
#   'action': 1,
#   'addmiss': 2,
#   'adult': 1,
#   'agre': 1,
#   'aguila': 1,
#   'alert': 1,
#   'alissa': 4,
#   'alot': 1,
#   'amou': 1,
#   'announc': 1,
#   'antibrahmanismvaccinefestiv': 2,
#   'anticult': 1,
#   'anyon': 7,
#   'appeal': 3,
#   'april': 4,
#   'arclight': 1,
#   'arvind': 11,
#   'ashwani': 1,
#   'assess': 13,
#   'assessm': 2,
#   'asthma': 2,
#   'attitud': 1,
#   'awar': 1,
#   'back': 1,
#   'bag': 2,
#   'baha': 1,
#   'baiskhi': 1,
#   'banelectionralliesincovid': 1,
#   'barrel': 2,
#   'basi': 1,
#   'be': 1,
#   'becom': 5,
#   'better': 1,
#   'between': 2,
#   'board': 103,
#   'boardexam': 3,
#   'bodi': 4,
#   'book': 11,
#   'borough': 1,
#   'break': 1,
#   'busi': 1,
#   'california': 1,
#   'cancel': 23,
#   'cancelboardexam': 44,
#   'cancelcbseboard': 4,
#   'cancleboardexam': 5,
#   'candid': 3,
#   'care': 2,
#   'carphon': 1,
#   'case': 42,
#   'caus': 5,
#   'cbsc': 1,
#   'cbse': 106,
#   'cbseboardexam': 1,
#   'cbsenew': 3,
#   'centr': 8,
#   'central': 1,
#   'chahe': 5,
#   'chattisgarh': 1,
#   'check': 1,
#   'children': 2,
#   'citi': 1,
#   'class': 9,
#   'cleaner': 1,
#   'clinic': 6,
#   'club': 4,
#   'colleagu': 8,
#   'colleg': 3,
#   'come': 2,
#   'compani': 3,
#   'concern': 1,
#   'construct': 1,
#   'contain': 1,
#   'control': 4,
#   'corona': 6,
#   'coronaviru': 2,
#   'corpor': 3,
#   'counti': 7,
#   'countri': 3,
#   'coup': 4,
#   'coupon': 2,
#   'covid': 100,
#   'cunt': 1,
#   'cure': 3,
#   'danish': 1,
#   'day': 2,
#   'delh': 2,
#   'delhi': 76,
#   'deliveri': 3,
#   'dessis': 12,
#   'didi': 3,
#   'discount': 1,
#   'doctor': 4,
#   'dorada': 1,
#   'dumb': 1,
#   'econom': 4,
#   'educ': 6,
#   'effect': 1,
#   'effort': 18,
#   'email': 1,
#   'embol': 3,
#   'equiti': 2,
#   'evalu': 1,
#   'event': 3,
#   'everyon': 7,
#   'everythi': 1,
#   'exam': 41,
#   'examinat': 1,
#   'exposur': 2,
#   'fabindia': 1,
#   'failur': 3,
#   'farmer': 2,
#   'fatigu': 2,
#   'figur': 8,
#   'film': 1,
#   'find': 2,
#   'forget': 3,
#   'forign': 2,
#   'form': 3,
#   'friday': 7,
#   'full': 2,
#   'gaff': 5,
#   'garbada': 1,
#   'garbag': 2,
#   'gender': 2,
#   'genom': 1,
#   'genos': 3,
#   'gentleman': 1,
#   'georg': 2,
#   'govern': 14,
#   'governmen': 1,
#   'gran': 5,
#   'group': 1,
#   'guess': 3,
#   'guidanc': 1,
#   'gun': 1,
#   'gupta': 1,
#   'gut': 1,
#   'guy': 1,
#   'hand': 4,
#   'haul': 1,
#   'heart': 2,
#   'heat': 1,
#   'hell': 1,
#   'hello': 1,
#   'hematologist': 3,
#   'high': 1,
#   'higher': 2,
#   'hindu': 10,
#   'hirpara': 1,
#   'histori': 5,
#   'homag': 1,
#   'home': 10,
#   'hospit': 8,
#   'hotlin': 5,
#   'hotspot': 1,
#   'hour': 16,
#   'husband': 6,
#   'hyster': 1,
#   'ibdp': 1,
#   'ics': 1,
#   'ideal': 1,
#   'inadequ': 2,
#   'independ': 5,
#   'india': 49,
#   'infect': 1,
#   'inhal': 2,
#   'inspir': 1,
#   'inter': 1,
#   'issu': 1,
#   'jallianw': 1,
#   'jallianwalabagh': 5,
#   'jean': 1,
#   'jgfyubhfnbfk': 1,
#   'just': 6,
#   'justifi': 2,
#   'karnataka': 1,
#   'karo': 1,
#   'kejriw': 15,
#   'kerala': 10,
#   'kid': 4,
#   'kochi': 1,
#   'kozhikod': 1,
#   'lakh': 3,
#   'lancet': 2,
#   'land': 1,
#   'least': 1,
#   'life': 3,
#   'link': 9,
#   'live': 12,
#   'liverpool': 2,
#   'lmao': 1,
#   'loan': 1,
#   'long': 1,
#   'look': 2,
#   'machi': 3,
#   'machineri': 2,
#   'maharaja': 1,
#   'maharashtra': 14,
#   'maheshbabu': 1,
#   'mail': 1,
#   'mamta': 3,
#   'mandatori': 1,
#   'marco': 3,
#   'mark': 2,
#   'martyr': 2,
#   'massacr': 2,
#   'match': 2,
#   'may': 1,
#   'mcnamara': 1,
#   'med': 1,
#   'meet': 1,
#   'meme': 1,
#   'mess': 2,
#   'method': 1,
#   'methodolog': 1,
#   'middl': 5,
#   'million': 1,
#   'minist': 1,
#   'minster': 1,
#   'minut': 4,
#   'mist': 2,
#   'mock': 2,
#   'mode': 12,
#   'moham': 2,
#   'monitor': 1,
#   'month': 1,
#   'moron': 1,
#   'mortal': 2,
#   'motherfuck': 1,
#   'motherland': 1,
#   'mppsc': 2,
#   'mull': 2,
#   'mum': 1,
#   'mumbai': 2,
#   'mumbaikar': 3,
#   'myanmar': 7,
#   'myopinion': 1,
#   'natio': 1,
#   'nation': 7,
#   'naturopathi': 1,
#   'nece': 8,
#   'neocoloni': 1,
#   'never': 1,
#   'news': 3,
#   'nice': 1,
#   'nostalgia': 1,
#   'notic': 1,
#   'oblivion': 1,
#   'offer': 1,
#   'offlin': 10,
#   'onlin': 3,
#   'opinion': 1,
#   'ordin': 1,
#   'oregonian': 1,
#   'organis': 6,
#   'osaka': 8,
#   'overpopul': 3,
#   'oxid': 1,
#   'paragraph': 3,
#   'parent': 10,
#   'parti': 6,
#   'particip': 1,
#   'partnership': 2,
#   'passinterstud': 1,
#   'passion': 1,
#   'patient': 6,
#   'pawankalyan': 1,
#   'payment': 3,
#   'pehlejaanfirexam': 1,
#   'peopl': 18,
#   'person': 1,
#   'petit': 1,
#   'phone': 1,
#   'photo': 6,
#   'pilot': 1,
#   'piro': 4,
#   'plan': 1,
#   'planet': 1,
#   'player': 3,
#   'plead': 7,
#   'pleas': 9,
#   'plss': 1,
#   'pmmodi': 1,
#   'polic': 5,
#   'polici': 6,
#   'polit': 3,
#   'politician': 2,
#   'popul': 1,
#   'pork': 2,
#   'post': 2,
#   'postpon': 8,
#   'postpond': 1,
#   'postponeboardexam': 1,
#   'postponeneetpg': 2,
#   'power': 1,
#   'prabha': 1,
#   'practic': 8,
#   'pradesh': 1,
#   'prasad': 1,
#   'pre': 12,
#   'prefer': 1,
#   'pressur': 5,
#   'princephilip': 1,
#   'problem': 2,
#   'profit': 2,
#   'project': 4,
#   'protect': 1,
#   'protest': 3,
#   'proud': 1,
#   'provinc': 6,
#   'pune': 6,
#   'punjab': 4,
#   'queenelizabeth': 1,
#   'rakesh': 1,
#   'rapid': 4,
#   'rashtra': 7,
#   'reall': 1,
#   'redund': 1,
#   'remuner': 1,
#   'repeat': 1,
#   'report': 4,
#   'repres': 1,
#   'represent': 1,
#   'request': 2,
#   'research': 9,
#   'resid': 1,
#   'respons': 1,
#   'result': 10,
#   'retweet': 1,
#   'rink': 8,
#   'rise': 5,
#   'risk': 3,
#   'robot': 1,
#   'rule': 5,
#   'runway': 1,
#   'rupaniji': 1,
#   'sager': 1,
#   'sake': 1,
#   'salah': 2,
#   'sar': 1,
#   'sarscov': 1,
#   'say': 2,
#   'school': 11,
#   'seriou': 1,
#   'session': 8,
#   'sex': 1,
#   'sharam': 1,
#   'share': 4,
#   'shot': 4,
#   'sign': 1,
#   'situat': 10,
#   'skater': 16,
#   'some': 1,
#   'someon': 5,
#   'someth': 1,
#   'sourc': 1,
#   'spray': 2,
# ...
#   'rycroft': 1,
#   'sakariya': 1,
#   'sarita': 4,
#   'saveindi': 1,
#   'scaremong': 1,
#   'scotland': 4,
#   'scream': 1,
#   'second': 14,
#   'selfi': 1,
#   'selfish': 1,
#   'sent': 1,
#   'seri': 2,
#   'server': 1,
#   'servic': 1,
#   'sever': 2,
#   'seychel': 1,
#   'shahrukhkhan': 1,
#   'sharif': 1,
#   'shot': 2,
#   'shouldn': 1,
#   'shower': 1,
#   'sign': 10,
#   'simpl': 1,
#   'sirji': 1,
#   'site': 1,
#   'slot': 1,
#   'snapper': 1,
#   'soap': 1,
#   'someon': 7,
#   'somerset': 1,
#   'songkran': 1,
#   'sort': 1,
#   'spat': 2,
#   'spectrum': 1,
#   'spokesperson': 1,
#   'spread': 4,
#   'spring': 2,
#   'sra': 1,
#   'sreedharan': 3,
#   'stan': 2,
#   'startup': 1,
#   'starv': 3,
#   'state': 7,
#   'step': 2,
#   'stori': 8,
#   'stress': 1,
#   'sub': 1,
#   'subsid': 2,
#   'suffer': 1,
#   'support': 8,
#   'surg': 4,
#   'surpris': 2,
#   'syndrom': 1,
#   'tablighi': 2,
#   'talaga': 1,
#   'target': 5,
#   'team': 1,
#   'tell': 4,
#   'tension': 1,
#   'terror': 2,
#   'thank': 22,
#   'their': 1,
#   'theme': 1,
#   'think': 1,
#   'thoma': 1,
#   'thousand': 2,
#   'thur': 1,
#   'tikautsav': 4,
#   'time': 3,
#   'timelin': 1,
#   'today': 19,
#   'toll': 5,
#   'ton': 3,
#   'tool': 1,
#   'tori': 1,
#   'total': 1,
#   'tournament': 1,
#   'tracker': 16,
#   'tradit': 1,
#   'tran': 1,
#   'travel': 1,
#   'treatment': 3,
#   'trend': 1,
#   'trophi': 1,
#   'truth': 1,
#   'twitter': 1,
#   'uccsrckocc': 1,
#   'unemploy': 2,
#   'uniti': 3,
#   'updat': 21,
#   'upsurg': 2,
#   'urgent': 2,
#   'usa': 1,
#   'user': 1,
#   'vaccin': 98,
#   'vaccineswork': 1,
#   'version': 1,
#   'victoria': 1,
#   'video': 5,
#   'view': 1,
#   'vihar': 4,
#   'violenc': 1,
#   'viru': 7,
#   'visit': 2,
#   'visual': 3,
#   'vivid': 1,
#   'voic': 4,
#   'volunt': 6,
#   'wage': 4,
#   'wahiduddin': 4,
#   'wait': 1,
#   'wale': 1,
#   'webinar': 1,
#   'websit': 4,
#   'week': 14,
#   'wherea': 1,
#   'whistl': 1,
#   'winner': 1,
#   'wise': 1,
#   'women': 2,
#   'word': 3,
#   'worker': 3,
#   'world': 33,
#   'worldmort': 1,
#   'worldpolit': 1,
#   'year': 22,
#   'york': 2,
#   'young': 1,
#   'youtub': 1},
#  {'aapko': 1,
#   'achiev': 1,
#   'album': 1,
#   'bed': 6,
#   'bihar': 1,
#   'board': 268,
#   'cancel': 269,
#   'cancelboardexam': 2,
#   'carrier': 1,
#   'cbse': 2,
#   'charg': 1,
#   'circumst': 1,
#   'conduct': 1,
#   'covid': 280,
#   'date': 1,
#   'dear': 7,
#   'doe': 1,
#   'doesn': 1,
#   'english': 1,
#   'exam': 538,
#   'ferreira': 1,
#   'hain': 1,
#   'harass': 1,
#   'hindi': 1,
#   'hotspot': 1,
#   'human': 2,
#   'idea': 1,
#   'india': 2,
#   'kannada': 1,
#   'karnataka': 7,
#   'languag': 2,
#   'live': 1,
#   'mbb': 3,
#   'mla': 1,
#   'muh': 1,
#   'nahi': 1,
#   'nee': 1,
#   'need': 6,
#   'neet': 2,
#   'norm': 2,
#   'opportun': 1,
#   'pata': 1,
#   'phir': 1,
#   'pod': 1,
#   'refund': 1,
#   'rest': 1,
#   'risk': 1,
#   'sabhi': 262,
#   'satur': 6,
#   'sound': 1,
#   'standard': 1,
#   'stil': 1,
#   'stud': 1,
#   'student': 274,
#   'that': 1,
#   'warrior': 1,
#   'whattt': 1,
#   'whistleblow': 2,
#   'who': 1},
#  {'aajkal': 2,
#   'aakhri': 1,
#   'aayog': 1,
#   'abdul': 1,
#   'acco': 1,
#   'account': 1,
#   'achiev': 1,
#   'action': 1,
#   'actor': 1,
#   'adani': 1,
#   'adhikari': 1,
#   'admiss': 1,
#   'admit': 1,
#   'african': 2,
#   'agnat': 2,
#   'agre': 2,
#   'ahamedabad': 1,
#   'ahm': 5,
#   'ahmadiya': 10,
#   'aipc': 1,
#   'album': 1,
#   'allerton': 1,
#   'allianc': 1,
#   'ambul': 1,
#   'america': 4,
#   'amid': 1,
#   'analysi': 3,
#   'anand': 1,
#   'anchor': 1,
#   'anim': 2,
#   'anniv': 1,
#   'announc': 2,
#   'antoni': 2,
#   'apn': 2,
#   'app': 1,
#   'appeas': 3,
#   'appl': 2,
#   'applicat': 2,
#   'approv': 3,
#   'april': 5,
#   'arabia': 5,
#   'area': 1,
#   'arirang': 1,
#   'art': 1,
#   'artifici': 1,
#   'arvindkejriw': 1,
#   'arya': 1,
#   'asia': 8,
#   'ask': 2,
#   'assam': 2,
#   'assist': 1,
#   'audit': 3,
#   'avail': 1,
#   'back': 1,
#   'baisakhi': 2,
#   'balasaheb': 1,
#   'bana': 3,
#   'banerji': 1,
#   'bangladesh': 1,
#   'bank': 1,
#   'bann': 2,
#   'bar': 4,
#   'barbado': 2,
#   'basic': 1,
#   'beach': 2,
#   'bean': 1,
#   'becker': 1,
#   'bed': 1,
#   'beer': 1,
#   'bengal': 6,
#   'best': 1,
#   'bestfanarmi': 1,
#   'beyond': 4,
#   'bhaskar': 1,
#   'bhavan': 2,
#   'biden': 1,
#   'biggest': 1,
#   'bihu': 1,
#   'bill': 2,
#   'billion': 1,
#   'birth': 1,
#   'block': 2,
#   'blockbust': 2,
#   'blood': 1,
#   'board': 12,
#   'boat': 2,
#   'bodi': 5,
#   'bollywood': 1,
#   'brahma': 1,
#   'breach': 2,
#   'break': 3,
#   'breakingnew': 2,
#   'breat': 1,
#   'brgi': 1,
#   'broadband': 1,
#   'broke': 6,
#   'buddhist': 1,
#   'build': 1,
#   'bulli': 5,
#   'burgo': 1,
#   'busi': 1,
#   'bylin': 2,
#   'cabinet': 1,
#   'cadacad': 1,
#   'call': 2,
#   'cambodia': 1,
#   'cameron': 1,
#   'canada': 1,
#   'cancel': 6,
#   'cancelboa': 1,
#   'cancelboard': 1,
#   'cancelboardexam': 9,
#   'candl': 1,
#   'cant': 1,
#   'capf': 1,
#   'case': 25,
#   'cbse': 6,
#   'celebr': 3,
#   'centr': 6,
#   'central': 4,
#   'chairman': 1,
#   'chaitra': 2,
#   'chakrabar': 1,
#   'champion': 1,
#   'chand': 2,
#   'chang': 1,
#   'charg': 1,
#   'cheiraoba': 2,
#   'cheti': 2,
#   'chhattisgarh': 1,
#   'chidambaram': 1,
#   'china': 4,
#   'chine': 1,
#   'cholera': 12,
#   'christin': 3,
#   'churayi': 1,
#   'church': 1,
#   'cipolla': 3,
#   'citizen': 4,
#   'class': 2,
#   'clear': 1,
#   'climat': 1,
#   'clinic': 2,
#   'club': 3,
#   'coalfield': 1,
#   'collect': 4,
#   'color': 1,
#   'commiss': 5,
#   'compani': 2,
#   'compar': 2,
#   'competit': 1,
#   'compon': 2,
#   'congratul': 2,
#   'congreg': 4,
#   'congress': 7,
#   'consid': 1,
#   'consult': 1,
#   'continu': 3,
#   'cool': 2,
#   'coron': 1,
#   'corona': 4,
#   'coronaviru': 1,
#   'count': 6,
#   'counti': 2,
#   'countri': 4,
#   'courier': 2,
#   'cours': 1,
#   'court': 5,
#   'cover': 3,
#   'coverag': 4,
#   'covi': 6,
#   'covid': 98,
#   'covidvaccin': 1,
#   'credit': 1,
#   'cremat': 1,
#   'crime': 7,
#   'crisi': 1,
#   'crowd': 1,
#   'crusad': 1,
#   'cure': 1,
#   'curfew': 2,
#   'custom': 1,
#   'daili': 2,
#   'danger': 2,
#   'dark': 2,
#   'dashboar': 1,
#   'data': 1,
#   'date': 3,
#   'dawn': 1,
#   'day': 7,
#   'deal': 1,
#   'dear': 2,
#   'dearborn': 1,
#   'death': 12,
#   'debat': 1,
#   'declar': 1,
#   'deepak': 1,
#   'delhi': 3,
#   'delhit': 1,
#   'delv': 1,
#   'demand': 3,
#   'dharampura': 3,
#   'diagnosi': 2,
#   'diagnost': 3,
#   'didrutokillkenei': 1,
#   'digit': 3,
#   'dimaag': 2,
#   'director': 4,
#   'discours': 2,
#   'diseas': 2,
#   'dispos': 2,
#   'distribut': 2,
#   'district': 3,
#   'divers': 1,
#   'do': 1,
#   'doctor': 2,
#   'doesn': 6,
#   'dominica': 2,
#   'donat': 1,
#   'dose': 1,
#   'doubt': 2,
#   'dream': 3,
#   'dress': 1,
#   'drink': 1,
#   'drive': 2,
#   'econom': 1,
#   'educ': 3,
#   'edvig': 1,
#   'elect': 8,
#   'electr': 1,
#   'emerg': 4,
#   'emma': 1,
#   'enemi': 1,
#   'energi': 1,
#   'engin': 1,
#   'english': 4,
#   'enough': 2,
#   'epidem': 6,
#   'episod': 1,
#   'erupt': 2,
#   'esm': 1,
#   'event': 1,
#   'everywher': 2,
#   'exam': 28,
#   'expand': 1,
#   'expert': 1,
#   'explain': 1,
#   'extr': 1,
#   'extra': 1,
#   'facebook': 1,
#   'fact': 6,
#   'fail': 1,
#   'famili': 1,
#   'fan': 1,
#   'fast': 3,
#   'fatal': 1,
#   'fear': 1,
#   'feel': 4,
#   'fema': 1,
#   'fertil': 1,
#   'festiv': 2,
#   'file': 1,
#   'film': 2,
#   'final': 1,
#   'find': 1,
#   'fine': 2,
#   'fintech': 1,
#   'fire': 2,
#   'firm': 2,
#   'first': 2,
#   'fiscal': 1,
#   'fit': 1,
#   'fittim': 1,
#   'flood': 2,
#   'focu': 2,
#   'food': 9,
#   'foodmarket': 1,
#   'forc': 3,
#   'forecast': 2,
#   'foreign': 2,
#   'former': 1,
#   'founder': 5,
#   'fourth': 1,
#   'franc': 1,
#   'fraud': 5,
#   'free': 1,
#   'friday': 1,
#   'frien': 1,
#   'friend': 5,
#   'from': 3,
#   'fuel': 1,
#   'fund': 4,
#   'gadkari': 3,
#   'gajanan': 1,
#   'gandhi': 3,
#   'gandhina': 1,
#   'garden': 3,
#   'gather': 1,
#   'gaurav': 1,
#   'gcash': 1,
#   'gener': 3,
#   'geneva': 3,
#   'germani': 1,
#   'ghaziabad': 1,
#   'ghoom': 1,
#   'ghulam': 5,
#   'give': 2,
#   'given': 3,
#   'global': 5,
#   'globe': 1,
#   'go': 1,
#   'godi': 3,
#   'golf': 1,
#   'good': 1,
#   'googl': 2,
#   'govern': 14,
#   'govt': 6,
#   'greensil': 2,
#   'greet': 3,
#   'group': 1,
#   'grow': 3,
#   'growth': 1,
#   'guatemala': 1,
#   'gudi': 3,
#   'gudipadwa': 1,
#   'guidelin': 1,
#   'gujarat': 3,
#   'haft': 1,
#   'happi': 3,
#   'hardwar': 1,
#   'haridwar': 1,
#   'haryana': 3,
#   'hazrat': 1,
#   'head': 1,
#   'health': 9,
#   'healthcar': 3,
#   'heard': 1,
#   'heart': 1,
#   'help': 1,
#   'high': 4,
#   'hindu': 9,
#   'histori': 4,
#   'hitler': 1,
#   'hogayi': 1,
#   'holi': 1,
#   'homag': 1,
#   'home': 3,
#   'hooda': 1,
#   'hospit': 4,
#   'hotel': 3,
#   'hotspot': 2,
#   'hous': 2,
#   'howcanihelp': 1,
#   'hunger': 1,
#   'hyderabad': 2,
#   'ill': 1,
#   'illus': 1,
#   'imag': 4,
#   'imagin': 1,
#   'impa': 1,
#   'impact': 2,
#   'import': 1,
#   'importan': 1,
#   'increas': 1,
#   'index': 1,
#   'india': 62,
#   'indiabloom': 1,
#   'indic': 1,
#   'indonesia': 1,
#   'indrani': 1,
#   'indrapuram': 1,
#   'industri': 1,
#   'indvpak': 1,
#   'inefficac': 1,
#   'infect': 2,
#   'inocul': 1,
#   'inquiri': 6,
#   'intellig': 3,
#   'interest': 2,
#   'intern': 1,
#   'internala': 1,
#   'internalass': 3,
#   'interven': 1,
#   'interview': 1,
#   'invit': 2,
#   'irani': 2,
#   'ironi': 1,
#   'ism': 1,
#   'issu': 4,
#   'itali': 1,
#   'italian': 1,
#   'jab': 2,
#   'jagatpita': 1,
#   'jaguar': 1,
#   'jaipuria': 1,
#   'jakrif': 1,
#   'jaleel': 1,
#   'jamaat': 3,
#   'jamat': 2,
#   'jammat': 1,
#   'jeff': 1,
#   'jihad': 2,
#   'join': 2,
#   'joke': 1,
#   'jone': 1,
#   'journal': 2,
#   'journalist': 2,
#   'judg': 2,
#   'junk': 1,
#   'just': 4,
#   'jwaab': 2,
#   'kaithal': 3,
#   'kanhaiya': 1,
#   'karlo': 3,
#   'karnan': 2,
#   'keep': 3,
#   'kept': 1,
#   'kerala': 3,
#   'kheer': 1,
#   'khule': 1,
#   'kind': 1,
#   'kingdom': 1,
#   'kisn': 1,
#   'kit': 1,
#   'kitn': 1,
#   'know': 2,
#   'korea': 2,
#   'krte': 2,
#   'ksum': 1,
#   'kumar': 2,
#   'kumbh': 9,
#   'kumbhm': 1,
#   'kunjam': 1,
#   'kuwait': 5,
#   'label': 2,
#   'lahor': 2,
#   'lake': 1,
#   'lakh': 1,
#   'lallagud': 1,
#   'land': 1,
#   'latest': 1,
#   'leader': 1,
#   'learn': 2,
#   'lekhram': 5,
#   'lepesadu': 2,
#   'less': 1,
#   'leta': 3,
#   'lete': 2,
#   'lethbridg': 1,
#   'letter': 1,
#   'life': 1,
#   'light': 2,
#   'like': 2,
#   'line': 1,
#   'live': 2,
#   'liy': 2,
#   'lobo': 1,
#   'loboan': 1,
#   'lockdown': 2,
#   'lokayukta': 1,
#   'lucia': 2,
#   'lumpi': 1,
#   'luthor': 1,
#   'lutyensmedia': 1,
#   'machin': 3,
#   'made': 1,
#   'madhya': 2,
#   'maha': 1,
#   'maharashtra': 4,
#   'major': 2,
#   'make': 1,
#   'mall': 1,
#   'mallya': 1,
#   'manag': 4,
#   'manchest': 1,
#   'mandir': 1,
#   'mani': 1,
#   'manor': 1,
#   'march': 2,
#   'markaz': 2,
#   'market': 6,
#   'martin': 1,
#   'mask': 1,
#   'master': 1,
#   'mathew': 1,
#   'maul': 1,
#   'mayor': 1,
#   'media': 5,
#   'meet': 3,
#   'mela': 8,
#   'member': 2,
#   'messag': 3,
#   'michael': 1,
#   'midnight': 1,
#   'million': 4,
#   'mini': 1,
#   'minist': 15,
#   'minor': 1,
#   'minut': 2,
#   'mirza': 5,
#   'mobil': 2,
#   'model': 2,
#   'modi': 5,
#   'mombasa': 2,
#   'money': 2,
#   'most': 2,
#   'motor': 1,
#   'movement': 6,
#   'movi': 2,
#   'mrna': 1,
#   'mumbai': 3,
#   'muncip': 1,
#   'municip': 1,
#   'museum': 3,
#   'muslim': 6,
#   'mva': 3,
#   'nadu': 1,
#   'nairobi': 2,
#   'nanosci': 1,
#   'narendra': 3,
#   'nation': 1,
#   'natur': 3,
#   'navalt': 1,
#   'navratri': 1,
#   'navreh': 3,
#   'naxalit': 1,
#   'neend': 1,
#   'neighborhood': 1,
#   'new': 8,
#   'news': 4,
#   'newyear': 1,
#   'ngo': 1,
#   'night': 2,
#   'niti': 1,
#   'nitin': 3,
#   'nizamuddin': 1,
#   'normal': 1,
#   'observ': 1,
#   'offer': 1,
#   'offic': 3,
#   'offici': 3,
#   'offlin': 3,
#   'onli': 2,
#   'onlin': 4,
#   'open': 2,
#   'order': 2,
#   'organ': 1,
#   'organis': 1,
#   'other': 1,
#   'ourfrontdoortoyour': 1,
#   'outdoor': 3,
#   'outsid': 1,
#   'oxygen': 1,
#   'pachadi': 1,
#   'pacif': 3,
#   'padwa': 2,
#   'pakistan': 4,
#   'pakvind': 1,
#   'palm': 2,
#   'pandem': 8,
#   'pandit': 5,
#   'panel': 2,
#   'parent': 3,
#   'parikshapecharcha': 2,
#   'parisha': 1,
#   'parti': 2,
#   'particip': 1,
#   'pass': 1,
#   'patel': 5,
#   'patient': 1,
#   'peopl': 11,
#   'personnel': 2,
#   'petit': 1,
#   'pfizer': 1,
#   'photo': 1,
#   'pinarayi': 1,
#   'pitcher': 1,
#   'place': 1,
#   'plan': 1,
#   'plann': 2,
#   'plasma': 1,
#   'plastic': 2,
#   'plea': 1,
#   'pleas': 4,
#   'poco': 1,
#   'polic': 2,
#   'polici': 1,
#   'polit': 2,
#   'politician': 1,
#   'polythen': 2,
#   'popul': 2,
#   'port': 1,
#   'portal': 1,
#   'post': 1,
#   'postpaid': 1,
#   'practic': 3,
#   'pradesh': 2,
#   'prasad': 1,
#   'pray': 1,
#   'predict': 1,
#   'pregnanc': 1,
#   'prepaid': 1,
#   'presid': 4,
#   'prevent': 1,
#   'price': 1,
#   'prime': 2,
#   'prioriti': 3,
#   'prithvi': 1,
#   'priti': 5,
#   'privaci': 2,
#   'proce': 1,
#   'product': 1,
#   'prof': 1,
#   'profession': 2,
#   'program': 2,
#   'properli': 2,
#   'prorgramm': 1,
#   'pubg': 3,
#   'public': 4,
#   'puddin': 1,
#   'pump': 1,
#   'pure': 1,
#   'push': 1,
#   'pushkar': 2,
#   'puthandu': 1,
#   'putin': 1,
#   'question': 2,
#   'quicker': 1,
#   'race': 1,
#   'racism': 5,
#   'rage': 1,
#   'raisina': 3,
#   'rajasthan': 1,
#   'rajgop': 1,
#   'ralli': 3,
#   'ramadan': 1,
#   'rampag': 2,
#   'rana': 1,
#   'ranganathan': 1,
#   'rate': 3,
#   'ravish': 1,
#   'rawat': 3,
#   'reaction': 1,
#   'read': 4,
#   'realm': 1,
#   'reason': 1,
#   'record': 6,
#   'recoveri': 1,
#   'redd': 1,
#   'reflect': 1,
#   'region': 8,
#   'registrati': 1,
#   'reliant': 1,
#   'relief': 1,
#   'remark': 2,
#   'replac': 1,
#   'repo': 1,
#   'report': 6,
#   'request': 2,
#   'requir': 1,
#   'research': 1,
#   'reserv': 1,
#   'respon': 5,
#   'rest': 1,
#   'restaur': 5,
#   'restrict': 1,
#   'resum': 1,
#   'retail': 1,
#   'retweet': 1,
#   'reveal': 3,
#   'review': 2,
#   'rich': 1,
#   'riot': 2,
#   'rise': 1,
#   'risk': 1,
#   'roll': 1,
#   'roof': 3,
#   'room': 1,
#   'rover': 1,
#   'rule': 1,
#   'russia': 5,
#   'safe': 1,
#   'sajibu': 2,
#   'salaam': 1,
#   'sale': 3,
#   'samson': 2,
#   'sanam': 1,
#   'sanchi': 2,
#   'sanju': 1,
#   'sarang': 3,
#   'saudi': 5,
#   'say': 1,
#   'scania': 6,
#   'scapegoat': 2,
#   'scare': 5,
#   'scarecrow': 1,
#   'school': 6,
#   'scientist': 1,
#   'search': 1,
#   'season': 1,
#   'seater': 1,
#   'secret': 1,
#   'secur': 1,
#   'seek': 1,
#   'seeker': 1,
#   'self': 3,
#   'sena': 1,
#   'senior': 1,
#   'sens': 5,
#   'sentenc': 2,
#   'serco': 2,
#   'servic': 8,
#   'shahi': 2,
#   'share': 1,
#   'shaw': 1,
#   'shit': 1,
#   'shiv': 1,
#   'shore': 1,
#   'shortag': 1,
#   'shot': 2,
#   'should': 3,
#   'shouldn': 1,
#   'shri': 2,
#   'sikh': 1,
#   'silli': 1,
#   'singapor': 1,
#   'singh': 4,
#   'singl': 1,
#   'singlif': 1,
#   'situat': 3,
#   'sixth': 6,
#   'skill': 1,
#   'slow': 2,
#   'slowest': 3,
#   'smile': 1,
#   'smriti': 2,
#   'snan': 2,
#   'solar': 2,
#   'solo': 1,
#   'someon': 1,
#   'son': 3,
#   'sonia': 3,
#   'sourc': 1,
#   'south': 7,
#   'southkorea': 1,
#   'speak': 1,
#   'speakupforvacci': 1,
#   'spec': 1,
#   'special': 3,
#   'speech': 1,
#   'spineless': 1,
#   'spot': 2,
#   'spread': 5,
#   'spreader': 4,
#   'spring': 1,
#   'sprout': 1,
#   'staff': 2,
#   'startup': 3,
#   'stat': 1,
#   'state': 23,
#   'stay': 2,
#   'stem': 1,
#   'stop': 2,
#   'stori': 2,
#   'strongli': 1,
#   'structur': 1,
#   'student': 8,
#   'sturgeon': 3,
#   'suitabl': 2,
#   'sukka': 1,
#   'sukladi': 2,
#   'suna': 1,
#   'super': 4,
#   'surat': 2,
#   'surg': 1,
#   'surgeri': 1,
#   'suriya': 1,
#   'surviv': 1,
#   'sustain': 1,
#   'suvendu': 1,
#   'swaal': 2,
#   'swalanyeti': 1,
#   'swara': 1,
#   'system': 1,
#   'tablighi': 5,
#   'tablighijamaat': 1,
#   'take': 3,
#   'tamil': 2,
#   'task': 1,
#   'tata': 1,
#   'team': 5,
#   'teaser': 2,
#   'tech': 1,
#   'teekautsav': 1,
#   'templ': 1,
#   'tender': 1,
#   'teri': 1,
#   'test': 2,
#   'thackeray': 1,
#   'thanx': 1,
#   'that': 4,
#   'their': 1,
#   'these': 1,
#   'thi': 3,
#   'think': 4,
#   'till': 2,
#   'time': 14,
#   'tirath': 2,
#   'today': 4,
#   'toll': 1,
#   'tone': 2,
#   'took': 1,
#   'town': 1,
#   'track': 3,
#   'trailer': 4,
#   'trampstamp': 1,
#   'travel': 2,
#   'trend': 4,
#   'trophi': 1,
#   'trump': 2,
#   'trust': 1,
#   'tuesday': 1,
#   'tweet': 1,
#   'twin': 1,
#   'twiterr': 1,
#   'twitter': 3,
#   'uddhav': 1,
#   'ugadi': 5,
#   'uncertainti': 1,
#   'unit': 2,
#   'uniti': 1,
#   'univers': 1,
#   'updat': 5,
#   'urdu': 3,
#   'uthra': 1,
#   'uttarakhand': 3,
#   'vaadivaas': 1,
#   'vaccin': 16,
#   'vakeel': 1,
#   'vakeelsaab': 3,
#   'variant': 3,
#   'varun': 1,
#   'version': 1,
#   'victori': 2,
#   'vijayan': 1,
#   'villag': 5,
#   'vincent': 2,
#   'vishu': 3,
#   'vishwa': 1,
#   'voilenc': 1,
#   'volcano': 2,
#   'vote': 2,
#   'wait': 2,
#   'want': 3,
#   'ward': 2,
#   'warna': 2,
#   'watch': 1,
#   'water': 2,
#   'wave': 1,
#   'webinar': 1,
#   'wedn': 1,
#   'wednesday': 1,
#   'week': 6,
#   'weekend': 2,
#   'well': 2,
#   'west': 5,
#   'whaaat': 1,
#   'whatsapp': 1,
#   'wheein': 4,
#   'when': 1,
#   'where': 1,
#   'who': 1,
#   'wide': 2,
#   'wifi': 1,
#   'wild': 1,
#   'wildanim': 1,
#   'will': 1,
#   'wire': 1,
#   'within': 1,
#   'woman': 1,
#   'world': 6,
#   'worth': 1,
#   'yahan': 1,
#   'yeadon': 1,
#   'year': 3,
#   'yestarday': 1,
#   'yesterday': 2,
#   'yql': 1,
#   'zone': 1,
#   'zorawar': 1}]

# %%
top_index = doc_count.argsort()[-10:][::-1]

# %%
top_index = top_index.tolist()

# %%
top_index
# Out:
# [1, 7, 2, 3, 5, 6, 0, 8, 4, 9]

# %%
print('Most important Topics/clusters (by number of documents inside):', top_index)
# Out:
# Most important Topics/clusters (by number of documents inside): [1, 7, 2, 3, 5, 6, 0, 8, 4, 9]

# %%
def top_words(cluster_word_distribution, top_cluster, values):
    for cluster in top_cluster:
        sort_dicts =sorted(mgp.cluster_word_distribution[cluster].items(), key=lambda k: k[1], reverse=True)[:values]
        print("\nCluster %s : %s"%(cluster,sort_dicts))

# %%
top_words(mgp.cluster_word_distribution, top_index, 5)
# Out:
# Cluster 1 : [('covid', 158), ('india', 48), ('vaccin', 47), ('health', 32), ('case', 29)]
#
# Cluster 7 : [('covid', 210), ('vaccin', 98), ('peopl', 74), ('india', 70), ('book', 56)]
#
# Cluster 2 : [('vaccin', 134), ('india', 107), ('covid', 106), ('approv', 35), ('govt', 34)]
#
# Cluster 3 : [('covid', 149), ('india', 85), ('case', 62), ('test', 42), ('infect', 22)]
#
# Cluster 5 : [('cbse', 106), ('board', 103), ('covid', 100), ('student', 86), ('delhi', 76)]
#
# Cluster 6 : [('covid', 161), ('india', 72), ('vaccin', 65), ('ghana', 28), ('govern', 22)]
#
# Cluster 0 : [('covid', 129), ('centr', 80), ('delhi', 57), ('hot', 47), ('student', 44)]
#
# Cluster 8 : [('exam', 538), ('covid', 280), ('student', 274), ('cancel', 269), ('board', 268)]
#
# Cluster 4 : [('covid', 181), ('pleas', 103), ('friend', 80), ('place', 72), ('emerg', 67)]
#
# Cluster 9 : [('covid', 98), ('india', 62), ('exam', 28), ('case', 25), ('state', 23)]

# %%
#from topic_allocation import topic_attribution
topic = {}
topic_name = [ 'type 1',
               'type 2',
               'type 3',
               'type 4',
               'type 5',
               'type 6',
               'type 7',
               'type 8',
               'type 9',
               'type 10'
          
          ]
for i, topic_num in enumerate(top_index):
  topic[topic_num] = topic_name[i]

# %%
tokenized_text = tokenized_tweet

# %%
def create_topics_dataframe(data_text=data_text,  mgp=mgp, threshold=0.3, topic=topic, tokenized_text=tokenized_text):
    
    result = pd.DataFrame(columns=['Text', 'Topic', 'Tokenized-text'])
    print(data_text[0])
    i = 0
    for i, text in enumerate(data_text):
        
        result.at[i, 'Text'] = text
        result.at[i, 'Tokenized-text'] = tokenized_text[i]
        prob = mgp.choose_best_label(tokenized_text[i])
        if prob[1] >= threshold:
            result.at[i, 'Topic'] = topic[prob[0]]
        else:
            result.at[i, 'Topic'] = 'Other'
    return result

# %%
result = create_topics_dataframe(data_text=data_text, mgp=mgp, threshold=0.3, topic=topic, tokenized_text=tokenized_text)
result.head(15)
# Out:
# RT @Joydas: When Is the Last Election Rally of Narendra Modi in West Bengal? That’s the Day Election Commission will decide too many Covid…
#                                                  Text  ...                                     Tokenized-text
# 0   RT @Joydas: When Is the Last Election Rally of...  ...  [elect, ralli, narendra, modi, west, bengal, t...
# 1   RT @abir_1729: #cancelboardexam2021\n#cancelbo...  ...             [cancelboardexam, student, exam, date]
# 2   RT @LiveLawIndia: Can Centre Intervene If A St...  ...  [centr, interven, state, do, well, high, court...
# 3   RT @soompi: #GOT7's #BamBam Pauses Activities ...  ...  [got, bambam, paus, activ, staff, member, test...
# 4   RT @NagpurKaRajini: So Covid in Maharashtra sp...  ...  [covid, maharashtra, spread, modi, west, benga...
# 5   UK economy returns to growth despite Covid res...  ...                 [economi, growth, covid, restrict]
# 6   RT @PGaspirant7: #postponeneetpg \n@profplal\n...  ...    [postponeneetpg, covid, stay, surg, wait, surg]
# 7   RT @dinesh_sir: Thanks for taking decisions fo...  ...  [thank, decis, safeti, student, pictur, exam, ...
# 8   RT @Nher_who: Now that India is facing Second ...  ...  [india, second, covid, let, hope, fund, name, ...
# 9   RT @abcnews: Thousands of vulnerable Australia...  ...              [thousand, australian, covid, vaccin]
# 10  RT @Reuters: China reports 9 new COVID-19 case...  ...                       [china, report, covid, case]
# 11  RT @DrTeckKhong: I’ve been asked if I would co...  ...                         [clinic, colleagu, counti]
# 12  @XanderhalTV Didn't hear a peep out of these p...  ...        [didn, peopl, trump, covid, medicin, tissu]
# 13  RT @syahredzan: Make your cabinet smaller, rem...  ...                   [cabinet, envoy, minist, salari]
# 14  RT @DoraResists: @thomaskaine5 You couldn’t pa...  ...        [couldn, money, vacat, covid, trump, haven]
#
# [15 rows x 3 columns]

# %%
import plotly.express as px

fig = px.pie(result, names='Topic',  title='Topics', color_discrete_sequence=px.colors.sequential.Burg)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="ee5932c5-4b88-45b2-9c85-5736ff2edd26" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("ee5932c5-4b88-45b2-9c85-5736ff2edd26")) {
#                     Plotly.newPlot(
#                         'ee5932c5-4b88-45b2-9c85-5736ff2edd26',
#                         [{"domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "hoverlabel": {"namelength": 0}, "hovertemplate": "Topic=%{label}", "labels": ["Other", "type 8", "Other", "type 6", "type 10", "type 3", "type 4", "type 7", "type 2", "type 3", "type 4", "type 5", "type 6", "type 6", "type 3", "type 3", "type 1", "type 7", "type 8", "type 6", "type 1", "type 6", "type 8", "type 8", "type 3", "type 4", "type 8", "type 3", "type 5", "type 4", "type 2", "type 2", "type 6", "type 1", "type 5", "type 5", "type 8", "type 7", "type 1", "type 2", "type 5", "type 5", "type 7", "type 3", "type 9", "type 5", "type 3", "type 7", "Other", "type 5", "type 6", "type 4", "type 7", "type 7", "type 9", "type 3", "type 2", "type 8", "type 3", "type 7", "type 8", "type 1", "type 8", "type 8", "type 4", "type 9", "type 5", "Other", "type 10", "type 3", "type 1", "type 3", "type 6", "type 1", "type 7", "type 9", "type 7", "type 1", "type 4", "type 4", "type 5", "Other", "type 7", "type 6", "Other", "type 6", "type 2", "type 7", "type 8", "type 1", "type 4", "type 4", "type 9", "type 4", "type 5", "type 9", "type 5", "type 6", "type 7", "type 2", "type 1", "Other", "type 7", "type 7", "type 5", "Other", "type 4", "type 5", "type 1", "Other", "type 8", "type 2", "type 7", "type 3", "type 8", "type 4", "type 6", "Other", "type 2", "type 1", "type 7", "type 2", "type 1", "type 2", "type 5", "type 7", "type 7", "type 7", "type 6", "type 5", "type 4", "type 3", "type 2", "type 5", "type 2", "Other", "Other", "type 6", "type 5", "type 3", "type 4", "type 7", "type 6", "type 4", "Other", "Other", "type 4", "type 8", "type 5", "type 8", "type 7", "type 4", "type 5", "type 6", "type 4", "type 7", "type 7", "type 3", "type 8", "type 7", "type 6", "type 9", "type 6", "type 4", "type 1", "type 4", "type 6", "type 8", "type 3", "type 4", "type 8", "type 7", "type 6", "type 2", "type 5", "type 4", "type 4", "type 6", "type 8", "Other", "type 5", "type 1", "type 5", "type 2", "type 2", "type 7", "type 1", "type 7", "type 2", "type 3", "type 8", "type 1", "type 8", "type 7", "type 3", "type 3", "type 4", "type 5", "type 1", "type 6", "type 7", "type 7", "type 8", "type 3", "type 10", "type 1", "type 1", "Other", "type 8", "type 5", "type 2", "type 8", "Other", "type 8", "type 7", "Other", "Other", "type 5", "type 1", "type 2", "type 5", "type 4", "type 5", "type 1", "type 8", "type 2", "type 7", "type 3", "type 3", "type 6", "type 1", "type 7", "type 1", "type 7", "type 4", "type 4", "type 9", "type 3", "type 4", "type 8", "type 2", "type 2", "type 2", "type 2", "type 2", "type 2", "type 7", "type 2", "type 2", "type 2", "type 2", "type 2", "type 8", "type 2", "type 2", "type 7", "type 9", "type 2", "type 7", "type 5", "type 3", "type 3", "Other", "type 8", "type 9", "type 7", "type 5", "type 7", "type 6", "type 2", "type 4", "type 10", "type 1", "type 4", "type 4", "type 3", "type 4", "type 2", "type 9", "Other", "type 2", "type 7", "type 6", "type 2", "type 8", "type 4", "Other", "Other", "type 1", "type 3", "type 8", "type 5", "type 8", "type 1", "type 2", "type 6", "type 1", "type 4", "type 1", "type 1", "type 9", "Other", "Other", "type 4", "type 6", "type 9", "type 4", "type 8", "type 6", "type 5", "type 5", "type 4", "type 6", "type 5", "type 6", "type 7", "type 8", "type 8", "type 2", "type 5", "type 5", "type 6", "type 1", "type 7", "type 8", "type 3", "type 5", "type 2", "type 7", "type 2", "type 3", "type 1", "type 9", "type 2", "type 1", "type 7", "type 2", "type 9", "type 5", "type 2", "type 3", "type 8", "type 7", "type 6", "type 2", "type 2", "type 6", "type 3", "type 8", "type 3", "type 6", "type 1", "type 8", "type 1", "type 7", "type 1", "type 4", "type 8", "type 6", "type 7", "type 9", "type 2", "type 5", "type 5", "type 3", "type 5", "type 2", "Other", "type 6", "type 3", "type 5", "type 5", "type 8", "type 3", "type 3", "type 5", "type 1", "type 5", "type 7", "type 2", "type 1", "type 9", "type 3", "type 4", "type 8", "type 1", "type 3", " ...

# %%
z = []

for item in y: 
    if item not in z:
        z.append(item)

# %%
z
# Out:
# [9, 8, 6, 2, 3, 0, 7, 5, 1, 4]

# %%
for item in z: 

    print(y.count(item))
# Out:
# 230
# 297
# 338
# 349
# 347
# 328
# 376
# 346
# 380
# 291

# %%
df
# Out:
#                                                  Tweets  ...                                       hashtags
# 0     RT @Joydas: When Is the Last Election Rally of...  ...                                             []
# 1     RT @abir_1729: #cancelboardexam2021\n#cancelbo...  ...  [#cancelboardexam2021, #cancelboardexams2021]
# 2     RT @LiveLawIndia: Can Centre Intervene If A St...  ...                                             []
# 3     RT @soompi: #GOT7's #BamBam Pauses Activities ...  ...                               [#GOT7, #BamBam]
# 4     RT @NagpurKaRajini: So Covid in Maharashtra sp...  ...                                             []
# ...                                                 ...  ...                                            ...
# 3277  RT @LawyerInBaking: 2020 March : India ran out...  ...                                             []
# 3278  RT @KirenRijiju: She is Inshah Bashir, Wheelch...  ...                                             []
# 3279  RT @indiacom: Regarding CBSE Board Exams 2021,...  ...                                             []
# 3280  RT @KanwalSibal: Why this obsession with dialo...  ...                                             []
# 3281  RT @Suhelseth: You might also wish us Happy Va...  ...                                             []
#
# [3282 rows x 10 columns]

# %%
df['cluster']=y

# %%
df[:10]
# Out:
#                                               Tweets  ... cluster
# 0  RT @Joydas: When Is the Last Election Rally of...  ...       9
# 1  RT @abir_1729: #cancelboardexam2021\n#cancelbo...  ...       8
# 2  RT @LiveLawIndia: Can Centre Intervene If A St...  ...       9
# 3  RT @soompi: #GOT7's #BamBam Pauses Activities ...  ...       6
# 4  RT @NagpurKaRajini: So Covid in Maharashtra sp...  ...       9
# 5  UK economy returns to growth despite Covid res...  ...       2
# 6  RT @PGaspirant7: #postponeneetpg \n@profplal\n...  ...       3
# 7  RT @dinesh_sir: Thanks for taking decisions fo...  ...       0
# 8  RT @Nher_who: Now that India is facing Second ...  ...       7
# 9  RT @abcnews: Thousands of vulnerable Australia...  ...       2
#
# [10 rows x 11 columns]

# %%
df[df['cluster']==8]
# Out:
#                                                  Tweets  ... cluster
# 1     RT @abir_1729: #cancelboardexam2021\n#cancelbo...  ...       8
# 18    RT @mukeshahlawatap: C:   Cancel \nB:   Board’...  ...       8
# 22    RT @SonuSood: C:   Cancel \nB:   Board’s \nS: ...  ...       8
# 23    RT @SonuSood: C:   Cancel \nB:   Board’s \nS: ...  ...       8
# 26    RT @SonuSood: C:   Cancel \nB:   Board’s \nS: ...  ...       8
# ...                                                 ...  ...     ...
# 2399  RT @SonuSood: C:   Cancel \nB:   Board’s \nS: ...  ...       8
# 2401  RT @SonuSood: C:   Cancel \nB:   Board’s \nS: ...  ...       8
# 2415  RT @SonuSood: C:   Cancel \nB:   Board’s \nS: ...  ...       8
# 2489  RT @RainSunMoonSky: Hindi is a foreign languag...  ...       8
# 2492  RT @Praveen_Sahu5: Students trying to #cancelb...  ...       8
#
# [297 rows x 11 columns]

# %%
c1 = df[df['cluster']==0]
c2 = df[df['cluster']==1]
c3 = df[df['cluster']==2]
c4 = df[df['cluster']==3]
c5 = df[df['cluster']==4]
c6 = df[df['cluster']==5]
c7 = df[df['cluster']==6]
c8 = df[df['cluster']==7]
c9 = df[df['cluster']==8]
c10 = df[df['cluster']==9]

# %%
c1
# Out:
#                                                  Tweets  ... cluster
# 7     RT @dinesh_sir: Thanks for taking decisions fo...  ...       0
# 17    RT @Voize_of_Reazon: Just hours after tweeting...  ...       0
# 37    @Himansh94406885 @AamAadmiParty @ArvindKejriwa...  ...       0
# 42    Good decision and long overdue. The MRA regula...  ...       0
# 47    RT @nidhiindiatv: Delhi CM @ArvindKejriwal req...  ...       0
# ...                                                 ...  ...     ...
# 3228  🎊It’s a wrap! #NeuroFemIndia2021 🎊\n\nSo 💯 gra...  ...       0
# 3265  RT @AbhishBanerj: US companies are neck deep i...  ...       0
# 3268  Top 10 Trusted Microfinance #Companies in Indi...  ...       0
# 3278  RT @KirenRijiju: She is Inshah Bashir, Wheelch...  ...       0
# 3281  RT @Suhelseth: You might also wish us Happy Va...  ...       0
#
# [328 rows x 11 columns]

# %%
import csv 
c1.to_csv('c1.csv')
c1.to_csv('c2.csv')
c1.to_csv('c3.csv')
c1.to_csv('c4.csv')
c1.to_csv('c5.csv')
c1.to_csv('c6.csv')
c1.to_csv('c7.csv')
c1.to_csv('c8.csv')
c1.to_csv('c9.csv')
c1.to_csv('c10.csv')

# %%
import pandas as pd
colnames = ['Tweets','is_retweet','retweeted','mentioned','hashtags','clean_tweet','cluster','new', 'tidy_text', 'tok', 'nouns']
df = pd.read_csv('c1.csv', names=colnames)

# %%
import nltk
from nltk.tokenize import RegexpTokenizer
from nltk.corpus import stopwords

nltk.download('stopwords')

def remove_links(tweet):

    '''Takes a string and removes web links from it'''
    tweet = re.sub(r'http\S+', '', tweet) # remove http links
    tweet = re.sub(r'bit.ly/\S+', '', tweet) # rempve bitly links
    tweet = tweet.strip('[link]') # remove [links]
    return tweet

def remove_users(tweet):
    '''Takes a string and removes retweet and @user information'''
    tweet = re.sub('(RT\s@[A-Za-z]+[A-Za-z0-9-_]+)', '', tweet) # remove retweet
    tweet = re.sub('(@[A-Za-z]+[A-Za-z0-9-_]+)', '', tweet) # remove tweeted at
    return tweet

my_stopwords = nltk.corpus.stopwords.words('english')
word_rooter = nltk.stem.snowball.PorterStemmer(ignore_stopwords=False).stem
my_punctuation = '!"$%&\'()*+,-./:;<=>?[\\]^_`{|}~•@'

# cleaning master function
def clean_tweet(tweet, bigrams=False):
    tweet = remove_users(tweet)
    tweet = remove_links(tweet)
    tweet = tweet.lower() # lower case
    tweet = re.sub('['+my_punctuation + ']+', ' ', tweet) # strip punctuation
    tweet = re.sub('\s+', ' ', tweet) #remove double spacing
    tweet = re.sub('([0-9]+)', '', tweet) # remove numbers
    tweet_token_list = [word for word in tweet.split(' ')
                            if word not in my_stopwords] # remove stopwords

    tweet_token_list = [word_rooter(word) if '#' not in word else word
                        for word in tweet_token_list] # apply word rooter
    if bigrams:
        tweet_token_list = tweet_token_list+[tweet_token_list[i]+'_'+tweet_token_list[i+1]
                                            for i in range(len(tweet_token_list)-1)]
    tweet = ' '.join(tweet_token_list)
    return tweet

nltk.download('stopwords')

df['clean_tweet'] = df.Tweets.apply(clean_tweet)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
fetched_tweets = df.clean_tweet.tolist()

# %%
fetched_tweets
# Out:
# ['tweet',
#  ' thank take decis safeti student pleas tri clear pictur futur exam pattern asap s…',
#  ' hour tweet kill ride bike love cycl cautiou hell i…',
#  ' yrr tumn hardwork kiy hai bo wast toh ho nhi jaayega becz knowl… ',
#  'good decis long overdu mra regulatori bodi one stringent emerg requiremen… ',
#  ' delhi cm request centr govt #cancelcbseboardexams amid fear exam centr becom covid hots…',
#  ' good decis altern assess way postpon long time #internalas…',
#  ' delhi cm request centr govt #cancelcbseboardexams amid fear exam centr becom covid hots…',
#  ' thank ',
#  ' covid patient given oxygen autorikshaw visual satara district maharashtra ',
#  ' option scenario deal #publicdebt post covid #euroarea …',
#  ' gov’t held respons gov’t forc futur star sit exam fast spread…',
#  ' #cancelboardexam #internalassessment amaz full ever seen thank support',
#  'here’ help us soon see covid  ‘turnaround ’ fauci say ',
#  ' citi post covid futur ',
#  '  land right defend lawyer repres pap pap leader arbitrarili arrest secur forces…',
#  ' actor yet back students’ demand #cancelboardexams “don let exam centr becom covid hots…',
#  ' gov’t held respons gov’t forc futur star sit exam fast spread…',
#  ' ie walk area  km — #haridwar railway station har ki pauri amp ghat arrangements…',
#  ' actor yet back students’ demand #cancelboardexams “don let exam centr becom covid hots…',
#  ' delhi cm request centr govt #cancelcbseboardexams amid fear exam centr becom covid hots…',
#  ' unfinish busi \U0001f977🖤🤘🏽 offici announc take covid year continu play universit…',
#  ' laundri wash covid clean suppli fro… ',
#  'brain destroy greed consumer hedon',
#  ' actor yet back students’ demand #cancelboardexams “don let exam centr becom covid hots…',
#  ' thank take decis safeti student pleas tri clear pictur futur exam pattern asap s…',
#  ' #delhi chief minist #arvindkejriwal appeal centr cancel upcom cbse  board exam follow sp…',
#  ' gov’t held respons gov’t forc futur star sit exam fast spread…',
#  ' delhi cm request centr govt #cancelcbseboardexams amid fear exam centr becom covid hots…',
#  ' dishearten gov’t taken decis #boardexams yet student make hue amp cri still one ready…',
#  ' delhi cm request centr govt #cancelcbseboardexams amid fear exam centr becom covid hots…',
#  ' citi post covid futur ',
#  ' excel decis district congress offic chhattisgarh turn covid hospit t…',
#  ' thank take decis safeti student pleas tri clear pictur futur exam pattern asap s…',
#  'everi stori two aspect pictur show naga sadhu wear masks😷 wait take dip ganga during… ',
#  ' #hospitals #mumbai pl help sir covid center friend mom need icu bed kaha pe bhi avail nahi mumb…',
#  ' chief final call ban wet market covid outbreak ',
#  ' actor yet back students’ demand #cancelboardexams “don let exam centr becom covid hots…',
#  ' state examin center emerg covid hotspot delhi cm urg centr cancel cbse bo…',
#  ' delhi cm #arvindkejriwal said decis conduct #boardexams reconsid view rise number #c…',
#  ' break  doctor sign letter warn grave danger give children co vi  jab ',
#  ' thank take decis safeti student pleas tri clear pictur futur exam pattern asap s…',
#  ' delhi cm sh met chairman ganga ram hospit prof dr rana express concern  d…',
#  ' gov’t held respons gov’t forc futur star sit exam fast spread…',
#  ' actor yet back students’ demand #cancelboardexams “don let exam centr becom covid hots…',
#  '  hour indian express walk area  km — railway station haridwar icon har…',
#  ' thank take decis safeti student pleas tri clear pictur futur exam pattern asap s…',
#  ' delhi cm request centr govt #cancelcbseboardexams amid fear exam centr becom covid hots…',
#  ' resurg pandem indict human compuls sacrific mani fellowmen laid wast i…',
#  ' gov’t held respons gov’t forc futur star sit exam fast spread…',
#  ' delhi cm request centr govt #cancelcbseboardexams amid fear exam centr becom covid hots…',
#  ' long queue ambul outsid govt run covid hospit ahmedabad regular featur recent st…',
#  ' mam pleas speak   lac doctor duti day night forc travel i…',
#  ' #cbse mull decis  #boardexams given rise #covid case hope factor preced exist it…',
#  ' centr around  km away place regist nd day even abl go electi…',
#  ' gov’t held respons gov’t forc futur star sit exam fast spread…',
#  ' delhi cm request centr govt #cancelcbseboardexams amid fear exam centr becom covid hots…',
#  ' covid danger us 🙏🏻#cancelboardexams ',
#  ' resurg pandem indict human compuls sacrific mani fellowmen laid wast i…',
#  ' delhi cm request centr govt #cancelcbseboardexams amid fear exam centr becom covid hots…',
#  ' citi post covid futur ',
#  ' request centr cancel cbse exam say delhi cm ',
#  ' close  land right defend lawyer repres pap arbitrarili arrest secur forc faci…',
#  ' delhi cm request centr govt #cancelcbseboardexams amid fear exam centr becom covid hots…',
#  ' pill smoke someth choos danger well known … ',
#  ' citi post covid futur ',
#  ' get covid shot refus ',
#  ' delhi cm request centr govt #cancelcbseboardexams amid fear exam centr becom covid hots…',
#  'thank sir #cancelcbseboardexam',
#  ' visual outsid mortuari bhim rao ambedkar memori hospit raipur chhattisgarh report   fresh covid  cases…',
#  ' gov’t held respons gov’t forc futur star sit exam fast spread…',
#  ' uganda struggl strengthen measur curb spread covid  secur agenc work multin co…',
#  ' accord covid patient rel  patient die within hour due lack oxygen suppli nalasopara vi…',
#  ' citi post covid futur ',
#  ' delhi cm request centr govt #cancelcbseboardexams amid fear exam centr becom covid hots…',
#  ' thank u bhai love ❤️',
#  ' delhi cm request centr govt #cancelcbseboardexams amid fear exam centr becom covid hots…',
#  ' covid wast contemporari archaeolog help shape polici paper open access ',
#  ' centr around  km away place regist nd day even abl go electi…',
#  ' gov’t held respons gov’t forc futur star sit exam fast spread…',
#  '  land right defend lawyer repres pap pap leader arbitrarili arrest secur forces…',
#  ' well done delhi cm decis cancel cbse exam help control speed viru student health cannot be…',
#  ' thank take decis safeti student pleas tri clear pictur futur exam pattern asap s…',
#  ' don’t spread fake news devote test neg enter citi ',
#  ' delhi cm request centr govt #cancelcbseboardexams amid fear exam centr becom covid hots…',
#  ' thank take decis safeti student pleas tri clear pictur futur exam pattern asap s…',
#  ' actor yet back students’ demand #cancelboardexams “don let exam centr becom covid hots…',
#  '  hour indian express walk area  km — railway station haridwar icon har…',
#  ' delhi cm ask centr cancel cbse exam say  covid patient  year ',
#  ' thank take decis safeti student pleas tri clear pictur futur exam pattern asap s…',
#  ' citi post covid futur ',
#  ' delhi cm request centr govt #cancelcbseboardexams amid fear exam centr becom covid hots…',
#  'thank sir 🙏🏻 #internalassesment #cancelboardexam ',
#  ' delhi cm ask centr cancel cbse exam say  covid patient  year ',
#  ' maharashtra especi mumbai metropolitan region offici beyond redempt everi singl hospit bed c…',
#  ' citi post covid futur ',
#  ' 🌺॥ जय शेरावाली माता की जय ॥ 🌺 shubh navratri hindu follow sanatan dharma hon abl pm mo…',
#  ' horrif visual ambedkar hospit raipur bodi #covid patient pile mortuari f…',
#  ' actor yet back students’ demand #cancelboardexams “don let exam centr becom covid hots…',
#  ' reliev hear solut achiev allow child refuge reloc well done ex…',
#  '  peopl test covid posit #kumbh  lakh devote visit #haridwar monday thermal screeni…',
#  ' delhi cm request centr govt #cancelcbseboardexams amid fear exam centr becom covid hots…',
#  ' request centr cancel cbse exam say delhi cm ',
#  'everyon know covid case rise enorm hell govt even… ',
#  'plan travel train see indian railways’ latest covid  guidelin via newspo… ',
#  'thank beauti link tag follow version pandem see far we’ll go #unprecedentedtimes … ',
#  ' ten covid  patient allegedli die due lack oxygen maharashtra’ vasai near mumbai ',
#  ' alway alleg news portal prove best fake news  hospit fulli convert covid special how…',
#  ' sir pleas speak neet pg  us ordinari doctor work covid center dont h… ',
#  ' gardai vaccin allow travel reloc child refuge greec stori …',
#  'drdo set covid  hospit  bed icu facil delhi ',
#  ' mam  lakh doctor sit offlin neet pg exam  april mani alreadi posit due covid dutie…',
#  ' thank take decis safeti student pleas tri clear pictur futur exam pattern asap s…',
#  ' maharashtra especi mumbai metropolitan region offici beyond redempt everi singl hospit bed c…',
#  ' actor yet back students’ demand #cancelboardexams “don let exam centr becom covid hots…',
#  '   #covid case last  hour #delhi read number mask stay safe ',
#  'good memori rememb similar outrag last year focuss part street wh… ',
#  ' thank take decis safeti student pleas tri clear pictur futur exam pattern asap s…',
#  ' ok ',
#  ' delhi cm request centr govt #cancelcbseboardexams amid fear exam centr becom covid hots…',
#  'ot michigan shut hell ',
#  ' delhi cm request centr govt #cancelcbseboardexams amid fear exam centr becom covid hots…',
#  ' gov’t held respons gov’t forc futur star sit exam fast spread…',
#  ' thank take decis safeti student pleas tri clear pictur futur exam pattern asap s…',
#  ' delhi cm request centr govt #cancelcbseboardexams amid fear exam centr becom covid hots…',
#  ' request centr cancel cbse exam say delhi cm #httweets via unfol…',
#  ' lost covid ue law student grante colleg law scholarship gener avail schol…',
#  ' need icu bed ventil facil covid patient tri reach hospit suggest war roo…',
#  ' delhi cm request centr govt #cancelcbseboardexams amid fear exam centr becom covid hots…',
#  ' follow top tip help busi step closer covid secur progress throughout roadmap o…',
#  'nearli million hindu bath monday gang observ social distanc wore mask … ',
#  ' maharashtra especi mumbai metropolitan region offici beyond redempt everi singl hospit bed c…',
#  ' delhi cm request centr govt #cancelcbseboardexams amid fear exam centr becom covid hots…',
#  ' lost covid ue law student grante colleg law scholarship gener avail schol…',
#  ' citi post covid futur ',
#  ' actor yet back students’ demand #cancelboardexams “don let exam centr becom covid hots…',
#  ' delhi cm request centr govt #cancelcbseboardexams amid fear exam centr becom covid hots…',
#  ' “we less plasma stock request fallen ill last day recov pleas donat p…',
#  ' delhi cm request centr govt #cancelcbseboardexams amid fear exam centr becom covid hots…',
#  ' congress leader ask govt reconsid decis conduct #cbseboardexams covid case peak in…',
#  ' spatio tempor singl cell atla human develop spinal cord onlin provid overal descript the…',
#  ' show polit covid  amp mask larg gather blm riot loot destroy busi and…',
#  ' variou checkpoint indian express count  devote ask rt pcr report — least  n…',
#  ' despit lock march  enact strict social distanc measur toronto see hospit intens care…',
#  ' don’t spread fake news devote test neg enter citi ',
#  ' delhi cm request centr govt #cancelcbseboardexams amid fear exam centr becom covid hots…',
#  ' #delhi chief minist #arvindkejriwal appeal centr cancel upcom cbse  board exam follow sp…',
#  ' citi post covid futur ',
#  ' lost covid ue law student grante colleg law scholarship gener avail schol…',
#  ' set  new covid care centr across citi   bed #chennaicorporation #covidcare… ',
#  ' gov’t held respons gov’t forc futur star sit exam fast spread…',
#  ' univers delhi issu fresh measur view increas covid  pandem read ',
#  'thankyou sir support us tab bhi wale sunn samajh nhi rh… ',
#  ' spatio tempor singl cell atla human develop spinal cord onlin provid overal descript the…',
#  '#cancelboardexams #internalassessment #boardexams #studentslivesmatter save student save futur',
#  ' jim friend colleg six hour tweet kill bike car ran ',
#  'rt taylorhudak liter keep awak night former chief scientist pfizer dr michael yeadon reveal biggest fear…',
#  ' mind amp everyon els busi say someth h… ',
#  ' thank take decis safeti student pleas tri clear pictur futur exam pattern asap s…',
#  ' delhi’ main lnjp hospit close opd emerg servic elect surgeri except #covid emergen…',
#  ' #delhi chief minist #arvindkejriwal appeal centr cancel upcom cbse  board exam follow sp…',
#  ' thank take decis safeti student pleas tri clear pictur futur exam pattern asap s…',
#  ' delhi cm request centr govt #cancelcbseboardexams amid fear exam centr becom covid hots…',
#  ' delhi cm press confer express concern grow case #covid said due t…',
#  '  covid death  pvt hospit nalasopara yesterday famili alleg death due oxygen shortag …',
#  ' “we less plasma stock request fallen ill last day recov pleas donat p…',
#  ' absolut devast icon kiwi mountain compani conquer mt everest fall victim covid  ',
#  'pakistan anti franc protest disrupt covid  oxygen suppli say offici ',
#  'offici covid stat gujarat true ',
#  ' rishi sunak confirm push help ex pm david cameron greensil covid loan request yet di…',
#  ' don’t spread fake news devote test neg enter citi ',
#  ' #cancelboardexam #sonusood request everyon amid rise #covid case ',
#  ' covid',
#  'curb covid spread time lockdown ye follow could one good potential… ',
#  ' mani pvt govt hospit turn fulli covid hospit bed ad delhi cm take decision…',
#  ' well done delhi cm decis cancel cbse exam help control speed viru student health cannot be…',
#  ' thank take decis safeti student pleas tri clear pictur futur exam pattern asap s…',
#  ' delhi cm request centr govt #cancelcbseboardexams amid fear exam centr becom covid hots…',
#  'auto compani safeti playbook protocol place year meticul laid they… ',
#  ' citi post covid futur ',
#  ' delhi cm ask centr cancel cbse exam say  covid patient  year ',
#  ' sir pleas speak neet pg  us ordinari doctor work covid center dont nu…',
#  ' citi post covid futur ',
#  '  land right defend lawyer repres pap pap leader arbitrarili arrest secur forces…',
#  ' student respect decis tak… ',
#  '  hour indian express walk area  km — railway station haridwar icon har…',
#  ' monday even  lakh devote turn second shahi snan ganga accord medic departmen…',
#  ' citi post covid futur ',
#  'pl note help guysss🙏🙏',
#  ' actor yet back students’ demand #cancelboardexams “don let exam centr becom covid hots…',
#  ' actor yet back students’ demand #cancelboardexams “don let exam centr becom covid hots…',
#  ' sole singl exampl provid brecur and… ',
#  ' actor yet back students’ demand #cancelboardexams “don let exam centr becom covid hots…',
#  ' thank take decis safeti student pleas tri clear pictur futur exam pattern asap s…',
#  ' dishearten gov’t taken decis #boardexams yet student make hue amp cri still one ready…',
#  'mani facil locat region  region  convers augment need facil… ',
#  ' covid patient covid spreader ',
#  ' gov’t held respons gov’t forc futur star sit exam fast spread…',
#  'nearli half busi travel reject futur flight favour video call ',
#  ' thank take decis safeti student pleas tri clear pictur futur exam pattern asap s…',
#  ' thank take decis safeti student pleas tri clear pictur futur exam pattern asap s…',
#  ' gov’t held respons gov’t forc futur star sit exam fast spread…',
#  ' excel decis district congress offic chhattisgarh turn covid hospit t…',
#  ' maharashtra especi mumbai metropolitan region offici beyond redempt everi singl hospit bed c…',
#  ' fear hidden debt could stymi small busi covid ',
#  ' lbc choos post choos caption queue lo… ',
#  'uk automat covid trace hit yet anoth snag ',
#  ' mathew carver founder famou could never thought  year begin foodse…',
#  ' “we less plasma stock request fallen ill last day recov pleas donat p…',
#  ' #middaynews three jumbo #covid centr come   bed ad say chief …',
#  ' thank much transcrib dr mike yeadon vital import interview danger vaccine…',
#  'spoke rel canada toronto yesterday covid case rise 😱😱😱 ',
#  'listen stephen ask whether it’ safe go beach summer beach forest p… ',
#  ' 😃 last night saw news love covid  bulletin ukrain itali no… ',
#  ' citi post covid futur ',
#  ' potenti oxygen shortag lahor terrifi there’ place move anyon go give way ambul…',
#  'maintain good immun surviv covid  pandem comfort good immun strongest defence… ',
#  ' #cancelboardexam #sonusood request everyon amid rise #covid case ',
#  ' delhi cm request centr govt #cancelcbseboardexams amid fear exam centr becom covid hots…',
#  ' excel step kaushal raj sharma ji almost  extra bed creat l l covid patient i…',
#  'sheep move new herd town sampl paper show effect lockdowns… ',
#  ' thank beauti link tag follow version pandem see far we’ll go #unprecedentedtimes …',
#  ' renown virologist dr sucharit bhakdi asymptomat carrier spreader covid ',
#  ' maharashtra especi mumbai metropolitan region offici beyond redempt everi singl hospit bed c…',
#  ' delhi cm request centr govt #cancelcbseboardexams amid fear exam centr becom covid hots…',
#  'help sixth former make lost learn say uk colleg leader ',
#  ' delhi cm request centr govt #cancelcbseboardexams amid fear exam centr becom covid hots…',
#  ' dishearten gov’t taken decis #boardexams yet student make hue amp cri still one ready…',
#  ' don’t spread fake news devote test neg enter citi ',
#  ' actor yet back students’ demand #cancelboardexams “don let exam centr becom covid hots…',
#  ' govt organ golf tournament spread covid  among peopl ',
#  ' delhi cm request centr govt #cancelcbseboardexams amid fear exam centr becom covid hots…',
#  ' delhi cm request centr govt #cancelcbseboardexams amid fear exam centr becom covid hots…',
#  ' วันที่  หลังจากติดโควิดแล้ว #หมอชนะ ยังคงเป็นสีเขียวสวยงาม เสี่ยงต่ำมาก … it’  day covid  yet…',
#  ' realli look forward final launch tomorrow ',
#  ' it’ choic face consequ either live restrict lifestyl keep case low l… ',
#  ' bro kisn achh se tayari ki hai kisn nhi ki everyon safeti c… ',
#  ' 💔patient ‘elective’ life chang surgeri postpon hospit overwhelm 💔covid survivor wonde…',
#  ' don’t spread fake news devote test neg enter citi ',
#  '  covid death  pvt hospit nalasopara yesterday famili alleg death due oxygen shortag …',
#  ' delhi cm request centr govt #cancelcbseboardexams amid fear exam centr becom covid hots…',
#  ' thank take decis safeti student pleas tri clear pictur futur exam pattern asap s…',
#  ' break  doctor sign letter warn grave danger give children co vi  jab ',
#  ' citi post covid futur ',
#  ' “ nna covid e mboril shem ‼️‼️” ',
#  ' delhi cm #arvindkejriwal said decis conduct #boardexams reconsid view rise number #c…',
#  ' thank support cbse student save life student #cancelboardexams ',
#  ' urgent need plasma donor critic covid  patient new delhi lead would appreci help would…',
#  ' beg help  children one autist husband fell ill covid keep isolated…',
#  ' gov’t held respons gov’t forc futur star sit exam fast spread…',
#  ' thank take decis safeti student pleas tri clear pictur futur exam pattern asap s…',
#  ' gov’t held respons gov’t forc futur star sit exam fast spread…',
#  ' sir pleas speak neet pg  us ordinari doctor work covid center dont nu…',
#  ' #हिन्दू नववर्ष की सभी को शुभकामनाएं happi #gudipadwa happi #navratri happi #ugadi happi #ramadanmubarak everyo…',
#  ' sir pleas speak neet pg  us ordinari doctor work covid center dont nu…',
#  ' citi post covid futur ',
#  ' delhi cm request centr govt #cancelcbseboardexams amid fear exam centr becom covid hots…',
#  ' delhi cm request centr govt #cancelcbseboardexams amid fear exam centr becom covid hots…',
#  ' ‘we lose doctors’ sudan’ health worker plead covid jab ',
#  ' #covid migrant arriv huge number mumbai station amid lockdown fear railway call summer rush ',
#  ' us compani neck deep collabor chines govt major indian busi remov dow j…',
#  'excel depict current situat preval india ',
#  ' dozen news organis take part #climateemergencyweek includ reuter bloomberg agenc franc pre…',
#  ' everyon opinion may agre disagre india rule sharia one call behead disagre…',
#  ' might also wish us happi vaisakhi ugadi navratri tomorrow vishu sinc india one biggest market …',
#  ' arm #ai #onlinemandis shake #farming aim cut wast #boost #farmincome mi…',
#  ' discuss “wellb hour understand emot pain  pm ” …',
#  ' thank need hour good see maharashtra govt i…',
#  '  hour indian express walk area  km — railway station haridwar icon har…',
#  ' hold ur breath u call masterstrok govt wait letter remind the…',
#  ' might also wish us happi vaisakhi ugadi navratri tomorrow vishu sinc india one biggest market …',
#  ' peac karachi part india ',
#  ' jagmeet singh famili left india refuge decad ago abandon right indian citizenship jagmeet pe…',
#  ' darjeel one beauti citi india one oldest establish citi india rece…',
#  ' tesla face speed bump take first step india’ nascent electr vehicl market analyst warn ',
#  ' kashmir trade polit help india pakistan move forward ex envoy delhi salman bashir …',
#  'ummm ask ass burn seem becom stiff hole littl pain washroom unable… ',
#  ' resurg pandem indict human compuls sacrific mani fellowmen laid wast i…',
#  ' darjeel one beauti citi india one oldest establish citi india rec…',
#  ' sir covid warrior gujarat request rais voic young doctor india are…',
#  ' resurg pandem indict human compuls sacrific mani fellowmen laid wast i…',
#  ' us compani neck deep collabor chines govt major indian busi remov dow j…',
#  ' us compani neck deep collabor chines govt major indian busi remov dow j…',
#  ' everyon opinion may agre disagre india rule sharia one call behead disagre…',
#  '  hour indian express walk area  km — railway station haridwar icon har…',
#  ' insist along mock abus shriek one take seriou…',
#  ' darjeel one beauti citi india one oldest establish citi india recei…',
#  ' everyon opinion may agre disagre india rule sharia one call behead disagre…',
#  ' might also wish us happi vaisakhi ugadi navratri tomorrow vishu sinc india one biggest market …',
#  ' us compani neck deep collabor chines govt major indian busi remov dow j…',
#  ' might also wish us happi vaisakhi ugadi navratri tomorrow vishu sinc india one biggest market …',
#  ' us compani neck deep collabor chines govt major indian busi remov dow j…',
#  ' indian care woke bs hilari apu everyon india laugh accent h…',
#  ' surat smimer amp pvt hospit refus admit patient   patient are…',
#  ' thank need hour good see maharashtra govt i…',
#  'new begin peac amp abund let harvest fresh feel hope happi amp heal 🌾\U0001fa98… ',
#  ' thank deepest gratitud sir gangaram hospit shape better doctor proud alumnu keep savin…',
#  ' darjeel one beauti citi india one oldest establish citi india received…',
#  ' might also wish us happi vaisakhi ugadi navratri tomorrow vishu sinc india one biggest market …',
#  ' everyon opinion may agre disagre india rule sharia one call behead disagre…',
#  'good decis peopl choic #wtoera',
#  ' #indian #supremecourt rock thank call frivol absolut wast time spread ha…',
#  ' it’ ur scriptur come practis #hanafi #sunni sect is… ',
#  ' #covid migrant arriv huge number mumbai station amid lockdown fear railway call summer rush ',
#  ' speechless',
#  ' us compani neck deep collabor chines govt major indian busi remov dow j…',
#  ' darjeel one beauti citi india one oldest establish citi india receiv…',
#  ' darjeel one beauti citi india one oldest establish citi india recei…',
#  '#tatagroup launch #marketplace well suit #enterprise #tech #solutions small medium enterprise… ',
#  ' us compani neck deep collabor chines govt major indian busi remov dow j…',
#  'india stock higher close trade nifti    ',
#  ' us compani neck deep collabor chines govt major indian busi remov dow j…',
#  ' everyon opinion may agre disagre india rule sharia one call behead disagre…',
#  ' hope premier univers region explor way promot mutual understanding…',
#  ' ambul patient wait line admit insid hospit ahmedabad gujrat situat g…',
#  ' thank need hour good see maharashtra govt take initi help al…',
#  ' us compani neck deep collabor chines govt major indian busi remov dow j…',
#  '  hour indian express walk area  km — railway station haridwar icon har…',
#  ' everyon opinion may agre disagre india rule sharia one call behead disagre…',
#  ' “accord medic depart offici   devote test   pm sunday  pm monday — …',
#  ' poster ask behead ji put religi bigot owaisi aimim forget security…',
#  'let’ welcom ugadi great hope eager amp anticip let us look forward plenti joy satisfact… ',
#  ' thank need hour good see maharashtra govt i…',
#  ' resurg pandem indict human compuls sacrific mani fellowmen laid wast i…',
#  '🎊it’ wrap #neurofemindia 🎊 💯 grate everyon chose particip confer an… ',
#  ' us compani neck deep collabor chines govt major indian busi remov dow j…',
#  'top  trust microfin #companies india  #business',
#  ' inshah bashir wheelchair basketbal player jammu kashmir made india proud inspiration…',
#  ' might also wish us happi vaisakhi ugadi navratri tomorrow vishu sinc india one biggest market …']

# %%
from wordcloud import WordCloud 

allWords = ' '.join([tweets for tweets in df['clean_tweet']])
wordCloud = WordCloud(width = 800, height = 500, random_state = 21, max_font_size = 119).generate(allWords)
plt.imshow(wordCloud, interpolation = "bilinear")
plt.axis('off')
plt.show()

# %%
# !pip install wordCloud
# Out:
# Requirement already satisfied: wordCloud in /usr/local/lib/python3.7/dist-packages (1.5.0)
# Requirement already satisfied: numpy>=1.6.1 in /usr/local/lib/python3.7/dist-packages (from wordCloud) (1.19.5)
# Requirement already satisfied: pillow in /usr/local/lib/python3.7/dist-packages (from wordCloud) (7.1.2)

# %%
def get_tweet_sentiment(tweet):
		'''
		Utility function to classify sentiment of passed tweet
		using textblob's sentiment method
		'''
		# create TextBlob object of passed tweet text
		analysis = TextBlob(tweet)
		# set sentiment
		if analysis.sentiment.polarity > 0:
			return 'positive'
		elif analysis.sentiment.polarity == 0:
			return 'neutral'
		else:
			return 'negative'

# %%
	# parsing tweets one by one

from textblob import TextBlob
tweets = []
for tweet in fetched_tweets:
  #print(tweet)
				# empty dictionary to store required params of a tweet
  parsed_tweet = {}
  parsed_tweet['text'] = tweet
  parsed_tweet['sentiment']=get_tweet_sentiment(tweet)
  tweets.append(parsed_tweet)
	
 
	
print(tweets)
# Out:
# [{'text': 'tweet', 'sentiment': 'neutral'}, {'text': ' thank take decis safeti student pleas tri clear pictur futur exam pattern asap s…', 'sentiment': 'positive'}, {'text': ' hour tweet kill ride bike love cycl cautiou hell i…', 'sentiment': 'positive'}, {'text': ' yrr tumn hardwork kiy hai bo wast toh ho nhi jaayega becz knowl… ', 'sentiment': 'neutral'}, {'text': 'good decis long overdu mra regulatori bodi one stringent emerg requiremen… ', 'sentiment': 'positive'}, {'text': ' delhi cm request centr govt #cancelcbseboardexams amid fear exam centr becom covid hots…', 'sentiment': 'neutral'}, {'text': ' good decis altern assess way postpon long time #internalas…', 'sentiment': 'positive'}, {'text': ' delhi cm request centr govt #cancelcbseboardexams amid fear exam centr becom covid hots…', 'sentiment': 'neutral'}, {'text': ' thank ', 'sentiment': 'neutral'}, {'text': ' covid patient given oxygen autorikshaw visual satara district maharashtra ', 'sentiment': 'neutral'}, {'text': ' option scenario deal #publicdebt post covid #euroarea …', 'sentiment': 'neutral'}, {'text': ' gov’t held respons gov’t forc futur star sit exam fast spread…', 'sentiment': 'positive'}, {'text': ' #cancelboardexam #internalassessment amaz full ever seen thank support', 'sentiment': 'positive'}, {'text': 'here’ help us soon see covid  ‘turnaround ’ fauci say ', 'sentiment': 'neutral'}, {'text': ' citi post covid futur ', 'sentiment': 'neutral'}, {'text': '  land right defend lawyer repres pap pap leader arbitrarili arrest secur forces…', 'sentiment': 'positive'}, {'text': ' actor yet back students’ demand #cancelboardexams “don let exam centr becom covid hots…', 'sentiment': 'neutral'}, {'text': ' gov’t held respons gov’t forc futur star sit exam fast spread…', 'sentiment': 'positive'}, {'text': ' ie walk area  km — #haridwar railway station har ki pauri amp ghat arrangements…', 'sentiment': 'neutral'}, {'text': ' actor yet back students’ demand #cancelboardexams “don let exam centr becom covid hots…', 'sentiment': 'neutral'}, {'text': ' delhi cm request centr govt #cancelcbseboardexams amid fear exam centr becom covid hots…', 'sentiment': 'neutral'}, {'text': ' unfinish busi \U0001f977🖤🤘🏽 offici announc take covid year continu play universit…', 'sentiment': 'neutral'}, {'text': ' laundri wash covid clean suppli fro… ', 'sentiment': 'positive'}, {'text': 'brain destroy greed consumer hedon', 'sentiment': 'negative'}, {'text': ' actor yet back students’ demand #cancelboardexams “don let exam centr becom covid hots…', 'sentiment': 'neutral'}, {'text': ' thank take decis safeti student pleas tri clear pictur futur exam pattern asap s…', 'sentiment': 'positive'}, {'text': ' #delhi chief minist #arvindkejriwal appeal centr cancel upcom cbse  board exam follow sp…', 'sentiment': 'neutral'}, {'text': ' gov’t held respons gov’t forc futur star sit exam fast spread…', 'sentiment': 'positive'}, {'text': ' delhi cm request centr govt #cancelcbseboardexams amid fear exam centr becom covid hots…', 'sentiment': 'neutral'}, {'text': ' dishearten gov’t taken decis #boardexams yet student make hue amp cri still one ready…', 'sentiment': 'neutral'}, {'text': ' delhi cm request centr govt #cancelcbseboardexams amid fear exam centr becom covid hots…', 'sentiment': 'neutral'}, {'text': ' citi post covid futur ', 'sentiment': 'neutral'}, {'text': ' excel decis district congress offic chhattisgarh turn covid hospit t…', 'sentiment': 'neutral'}, {'text': ' thank take decis safeti student pleas tri clear pictur futur exam pattern asap s…', 'sentiment': 'positive'}, {'text': 'everi stori two aspect pictur show naga sadhu wear masks😷 wait take dip ganga during… ', 'sentiment': 'neutral'}, {'text': ' #hospitals #mumbai pl help sir covid center friend mom need icu bed kaha pe bhi avail nahi mumb…', 'sentiment': 'negative'}, {'text': ' chief final call ban wet market covid outbreak ', 'sentiment': 'negative'}, {'text': ' actor yet back students’ demand #cancelboardexams “don let ex ...

# %%
tweets
# Out:
# [{'sentiment': 'neutral', 'text': 'tweet'},
#  {'sentiment': 'positive',
#   'text': ' thank take decis safeti student pleas tri clear pictur futur exam pattern asap s…'},
#  {'sentiment': 'positive',
#   'text': ' hour tweet kill ride bike love cycl cautiou hell i…'},
#  {'sentiment': 'neutral',
#   'text': ' yrr tumn hardwork kiy hai bo wast toh ho nhi jaayega becz knowl… '},
#  {'sentiment': 'positive',
#   'text': 'good decis long overdu mra regulatori bodi one stringent emerg requiremen… '},
#  {'sentiment': 'neutral',
#   'text': ' delhi cm request centr govt #cancelcbseboardexams amid fear exam centr becom covid hots…'},
#  {'sentiment': 'positive',
#   'text': ' good decis altern assess way postpon long time #internalas…'},
#  {'sentiment': 'neutral',
#   'text': ' delhi cm request centr govt #cancelcbseboardexams amid fear exam centr becom covid hots…'},
#  {'sentiment': 'neutral', 'text': ' thank '},
#  {'sentiment': 'neutral',
#   'text': ' covid patient given oxygen autorikshaw visual satara district maharashtra '},
#  {'sentiment': 'neutral',
#   'text': ' option scenario deal #publicdebt post covid #euroarea …'},
#  {'sentiment': 'positive',
#   'text': ' gov’t held respons gov’t forc futur star sit exam fast spread…'},
#  {'sentiment': 'positive',
#   'text': ' #cancelboardexam #internalassessment amaz full ever seen thank support'},
#  {'sentiment': 'neutral',
#   'text': 'here’ help us soon see covid  ‘turnaround ’ fauci say '},
#  {'sentiment': 'neutral', 'text': ' citi post covid futur '},
#  {'sentiment': 'positive',
#   'text': '  land right defend lawyer repres pap pap leader arbitrarili arrest secur forces…'},
#  {'sentiment': 'neutral',
#   'text': ' actor yet back students’ demand #cancelboardexams “don let exam centr becom covid hots…'},
#  {'sentiment': 'positive',
#   'text': ' gov’t held respons gov’t forc futur star sit exam fast spread…'},
#  {'sentiment': 'neutral',
#   'text': ' ie walk area  km — #haridwar railway station har ki pauri amp ghat arrangements…'},
#  {'sentiment': 'neutral',
#   'text': ' actor yet back students’ demand #cancelboardexams “don let exam centr becom covid hots…'},
#  {'sentiment': 'neutral',
#   'text': ' delhi cm request centr govt #cancelcbseboardexams amid fear exam centr becom covid hots…'},
#  {'sentiment': 'neutral',
#   'text': ' unfinish busi \U0001f977🖤🤘🏽 offici announc take covid year continu play universit…'},
#  {'sentiment': 'positive', 'text': ' laundri wash covid clean suppli fro… '},
#  {'sentiment': 'negative', 'text': 'brain destroy greed consumer hedon'},
#  {'sentiment': 'neutral',
#   'text': ' actor yet back students’ demand #cancelboardexams “don let exam centr becom covid hots…'},
#  {'sentiment': 'positive',
#   'text': ' thank take decis safeti student pleas tri clear pictur futur exam pattern asap s…'},
#  {'sentiment': 'neutral',
#   'text': ' #delhi chief minist #arvindkejriwal appeal centr cancel upcom cbse  board exam follow sp…'},
#  {'sentiment': 'positive',
#   'text': ' gov’t held respons gov’t forc futur star sit exam fast spread…'},
#  {'sentiment': 'neutral',
#   'text': ' delhi cm request centr govt #cancelcbseboardexams amid fear exam centr becom covid hots…'},
#  {'sentiment': 'neutral',
#   'text': ' dishearten gov’t taken decis #boardexams yet student make hue amp cri still one ready…'},
#  {'sentiment': 'neutral',
#   'text': ' delhi cm request centr govt #cancelcbseboardexams amid fear exam centr becom covid hots…'},
#  {'sentiment': 'neutral', 'text': ' citi post covid futur '},
#  {'sentiment': 'neutral',
#   'text': ' excel decis district congress offic chhattisgarh turn covid hospit t…'},
#  {'sentiment': 'positive',
#   'text': ' thank take decis safeti student pleas tri clear pictur futur exam pattern asap s…'},
#  {'sentiment': 'neutral',
#   'text': 'everi stori two aspect pictur show naga sadhu wear masks😷 wait take dip ganga during… '},
#  {'sentiment': 'negative',
#   'text': ' #hospitals #mumbai pl help sir covid center friend mom need icu bed kaha pe bhi avail nahi mumb…'},
#  {'sentiment': 'negative',
#   'text': ' chief final call ban wet market covid outbreak '},
#  {'sentiment': 'neutral',
#   'text': ' actor yet back students’ demand #cancelboardexams “don let exam centr becom covid hots…'},
#  {'sentiment': 'negative',
#   'text': ' state examin center emerg covid hotspot delhi cm urg centr cancel cbse bo…'},
#  {'sentiment': 'neutral',
#   'text': ' delhi cm #arvindkejriwal said decis conduct #boardexams reconsid view rise number #c…'},
#  {'sentiment': 'neutral',
#   'text': ' break  doctor sign letter warn grave danger give children co vi  jab '},
#  {'sentiment': 'positive',
#   'text': ' thank take decis safeti student pleas tri clear pictur futur exam pattern asap s…'},
#  {'sentiment': 'neutral',
#   'text': ' delhi cm sh met chairman ganga ram hospit prof dr rana express concern  d…'},
#  {'sentiment': 'positive',
#   'text': ' gov’t held respons gov’t forc futur star sit exam fast spread…'},
#  {'sentiment': 'neutral',
#   'text': ' actor yet back students’ demand #cancelboardexams “don let exam centr becom covid hots…'},
#  {'sentiment': 'neutral',
#   'text': '  hour indian express walk area  km — railway station haridwar icon har…'},
#  {'sentiment': 'positive',
#   'text': ' thank take decis safeti student pleas tri clear pictur futur exam pattern asap s…'},
#  {'sentiment': 'neutral',
#   'text': ' delhi cm request centr govt #cancelcbseboardexams amid fear exam centr becom covid hots…'},
#  {'sentiment': 'neutral',
#   'text': ' resurg pandem indict human compuls sacrific mani fellowmen laid wast i…'},
#  {'sentiment': 'positive',
#   'text': ' gov’t held respons gov’t forc futur star sit exam fast spread…'},
#  {'sentiment': 'neutral',
#   'text': ' delhi cm request centr govt #cancelcbseboardexams amid fear exam centr becom covid hots…'},
#  {'sentiment': 'negative',
#   'text': ' long queue ambul outsid govt run covid hospit ahmedabad regular featur recent st…'},
#  {'sentiment': 'neutral',
#   'text': ' mam pleas speak   lac doctor duti day night forc travel i…'},
#  {'sentiment': 'neutral',
#   'text': ' #cbse mull decis  #boardexams given rise #covid case hope factor preced exist it…'},
#  {'sentiment': 'neutral',
#   'text': ' centr around  km away place regist nd day even abl go electi…'},
#  {'sentiment': 'positive',
#   'text': ' gov’t held respons gov’t forc futur star sit exam fast spread…'},
#  {'sentiment': 'neutral',
#   'text': ' delhi cm request centr govt #cancelcbseboardexams amid fear exam centr becom covid hots…'},
#  {'sentiment': 'neutral', 'text': ' covid danger us 🙏🏻#cancelboardexams '},
#  {'sentiment': 'neutral',
#   'text': ' resurg pandem indict human compuls sacrific mani fellowmen laid wast i…'},
#  {'sentiment': 'neutral',
#   'text': ' delhi cm request centr govt #cancelcbseboardexams amid fear exam centr becom covid hots…'},
#  {'sentiment': 'neutral', 'text': ' citi post covid futur '},
#  {'sentiment': 'neutral',
#   'text': ' request centr cancel cbse exam say delhi cm '},
#  {'sentiment': 'positive',
#   'text': ' close  land right defend lawyer repres pap arbitrarili arrest secur forc faci…'},
#  {'sentiment': 'neutral',
#   'text': ' delhi cm request centr govt #cancelcbseboardexams amid fear exam centr becom covid hots…'},
#  {'sentiment': 'neutral',
#   'text': ' pill smoke someth choos danger well known … '},
#  {'sentiment': 'neutral', 'text': ' citi post covid futur '},
#  {'sentiment': 'neutral', 'text': ' get covid shot refus '},
#  {'sentiment': 'neutral',
#   'text': ' delhi cm request centr govt #cancelcbseboardexams amid fear exam centr becom covid hots…'},
#  {'sentiment': 'neutral', 'text': 'thank sir #cancelcbseboardexam'},
#  {'sentiment': 'positive',
#   'text': ' visual outsid mortuari bhim rao ambedkar memori hospit raipur chhattisgarh report   fresh covid  cases…'},
#  {'sentiment': 'positive',
#   'text': ' gov’t held respons gov’t forc futur star sit exam fast spread…'},
#  {'sentiment': 'neutral',
#   'text': ' uganda struggl strengthen measur curb spread covid  secur agenc work multin co…'},
#  {'sentiment': 'negative',
#   'text': ' accord covid patient rel  patient die within hour due lack oxygen suppli nalasopara vi…'},
#  {'sentiment': 'neutral', 'text': ' citi post covid futur '},
#  {'sentiment': 'neutral',
#   'text': ' delhi cm request centr govt #cancelcbseboardexams amid fear exam centr becom covid hots…'},
#  {'sentiment': 'positive', 'text': ' thank u bhai love ❤️'},
#  {'sentiment': 'neutral',
#   'text': ' delhi cm request centr govt #cancelcbseboardexams amid fear exam centr becom covid hots…'},
#  {'sentiment': 'neutral',
#   'text': ' covid wast contemporari archaeolog help shape polici paper open access '},
#  {'sentiment': 'neutral',
#   'text': ' centr around  km away place regist nd day even abl go electi…'},
#  {'sentiment': 'positive',
#   'text': ' gov’t held respons gov’t forc futur star sit exam fast spread…'},
#  {'sentiment': 'positive',
#   'text': '  land right defend lawyer repres pap pap leader arbitrarili arrest secur forces…'},
#  {'sentiment': 'neutral',
#   'text': ' well done delhi cm decis cancel cbse exam help control speed viru student health cannot be…'},
#  {'sentiment': 'positive',
#   'text': ' thank take decis safeti student pleas tri clear pictur futur exam pattern asap s…'},
#  {'sentiment': 'negative',
#   'text': ' don’t spread fake news devote test neg enter citi '},
#  {'sentiment': 'neutral',
#   'text': ' delhi cm request centr govt #cancelcbseboardexams amid fear exam centr becom covid hots…'},
#  {'sentiment': 'positive',
#   'text': ' thank take decis safeti student pleas tri clear pictur futur exam pattern asap s…'},
#  {'sentiment': 'neutral',
#   'text': ' actor yet back students’ demand #cancelboardexams “don let exam centr becom covid hots…'},
#  {'sentiment': 'neutral',
#   'text': '  hour indian express walk area  km — railway station haridwar icon har…'},
#  {'sentiment': 'neutral',
#   'text': ' delhi cm ask centr cancel cbse exam say  covid patient  year '},
#  {'sentiment': 'positive',
#   'text': ' thank take decis safeti student pleas tri clear pictur futur exam pattern asap s…'},
#  {'sentiment': 'neutral', 'text': ' citi post covid futur '},
#  {'sentiment': 'neutral',
#   'text': ' delhi cm request centr govt #cancelcbseboardexams amid fear exam centr becom covid hots…'},
#  {'sentiment': 'neutral',
#   'text': 'thank sir 🙏🏻 #internalassesment #cancelboardexam '},
#  {'sentiment': 'neutral',
#   'text': ' delhi cm ask centr cancel cbse exam say  covid patient  year '},
#  {'sentiment': 'neutral',
#   'text': ' maharashtra especi mumbai metropolitan region offici beyond redempt everi singl hospit bed c…'},
#  {'sentiment': 'neutral', 'text': ' citi post covid futur '},
#  {'sentiment': 'neutral',
#   'text': ' 🌺॥ जय शेरावाली माता की जय ॥ 🌺 shubh navratri hindu follow sanatan dharma hon abl pm mo…'},
#  {'sentiment': 'neutral',
#   'text': ' horrif visual ambedkar hospit raipur bodi #covid patient pile mortuari f…'},
#  {'sentiment': 'neutral',
#   'text': ' actor yet back students’ demand #cancelboardexams “don let exam centr becom covid hots…'},
#  {'sentiment': 'neutral',
#   'text': ' reliev hear solut achiev allow child refuge reloc well done ex…'},
#  {'sentiment': 'neutral',
#   'text': '  peopl test covid posit #kumbh  lakh devote visit #haridwar monday thermal screeni…'},
#  {'sentiment': 'neutral',
#   'text': ' delhi cm request centr govt #cancelcbseboardexams amid fear exam centr becom covid hots…'},
#  {'sentiment': 'neutral',
#   'text': ' request centr cancel cbse exam say delhi cm '},
#  {'sentiment': 'neutral',
#   'text': 'everyon know covid case rise enorm hell govt even… '},
#  {'sentiment': 'positive',
#   'text': 'plan travel train see indian railways’ latest covid  guidelin via newspo… '},
#  {'sentiment': 'positive',
#   'text': 'thank beauti link tag follow version pandem see far we’ll go #unprecedentedtimes … '},
#  {'sentiment': 'negative',
#   'text': ' ten covid  patient allegedli die due lack oxygen maharashtra’ vasai near mumbai '},
#  {'sentiment': 'positive',
#   'text': ' alway alleg news portal prove best fake news  hospit fulli convert covid special how…'},
#  {'sentiment': 'negative',
#   'text': ' sir pleas speak neet pg  us ordinari doctor work covid center dont h… '},
#  {'sentiment': 'neutral',
#   'text': ' gardai vaccin allow travel reloc child refuge greec stori …'},
#  {'sentiment': 'neutral',
#   'text': 'drdo set covid  hospit  bed icu facil delhi '},
#  {'sentiment': 'negative',
#   'text': ' mam  lakh doctor sit offlin neet pg exam  april mani alreadi posit due covid dutie…'},
#  {'sentiment': 'positive',
#   'text': ' thank take decis safeti student pleas tri clear pictur futur exam pattern asap s…'},
#  {'sentiment': 'neutral',
#   'text': ' maharashtra especi mumbai metropolitan region offici beyond redempt everi singl hospit bed c…'},
#  {'sentiment': 'neutral',
#   'text': ' actor yet back students’ demand #cancelboardexams “don let exam centr becom covid hots…'},
#  {'sentiment': 'positive',
#   'text': '   #covid case last  hour #delhi read number mask stay safe '},
#  {'sentiment': 'positive',
#   'text': 'good memori rememb similar outrag last year focuss part street wh… '},
#  {'sentiment': 'positive',
#   'text': ' thank take decis safeti student pleas tri clear pictur futur exam pattern asap s…'},
#  {'sentiment': 'positive', 'text': ' ok '},
#  {'sentiment': 'neutral',
#   'text': ' delhi cm request centr govt #cancelcbseboardexams amid fear exam centr becom covid hots…'},
#  {'sentiment': 'neutral', 'text': 'ot michigan shut hell '},
#  {'sentiment': 'neutral',
#   'text': ' delhi cm request centr govt #cancelcbseboardexams amid fear exam centr becom covid hots…'},
#  {'sentiment': 'positive',
#   'text': ' gov’t held respons gov’t forc futur star sit exam fast spread…'},
#  {'sentiment': 'positive',
#   'text': ' thank take decis safeti student pleas tri clear pictur futur exam pattern asap s…'},
#  {'sentiment': 'neutral',
#   'text': ' delhi cm request centr govt #cancelcbseboardexams amid fear exam centr becom covid hots…'},
#  {'sentiment': 'neutral',
#   'text': ' request centr cancel cbse exam say delhi cm #httweets via unfol…'},
#  {'sentiment': 'neutral',
#   'text': ' lost covid ue law student grante colleg law scholarship gener avail schol…'},
#  {'sentiment': 'neutral',
#   'text': ' need icu bed ventil facil covid patient tri reach hospit suggest war roo…'},
#  {'sentiment': 'neutral',
#   'text': ' delhi cm request centr govt #cancelcbseboardexams amid fear exam centr becom covid hots…'},
#  {'sentiment': 'positive',
#   'text': ' follow top tip help busi step closer covid secur progress throughout roadmap o…'},
#  {'sentiment': 'positive',
#   'text': 'nearli million hindu bath monday gang observ social distanc wore mask … '},
#  {'sentiment': 'neutral',
#   'text': ' maharashtra especi mumbai metropolitan region offici beyond redempt everi singl hospit bed c…'},
#  {'sentiment': 'neutral',
#   'text': ' delhi cm request centr govt #cancelcbseboardexams amid fear exam centr becom covid hots…'},
#  {'sentiment': 'neutral',
#   'text': ' lost covid ue law student grante colleg law scholarship gener avail schol…'},
#  {'sentiment': 'neutral', 'text': ' citi post covid futur '},
#  {'sentiment': 'neutral',
#   'text': ' actor yet back students’ demand #cancelboardexams “don let exam centr becom covid hots…'},
#  {'sentiment': 'neutral',
#   'text': ' delhi cm request centr govt #cancelcbseboardexams amid fear exam centr becom covid hots…'},
#  {'sentiment': 'negative',
#   'text': ' “we less plasma stock request fallen ill last day recov pleas donat p…'},
#  {'sentiment': 'neutral',
#   'text': ' delhi cm request centr govt #cancelcbseboardexams amid fear exam centr becom covid hots…'},
#  {'sentiment': 'neutral',
#   'text': ' congress leader ask govt reconsid decis conduct #cbseboardexams covid case peak in…'},
#  {'sentiment': 'neutral',
#   'text': ' spatio tempor singl cell atla human develop spinal cord onlin provid overal descript the…'},
#  {'sentiment': 'negative',
#   'text': ' show polit covid  amp mask larg gather blm riot loot destroy busi and…'},
#  {'sentiment': 'negative',
#   'text': ' variou checkpoint indian express count  devote ask rt pcr report — least  n…'},
#  {'sentiment': 'positive',
#   'text': ' despit lock march  enact strict social distanc measur toronto see hospit intens care…'},
#  {'sentiment': 'negative',
#   'text': ' don’t spread fake news devote test neg enter citi '},
#  {'sentiment': 'neutral',
#   'text': ' delhi cm request centr govt #cancelcbseboardexams amid fear exam centr becom covid hots…'},
#  {'sentiment': 'neutral',
#   'text': ' #delhi chief minist #arvindkejriwal appeal centr cancel upcom cbse  board exam follow sp…'},
#  {'sentiment': 'neutral', 'text': ' citi post covid futur '},
#  {'sentiment': 'neutral',
#   'text': ' lost covid ue law student grante colleg law scholarship gener avail schol…'},
#  {'sentiment': 'positive',
#   'text': ' set  new covid care centr across citi   bed #chennaicorporation #covidcare… '},
#  {'sentiment': 'positive',
#   'text': ' gov’t held respons gov’t forc futur star sit exam fast spread…'},
#  {'sentiment': 'positive',
#   'text': ' univers delhi issu fresh measur view increas covid  pandem read '},
#  {'sentiment': 'neutral',
#   'text': 'thankyou sir support us tab bhi wale sunn samajh nhi rh… '},
#  {'sentiment': 'neutral',
#   'text': ' spatio tempor singl cell atla human develop spinal cord onlin provid overal descript the…'},
#  {'sentiment': 'neutral',
#   'text': '#cancelboardexams #internalassessment #boardexams #studentslivesmatter save student save futur'},
#  {'sentiment': 'neutral',
#   'text': ' jim friend colleg six hour tweet kill bike car ran '},
#  {'sentiment': 'neutral',
#   'text': 'rt taylorhudak liter keep awak night former chief scientist pfizer dr michael yeadon reveal biggest fear…'},
#  {'sentiment': 'neutral', 'text': ' mind amp everyon els busi say someth h… '},
#  {'sentiment': 'positive',
#   'text': ' thank take decis safeti student pleas tri clear pictur futur exam pattern asap s…'},
#  {'sentiment': 'positive',
#   'text': ' delhi’ main lnjp hospit close opd emerg servic elect surgeri except #covid emergen…'},
#  {'sentiment': 'neutral',
#   'text': ' #delhi chief minist #arvindkejriwal appeal centr cancel upcom cbse  board exam follow sp…'},
#  {'sentiment': 'positive',
#   'text': ' thank take decis safeti student pleas tri clear pictur futur exam pattern asap s…'},
#  {'sentiment': 'neutral',
#   'text': ' delhi cm request centr govt #cancelcbseboardexams amid fear exam centr becom covid hots…'},
#  {'sentiment': 'negative',
#   'text': ' delhi cm press confer express concern grow case #covid said due t…'},
#  {'sentiment': 'negative',
#   'text': '  covid death  pvt hospit nalasopara yesterday famili alleg death due oxygen shortag …'},
#  {'sentiment': 'negative',
#   'text': ' “we less plasma stock request fallen ill last day recov pleas donat p…'},
#  {'sentiment': 'negative',
#   'text': ' absolut devast icon kiwi mountain compani conquer mt everest fall victim covid  '},
#  {'sentiment': 'neutral',
#   'text': 'pakistan anti franc protest disrupt covid  oxygen suppli say offici '},
#  {'sentiment': 'positive', 'text': 'offici covid stat gujarat true '},
#  {'sentiment': 'neutral',
#   'text': ' rishi sunak confirm push help ex pm david cameron greensil covid loan request yet di…'},
#  {'sentiment': 'negative',
#   'text': ' don’t spread fake news devote test neg enter citi '},
#  {'sentiment': 'neutral',
#   'text': ' #cancelboardexam #sonusood request everyon amid rise #covid case '},
#  {'sentiment': 'neutral', 'text': ' covid'},
#  {'sentiment': 'positive',
#   'text': 'curb covid spread time lockdown ye follow could one good potential… '},
#  {'sentiment': 'neutral',
#   'text': ' mani pvt govt hospit turn fulli covid hospit bed ad delhi cm take decision…'},
#  {'sentiment': 'neutral',
#   'text': ' well done delhi cm decis cancel cbse exam help control speed viru student health cannot be…'},
#  {'sentiment': 'positive',
#   'text': ' thank take decis safeti student pleas tri clear pictur futur exam pattern asap s…'},
#  {'sentiment': 'neutral',
#   'text': ' delhi cm request centr govt #cancelcbseboardexams amid fear exam centr becom covid hots…'},
#  {'sentiment': 'neutral',
#   'text': 'auto compani safeti playbook protocol place year meticul laid they… '},
#  {'sentiment': 'neutral', 'text': ' citi post covid futur '},
#  {'sentiment': 'neutral',
#   'text': ' delhi cm ask centr cancel cbse exam say  covid patient  year '},
#  {'sentiment': 'negative',
#   'text': ' sir pleas speak neet pg  us ordinari doctor work covid center dont nu…'},
#  {'sentiment': 'neutral', 'text': ' citi post covid futur '},
#  {'sentiment': 'positive',
#   'text': '  land right defend lawyer repres pap pap leader arbitrarili arrest secur forces…'},
#  {'sentiment': 'neutral', 'text': ' student respect decis tak… '},
#  {'sentiment': 'neutral',
#   'text': '  hour indian express walk area  km — railway station haridwar icon har…'},
#  {'sentiment': 'neutral',
#   'text': ' monday even  lakh devote turn second shahi snan ganga accord medic departmen…'},
#  {'sentiment': 'neutral', 'text': ' citi post covid futur '},
#  {'sentiment': 'neutral', 'text': 'pl note help guysss🙏🙏'},
#  {'sentiment': 'neutral',
#   'text': ' actor yet back students’ demand #cancelboardexams “don let exam centr becom covid hots…'},
#  {'sentiment': 'neutral',
#   'text': ' actor yet back students’ demand #cancelboardexams “don let exam centr becom covid hots…'},
#  {'sentiment': 'neutral', 'text': ' sole singl exampl provid brecur and… '},
#  {'sentiment': 'neutral',
#   'text': ' actor yet back students’ demand #cancelboardexams “don let exam centr becom covid hots…'},
#  {'sentiment': 'positive',
#   'text': ' thank take decis safeti student pleas tri clear pictur futur exam pattern asap s…'},
#  {'sentiment': 'neutral',
#   'text': ' dishearten gov’t taken decis #boardexams yet student make hue amp cri still one ready…'},
#  {'sentiment': 'neutral',
#   'text': 'mani facil locat region  region  convers augment need facil… '},
#  {'sentiment': 'neutral', 'text': ' covid patient covid spreader '},
#  {'sentiment': 'positive',
#   'text': ' gov’t held respons gov’t forc futur star sit exam fast spread…'},
#  {'sentiment': 'negative',
#   'text': 'nearli half busi travel reject futur flight favour video call '},
#  {'sentiment': 'positive',
#   'text': ' thank take decis safeti student pleas tri clear pictur futur exam pattern asap s…'},
#  {'sentiment': 'positive',
#   'text': ' thank take decis safeti student pleas tri clear pictur futur exam pattern asap s…'},
#  {'sentiment': 'positive',
#   'text': ' gov’t held respons gov’t forc futur star sit exam fast spread…'},
#  {'sentiment': 'neutral',
#   'text': ' excel decis district congress offic chhattisgarh turn covid hospit t…'},
#  {'sentiment': 'neutral',
#   'text': ' maharashtra especi mumbai metropolitan region offici beyond redempt everi singl hospit bed c…'},
#  {'sentiment': 'negative',
#   'text': ' fear hidden debt could stymi small busi covid '},
#  {'sentiment': 'neutral', 'text': ' lbc choos post choos caption queue lo… '},
#  {'sentiment': 'neutral',
#   'text': 'uk automat covid trace hit yet anoth snag '},
#  {'sentiment': 'neutral',
#   'text': ' mathew carver founder famou could never thought  year begin foodse…'},
#  {'sentiment': 'negative',
#   'text': ' “we less plasma stock request fallen ill last day recov pleas donat p…'},
#  {'sentiment': 'neutral',
#   'text': ' #middaynews three jumbo #covid centr come   bed ad say chief …'},
#  {'sentiment': 'positive',
#   'text': ' thank much transcrib dr mike yeadon vital import interview danger vaccine…'},
#  {'sentiment': 'neutral',
#   'text': 'spoke rel canada toronto yesterday covid case rise 😱😱😱 '},
#  {'sentiment': 'positive',
#   'text': 'listen stephen ask whether it’ safe go beach summer beach forest p… '},
#  {'sentiment': 'positive',
#   'text': ' 😃 last night saw news love covid  bulletin ukrain itali no… '},
#  {'sentiment': 'neutral', 'text': ' citi post covid futur '},
#  {'sentiment': 'neutral',
#   'text': ' potenti oxygen shortag lahor terrifi there’ place move anyon go give way ambul…'},
#  {'sentiment': 'positive',
#   'text': 'maintain good immun surviv covid  pandem comfort good immun strongest defence… '},
#  {'sentiment': 'neutral',
#   'text': ' #cancelboardexam #sonusood request everyon amid rise #covid case '},
#  {'sentiment': 'neutral',
#   'text': ' delhi cm request centr govt #cancelcbseboardexams amid fear exam centr becom covid hots…'},
#  {'sentiment': 'neutral',
#   'text': ' excel step kaushal raj sharma ji almost  extra bed creat l l covid patient i…'},
#  {'sentiment': 'positive',
#   'text': 'sheep move new herd town sampl paper show effect lockdowns… '},
#  {'sentiment': 'positive',
#   'text': ' thank beauti link tag follow version pandem see far we’ll go #unprecedentedtimes …'},
#  {'sentiment': 'neutral',
#   'text': ' renown virologist dr sucharit bhakdi asymptomat carrier spreader covid '},
#  {'sentiment': 'neutral',
#   'text': ' maharashtra especi mumbai metropolitan region offici beyond redempt everi singl hospit bed c…'},
#  {'sentiment': 'neutral',
#   'text': ' delhi cm request centr govt #cancelcbseboardexams amid fear exam centr becom covid hots…'},
#  {'sentiment': 'neutral',
#   'text': 'help sixth former make lost learn say uk colleg leader '},
#  {'sentiment': 'neutral',
#   'text': ' delhi cm request centr govt #cancelcbseboardexams amid fear exam centr becom covid hots…'},
#  {'sentiment': 'neutral',
#   'text': ' dishearten gov’t taken decis #boardexams yet student make hue amp cri still one ready…'},
#  {'sentiment': 'negative',
#   'text': ' don’t spread fake news devote test neg enter citi '},
#  {'sentiment': 'neutral',
#   'text': ' actor yet back students’ demand #cancelboardexams “don let exam centr becom covid hots…'},
#  {'sentiment': 'neutral',
#   'text': ' govt organ golf tournament spread covid  among peopl '},
#  {'sentiment': 'neutral',
#   'text': ' delhi cm request centr govt #cancelcbseboardexams amid fear exam centr becom covid hots…'},
#  {'sentiment': 'neutral',
#   'text': ' delhi cm request centr govt #cancelcbseboardexams amid fear exam centr becom covid hots…'},
#  {'sentiment': 'neutral',
#   'text': ' วันที่  หลังจากติดโควิดแล้ว #หมอชนะ ยังคงเป็นสีเขียวสวยงาม เสี่ยงต่ำมาก … it’  day covid  yet…'},
#  {'sentiment': 'neutral',
#   'text': ' realli look forward final launch tomorrow '},
#  {'sentiment': 'positive',
#   'text': ' it’ choic face consequ either live restrict lifestyl keep case low l… '},
#  {'sentiment': 'neutral',
#   'text': ' bro kisn achh se tayari ki hai kisn nhi ki everyon safeti c… '},
#  {'sentiment': 'neutral',
#   'text': ' 💔patient ‘elective’ life chang surgeri postpon hospit overwhelm 💔covid survivor wonde…'},
#  {'sentiment': 'negative',
#   'text': ' don’t spread fake news devote test neg enter citi '},
#  {'sentiment': 'negative',
#   'text': '  covid death  pvt hospit nalasopara yesterday famili alleg death due oxygen shortag …'},
#  {'sentiment': 'neutral',
#   'text': ' delhi cm request centr govt #cancelcbseboardexams amid fear exam centr becom covid hots…'},
#  {'sentiment': 'positive',
#   'text': ' thank take decis safeti student pleas tri clear pictur futur exam pattern asap s…'},
#  {'sentiment': 'neutral',
#   'text': ' break  doctor sign letter warn grave danger give children co vi  jab '},
#  {'sentiment': 'neutral', 'text': ' citi post covid futur '},
#  {'sentiment': 'neutral', 'text': ' “ nna covid e mboril shem ‼️‼️” '},
#  {'sentiment': 'neutral',
#   'text': ' delhi cm #arvindkejriwal said decis conduct #boardexams reconsid view rise number #c…'},
#  {'sentiment': 'neutral',
#   'text': ' thank support cbse student save life student #cancelboardexams '},
#  {'sentiment': 'positive',
#   'text': ' urgent need plasma donor critic covid  patient new delhi lead would appreci help would…'},
#  {'sentiment': 'negative',
#   'text': ' beg help  children one autist husband fell ill covid keep isolated…'},
#  {'sentiment': 'positive',
#   'text': ' gov’t held respons gov’t forc futur star sit exam fast spread…'},
#  {'sentiment': 'positive',
#   'text': ' thank take decis safeti student pleas tri clear pictur futur exam pattern asap s…'},
#  {'sentiment': 'positive',
#   'text': ' gov’t held respons gov’t forc futur star sit exam fast spread…'},
#  {'sentiment': 'negative',
#   'text': ' sir pleas speak neet pg  us ordinari doctor work covid center dont nu…'},
#  {'sentiment': 'neutral',
#   'text': ' #हिन्दू नववर्ष की सभी को शुभकामनाएं happi #gudipadwa happi #navratri happi #ugadi happi #ramadanmubarak everyo…'},
#  {'sentiment': 'negative',
#   'text': ' sir pleas speak neet pg  us ordinari doctor work covid center dont nu…'},
#  {'sentiment': 'neutral', 'text': ' citi post covid futur '},
#  {'sentiment': 'neutral',
#   'text': ' delhi cm request centr govt #cancelcbseboardexams amid fear exam centr becom covid hots…'},
#  {'sentiment': 'neutral',
#   'text': ' delhi cm request centr govt #cancelcbseboardexams amid fear exam centr becom covid hots…'},
#  {'sentiment': 'neutral',
#   'text': ' ‘we lose doctors’ sudan’ health worker plead covid jab '},
#  {'sentiment': 'positive',
#   'text': ' #covid migrant arriv huge number mumbai station amid lockdown fear railway call summer rush '},
#  {'sentiment': 'positive',
#   'text': ' us compani neck deep collabor chines govt major indian busi remov dow j…'},
#  {'sentiment': 'neutral', 'text': 'excel depict current situat preval india '},
#  {'sentiment': 'neutral',
#   'text': ' dozen news organis take part #climateemergencyweek includ reuter bloomberg agenc franc pre…'},
#  {'sentiment': 'neutral',
#   'text': ' everyon opinion may agre disagre india rule sharia one call behead disagre…'},
#  {'sentiment': 'neutral',
#   'text': ' might also wish us happi vaisakhi ugadi navratri tomorrow vishu sinc india one biggest market …'},
#  {'sentiment': 'neutral',
#   'text': ' arm #ai #onlinemandis shake #farming aim cut wast #boost #farmincome mi…'},
#  {'sentiment': 'neutral',
#   'text': ' discuss “wellb hour understand emot pain  pm ” …'},
#  {'sentiment': 'positive',
#   'text': ' thank need hour good see maharashtra govt i…'},
#  {'sentiment': 'neutral',
#   'text': '  hour indian express walk area  km — railway station haridwar icon har…'},
#  {'sentiment': 'neutral',
#   'text': ' hold ur breath u call masterstrok govt wait letter remind the…'},
#  {'sentiment': 'neutral',
#   'text': ' might also wish us happi vaisakhi ugadi navratri tomorrow vishu sinc india one biggest market …'},
#  {'sentiment': 'neutral', 'text': ' peac karachi part india '},
#  {'sentiment': 'positive',
#   'text': ' jagmeet singh famili left india refuge decad ago abandon right indian citizenship jagmeet pe…'},
#  {'sentiment': 'neutral',
#   'text': ' darjeel one beauti citi india one oldest establish citi india rece…'},
#  {'sentiment': 'positive',
#   'text': ' tesla face speed bump take first step india’ nascent electr vehicl market analyst warn '},
#  {'sentiment': 'neutral',
#   'text': ' kashmir trade polit help india pakistan move forward ex envoy delhi salman bashir …'},
#  {'sentiment': 'negative',
#   'text': 'ummm ask ass burn seem becom stiff hole littl pain washroom unable… '},
#  {'sentiment': 'neutral',
#   'text': ' resurg pandem indict human compuls sacrific mani fellowmen laid wast i…'},
#  {'sentiment': 'neutral',
#   'text': ' darjeel one beauti citi india one oldest establish citi india rec…'},
#  {'sentiment': 'positive',
#   'text': ' sir covid warrior gujarat request rais voic young doctor india are…'},
#  {'sentiment': 'neutral',
#   'text': ' resurg pandem indict human compuls sacrific mani fellowmen laid wast i…'},
#  {'sentiment': 'positive',
#   'text': ' us compani neck deep collabor chines govt major indian busi remov dow j…'},
#  {'sentiment': 'positive',
#   'text': ' us compani neck deep collabor chines govt major indian busi remov dow j…'},
#  {'sentiment': 'neutral',
#   'text': ' everyon opinion may agre disagre india rule sharia one call behead disagre…'},
#  {'sentiment': 'neutral',
#   'text': '  hour indian express walk area  km — railway station haridwar icon har…'},
#  {'sentiment': 'neutral',
#   'text': ' insist along mock abus shriek one take seriou…'},
#  {'sentiment': 'neutral',
#   'text': ' darjeel one beauti citi india one oldest establish citi india recei…'},
#  {'sentiment': 'neutral',
#   'text': ' everyon opinion may agre disagre india rule sharia one call behead disagre…'},
#  {'sentiment': 'neutral',
#   'text': ' might also wish us happi vaisakhi ugadi navratri tomorrow vishu sinc india one biggest market …'},
#  {'sentiment': 'positive',
#   'text': ' us compani neck deep collabor chines govt major indian busi remov dow j…'},
#  {'sentiment': 'neutral',
#   'text': ' might also wish us happi vaisakhi ugadi navratri tomorrow vishu sinc india one biggest market …'},
#  {'sentiment': 'positive',
#   'text': ' us compani neck deep collabor chines govt major indian busi remov dow j…'},
#  {'sentiment': 'positive',
#   'text': ' indian care woke bs hilari apu everyon india laugh accent h…'},
#  {'sentiment': 'neutral',
#   'text': ' surat smimer amp pvt hospit refus admit patient   patient are…'},
#  {'sentiment': 'positive',
#   'text': ' thank need hour good see maharashtra govt i…'},
#  {'sentiment': 'positive',
#   'text': 'new begin peac amp abund let harvest fresh feel hope happi amp heal 🌾\U0001fa98… '},
#  {'sentiment': 'positive',
#   'text': ' thank deepest gratitud sir gangaram hospit shape better doctor proud alumnu keep savin…'},
#  {'sentiment': 'neutral',
#   'text': ' darjeel one beauti citi india one oldest establish citi india received…'},
#  {'sentiment': 'neutral',
#   'text': ' might also wish us happi vaisakhi ugadi navratri tomorrow vishu sinc india one biggest market …'},
#  {'sentiment': 'neutral',
#   'text': ' everyon opinion may agre disagre india rule sharia one call behead disagre…'},
#  {'sentiment': 'positive', 'text': 'good decis peopl choic #wtoera'},
#  {'sentiment': 'neutral',
#   'text': ' #indian #supremecourt rock thank call frivol absolut wast time spread ha…'},
#  {'sentiment': 'neutral',
#   'text': ' it’ ur scriptur come practis #hanafi #sunni sect is… '},
#  {'sentiment': 'positive',
#   'text': ' #covid migrant arriv huge number mumbai station amid lockdown fear railway call summer rush '},
#  {'sentiment': 'neutral', 'text': ' speechless'},
#  {'sentiment': 'positive',
#   'text': ' us compani neck deep collabor chines govt major indian busi remov dow j…'},
#  {'sentiment': 'neutral',
#   'text': ' darjeel one beauti citi india one oldest establish citi india receiv…'},
#  {'sentiment': 'neutral',
#   'text': ' darjeel one beauti citi india one oldest establish citi india recei…'},
#  {'sentiment': 'negative',
#   'text': '#tatagroup launch #marketplace well suit #enterprise #tech #solutions small medium enterprise… '},
#  {'sentiment': 'positive',
#   'text': ' us compani neck deep collabor chines govt major indian busi remov dow j…'},
#  {'sentiment': 'positive', 'text': 'india stock higher close trade nifti    '},
#  {'sentiment': 'positive',
#   'text': ' us compani neck deep collabor chines govt major indian busi remov dow j…'},
#  {'sentiment': 'neutral',
#   'text': ' everyon opinion may agre disagre india rule sharia one call behead disagre…'},
#  {'sentiment': 'neutral',
#   'text': ' hope premier univers region explor way promot mutual understanding…'},
#  {'sentiment': 'neutral',
#   'text': ' ambul patient wait line admit insid hospit ahmedabad gujrat situat g…'},
#  {'sentiment': 'positive',
#   'text': ' thank need hour good see maharashtra govt take initi help al…'},
#  {'sentiment': 'positive',
#   'text': ' us compani neck deep collabor chines govt major indian busi remov dow j…'},
#  {'sentiment': 'neutral',
#   'text': '  hour indian express walk area  km — railway station haridwar icon har…'},
#  {'sentiment': 'neutral',
#   'text': ' everyon opinion may agre disagre india rule sharia one call behead disagre…'},
#  {'sentiment': 'neutral',
#   'text': ' “accord medic depart offici   devote test   pm sunday  pm monday — …'},
#  {'sentiment': 'neutral',
#   'text': ' poster ask behead ji put religi bigot owaisi aimim forget security…'},
#  {'sentiment': 'positive',
#   'text': 'let’ welcom ugadi great hope eager amp anticip let us look forward plenti joy satisfact… '},
#  {'sentiment': 'positive',
#   'text': ' thank need hour good see maharashtra govt i…'},
#  {'sentiment': 'neutral',
#   'text': ' resurg pandem indict human compuls sacrific mani fellowmen laid wast i…'},
#  {'sentiment': 'neutral',
#   'text': '🎊it’ wrap #neurofemindia 🎊 💯 grate everyon chose particip confer an… '},
#  {'sentiment': 'positive',
#   'text': ' us compani neck deep collabor chines govt major indian busi remov dow j…'},
#  {'sentiment': 'positive',
#   'text': 'top  trust microfin #companies india  #business'},
#  {'sentiment': 'positive',
#   'text': ' inshah bashir wheelchair basketbal player jammu kashmir made india proud inspiration…'},
#  {'sentiment': 'neutral',
#   'text': ' might also wish us happi vaisakhi ugadi navratri tomorrow vishu sinc india one biggest market …'}]

# %%
   
# output the dataframe
  

ptweets = [tweet for tweet in tweets if tweet['sentiment'] == 'positive']
	# percentage of positive tweets
print("Positive tweets percentage: {} %".format(100*len(ptweets)/len(tweets)))
	# picking negative tweets from tweets
ntweets = [tweet for tweet in tweets if tweet['sentiment'] == 'negative']
	# percentage of negative tweets
print("Negative tweets percentage: {} %".format(100*len(ntweets)/len(tweets)))
	# percentage of neutral tweets
print("Neutral tweets percentage: {} % \
		".format(100*(len(tweets) -(len( ntweets )+len( ptweets)))/len(tweets)))

	# printing first 5 positive tweets
print("\n\nPositive tweets:")
for tweet in ptweets[:400]:
	print(tweet['text'])

	# printing first 5 negative tweets
print("\n\nNegative tweets:")
for tweet in ntweets[:10]:
  print(tweet['text'])
# Out:
# Positive tweets percentage: 28.267477203647417 %
# Negative tweets percentage: 9.422492401215806 %
# Neutral tweets percentage: 62.31003039513678 %
#
#
# Positive tweets:
#  thank take decis safeti student pleas tri clear pictur futur exam pattern asap s…
#  hour tweet kill ride bike love cycl cautiou hell i…
# good decis long overdu mra regulatori bodi one stringent emerg requiremen…
#  good decis altern assess way postpon long time #internalas…
#  gov’t held respons gov’t forc futur star sit exam fast spread…
#  #cancelboardexam #internalassessment amaz full ever seen thank support
#   land right defend lawyer repres pap pap leader arbitrarili arrest secur forces…
#  gov’t held respons gov’t forc futur star sit exam fast spread…
#  laundri wash covid clean suppli fro…
#  thank take decis safeti student pleas tri clear pictur futur exam pattern asap s…
#  gov’t held respons gov’t forc futur star sit exam fast spread…
#  thank take decis safeti student pleas tri clear pictur futur exam pattern asap s…
#  thank take decis safeti student pleas tri clear pictur futur exam pattern asap s…
#  gov’t held respons gov’t forc futur star sit exam fast spread…
#  thank take decis safeti student pleas tri clear pictur futur exam pattern asap s…
#  gov’t held respons gov’t forc futur star sit exam fast spread…
#  gov’t held respons gov’t forc futur star sit exam fast spread…
#  close  land right defend lawyer repres pap arbitrarili arrest secur forc faci…
#  visual outsid mortuari bhim rao ambedkar memori hospit raipur chhattisgarh report   fresh covid  cases…
#  gov’t held respons gov’t forc futur star sit exam fast spread…
#  thank u bhai love ❤️
#  gov’t held respons gov’t forc futur star sit exam fast spread…
#   land right defend lawyer repres pap pap leader arbitrarili arrest secur forces…
#  thank take decis safeti student pleas tri clear pictur futur exam pattern asap s…
#  thank take decis safeti student pleas tri clear pictur futur exam pattern asap s…
#  thank take decis safeti student pleas tri clear pictur futur exam pattern asap s…
# plan travel train see indian railways’ latest covid  guidelin via newspo…
# thank beauti link tag follow version pandem see far we’ll go #unprecedentedtimes …
#  alway alleg news portal prove best fake news  hospit fulli convert covid special how…
#  thank take decis safeti student pleas tri clear pictur futur exam pattern asap s…
#    #covid case last  hour #delhi read number mask stay safe
# good memori rememb similar outrag last year focuss part street wh…
#  thank take decis safeti student pleas tri clear pictur futur exam pattern asap s…
#  ok
#  gov’t held respons gov’t forc futur star sit exam fast spread…
#  thank take decis safeti student pleas tri clear pictur futur exam pattern asap s…
#  follow top tip help busi step closer covid secur progress throughout roadmap o…
# nearli million hindu bath monday gang observ social distanc wore mask …
#  despit lock march  enact strict social distanc measur toronto see hospit intens care…
#  set  new covid care centr across citi   bed #chennaicorporation #covidcare…
#  gov’t held respons gov’t forc futur star sit exam fast spread…
#  univers delhi issu fresh measur view increas covid  pandem read
#  thank take decis safeti student pleas tri clear pictur futur exam pattern asap s…
#  delhi’ main lnjp hospit close opd emerg servic elect surgeri except #covid emergen…
#  thank take decis safeti student pleas tri clear pictur futur exam pattern asap s…
# offici covid stat gujarat true
# curb covid spread time lockdown ye follow could one good potential…
#  thank take decis safeti student pleas tri clear pictur futur exam pattern asap s…
#   land right defend lawyer repres pap pap leader arbitrarili arrest secur forces…
#  thank take decis safeti student pleas tri clear pictur futur exam pattern asap s…
#  gov’t held respons gov’t forc futur star sit exam fast spread…
#  thank take decis safeti student pleas tri clear pictur futur exam pattern asap s…
#  thank take decis safeti student pleas tri clear pictur futur exam pattern asap s…
#  gov’t held respons gov’t forc futur star sit exam fast spread…
#  thank much transcrib dr mike yeadon vital import interview danger vaccine…
# listen stephen ask whether it’ safe go beach summer beach forest p…
#  😃 last night saw news love covid  bulletin ukrain itali no…
# maintain good immun surviv covid  pandem comfort good immun strongest defence…
# sheep move new herd town sampl paper show effect lockdowns…
#  thank beauti link tag follow version pandem see far we’ll go #unprecedentedtimes …
#  it’ choic face consequ either live restrict lifestyl keep case low l…
#  thank take decis safeti student pleas tri clear pictur futur exam pattern asap s…
#  urgent need plasma donor critic covid  patient new delhi lead would appreci help would…
#  gov’t held respons gov’t forc futur star sit exam fast spread…
#  thank take decis safeti student pleas tri clear pictur futur exam pattern asap s…
#  gov’t held respons gov’t forc futur star sit exam fast spread…
#  #covid migrant arriv huge number mumbai station amid lockdown fear railway call summer rush
#  us compani neck deep collabor chines govt major indian busi remov dow j…
#  thank need hour good see maharashtra govt i…
#  jagmeet singh famili left india refuge decad ago abandon right indian citizenship jagmeet pe…
#  tesla face speed bump take first step india’ nascent electr vehicl market analyst warn
#  sir covid warrior gujarat request rais voic young doctor india are…
#  us compani neck deep collabor chines govt major indian busi remov dow j…
#  us compani neck deep collabor chines govt major indian busi remov dow j…
#  us compani neck deep collabor chines govt major indian busi remov dow j…
#  us compani neck deep collabor chines govt major indian busi remov dow j…
#  indian care woke bs hilari apu everyon india laugh accent h…
#  thank need hour good see maharashtra govt i…
# new begin peac amp abund let harvest fresh feel hope happi amp heal 🌾🪘…
#  thank deepest gratitud sir gangaram hospit shape better doctor proud alumnu keep savin…
# good decis peopl choic #wtoera
#  #covid migrant arriv huge number mumbai station amid lockdown fear railway call summer rush
#  us compani neck deep collabor chines govt major indian busi remov dow j…
#  us compani neck deep collabor chines govt major indian busi remov dow j…
# india stock higher close trade nifti
#  us compani neck deep collabor chines govt major indian busi remov dow j…
#  thank need hour good see maharashtra govt take initi help al…
#  us compani neck deep collabor chines govt major indian busi remov dow j…
# let’ welcom ugadi great hope eager amp anticip let us look forward plenti joy satisfact…
#  thank need hour good see maharashtra govt i…
#  us compani neck deep collabor chines govt major indian busi remov dow j…
# top  trust microfin #companies india  #business
#  inshah bashir wheelchair basketbal player jammu kashmir made india proud inspiration…
#
#
# Negative tweets:
# brain destroy greed consumer hedon
#  #hospitals #mumbai pl help sir covid center friend mom need icu bed kaha pe bhi avail nahi mumb…
#  chief final call ban wet market covid outbreak
#  state examin center emerg covid hotspot delhi cm urg centr cancel cbse bo…
#  long queue ambul outsid govt run covid hospit ahmedabad regular featur recent st…
#  accord covid patient rel  patient die within hour due lack oxygen suppli nalasopara vi…
#  don’t spread fake news devote test neg enter citi
#  ten covid  patient allegedli die due lack oxygen maharashtra’ vasai near mumbai
#  sir pleas speak neet pg  us ordinari doctor work covid center dont h…
#  mam  lakh doctor sit offlin neet pg exam  april mani alreadi posit due covid dutie…

# %%
import pandas as pd

df = pd.DataFrame(tweets, columns=['sentiment'])
df.head(1000)
# Out:
#     sentiment
# 0     neutral
# 1    positive
# 2    positive
# 3     neutral
# 4    positive
# ..        ...
# 324   neutral
# 325  positive
# 326  positive
# 327  positive
# 328   neutral
#
# [329 rows x 1 columns]

# %%
df.apply(pd.Series.value_counts)
plt.title('Sentiment Analysis')
plt.xlabel ('Sentiment')
plt.ylabel('Counts')
df.apply(pd.Series.value_counts).plot(kind = 'bar')
plt.show()
